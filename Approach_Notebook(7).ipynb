# %% [markdown]
# # Approach Explanation:
#
# So what we plan to do is having multiple questions from a long context, we plan to separate out the context into chunks of roughly 800 words (tokens) and pass all of the questions along with the chunks and ask LLM to answer the relevant questions from the chunk and leave the rest of them blank. then, depending on the response observations we have, we will either interleave the answers manually or ask an LLM to do so.

# %% [markdown]
# ### Initial Code:
#
# This is the setup code, from the Experiments notebook, downloads the datasets and initial setup of class

# %%
# !pip install gdown #to download the dataset from google drive
# !pip install -U langchain-community # to work with the langchain llm



import gdown # to download dataset from google drive
import pandas as pd #to import dataset as
from collections import defaultdict # to store the context map
from langchain.llms import HuggingFaceHub # to initialize the LLM



validation_dataset_url = 'https://drive.google.com/uc?id=1bGNCDoItbvFbBWoDgBF8YcLFI1Te5RmV'
training_dataset_url = 'https://drive.google.com/uc?id=1-vsbRTLKgo2PalcG3AargcBblytlGQd1'

validation_dataset_filename = 'validation_dataset.csv'
training_dataset_filename = 'training_dataset.csv'

gdown.download(validation_dataset_url, validation_dataset_filename, quiet=True)
gdown.download(training_dataset_url, training_dataset_filename, quiet=True)


df = pd.read_csv(training_dataset_filename)


context_map = defaultdict(list)
for _, row in df.iterrows():
    context = row['context']
    question = row['question']
    answer = row['text']
    context_map[context].append((question, answer))
# Out:
# Requirement already satisfied: gdown in /usr/local/lib/python3.11/dist-packages (5.2.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.11/dist-packages (from gdown) (4.13.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from gdown) (3.18.0)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.11/dist-packages (from gdown) (2.32.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from gdown) (4.67.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4->gdown) (2.7)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4->gdown) (4.13.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests[socks]->gdown) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests[socks]->gdown) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests[socks]->gdown) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests[socks]->gdown) (2025.4.26)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.11/dist-packages (from requests[socks]->gdown) (1.7.1)
# Collecting langchain-community
#   Downloading langchain_community-0.3.23-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.56 in /usr/local/lib/python3.11/dist-packages (from langchain-community) (0.3.56)
# Requirement already satisfied: langchain<1.0.0,>=0.3.24 in /usr/local/lib/python3.11/dist-packages (from langchain-community) (0.3.24)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /usr/local/lib/python3.11/dist-packages (from langchain-community) (2.0.40)
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.11/dist-packages (from langchain-community) (2.32.3)
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.11/dist-packages (from langchain-community) (6.0.2)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.11/dist-packages (from langchain-community) (3.11.15)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in /usr/local/lib/python3.11/dist-packages (from langchain-community) (9.1.2)
# Collecting dataclasses-json<0.7,>=0.5.7 (from langchain-community)
#   Downloading dataclasses_json-0.6.7-py3-none-any.whl.metadata (25 kB)
# Collecting pydantic-settings<3.0.0,>=2.4.0 (from langchain-community)
#   Downloading pydantic_settings-2.9.1-py3-none-any.whl.metadata (3.8 kB)
# Requirement already satisfied: langsmith<0.4,>=0.1.125 in /usr/local/lib/python3.11/dist-packages (from langchain-community) (0.3.38)
# Collecting httpx-sse<1.0.0,>=0.4.0 (from langchain-community)
#   Downloading httpx_sse-0.4.0-py3-none-any.whl.metadata (9.0 kB)
# Requirement already satisfied: numpy>=1.26.2 in /usr/local/lib/python3.11/dist-packages (from langchain-community) (2.0.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.6.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.4.3)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.20.0)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json<0.7,>=0.5.7->langchain-community)
#   Downloading marshmallow-3.26.1-py3-none-any.whl.metadata (7.3 kB)
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json<0.7,>=0.5.7->langchain-community)
#   Downloading typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.8 in /usr/local/lib/python3.11/dist-packages (from langchain<1.0.0,>=0.3.24->langchain-community) (0.3.8)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /usr/local/lib/python3.11/dist-packages (from langchain<1.0.0,>=0.3.24->langchain-community) (2.11.3)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /usr/local/lib/python3.11/dist-packages (from langchain-core<1.0.0,>=0.3.56->langchain-community) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in /usr/local/lib/python3.11/dist-packages (from langchain-core<1.0.0,>=0.3.56->langchain-community) (24.2)
# Requirement already satisfied: typing-extensions>=4.7 in /usr/local/lib/python3.11/dist-packages (from langchain-core<1.0.0,>=0.3.56->langchain-community) (4.13.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from langsmith<0.4,>=0.1.125->langchain-community) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /usr/local/lib/python3.11/dist-packages (from langsmith<0.4,>=0.1.125->langchain-community) (3.10.17)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from langsmith<0.4,>=0.1.125->langchain-community) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from langsmith<0.4,>=0.1.125->langchain-community) (0.23.0)
# Collecting python-dotenv>=0.21.0 (from pydantic-settings<3.0.0,>=2.4.0->langchain-community)
#   Downloading python_dotenv-1.1.0-py3-none-any.whl.metadata (24 kB)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic-settings<3.0.0,>=2.4.0->langchain-community) (0.4.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2->langchain-community) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2->langchain-community) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2->langchain-community) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2->langchain-community) (2025.4.26)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.11/dist-packages (from SQLAlchemy<3,>=1.4->langchain-community) (3.2.1)
# Requirement already satisfied: anyio in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-community) (4.9.0)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-community) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-community) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.11/dist-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.56->langchain-community) (3.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain<1.0.0,>=0.3.24->langchain-community) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.1 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain<1.0.0,>=0.3.24->langchain-community) (2.33.1)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community)
#   Downloading mypy_extensions-1.1.0-py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.11/dist-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-community) (1.3.1)
# Downloading langchain_community-0.3.23-py3-none-any.whl (2.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 29.7 MB/s eta 0:00:00
# Downloading dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Downloading httpx_sse-0.4.0-py3-none-any.whl (7.8 kB)
# Downloading pydantic_settings-2.9.1-py3-none-any.whl (44 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.4/44.4 kB 3.4 MB/s eta 0:00:00
# Downloading marshmallow-3.26.1-py3-none-any.whl (50 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.9/50.9 kB 4.2 MB/s eta 0:00:00
# Downloading python_dotenv-1.1.0-py3-none-any.whl (20 kB)
# Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Downloading mypy_extensions-1.1.0-py3-none-any.whl (5.0 kB)
# Installing collected packages: python-dotenv, mypy-extensions, marshmallow, httpx-sse, typing-inspect, pydantic-settings, dataclasses-json, langchain-community
# Successfully installed dataclasses-json-0.6.7 httpx-sse-0.4.0 langchain-community-0.3.23 marshmallow-3.26.1 mypy-extensions-1.1.0 pydantic-settings-2.9.1 python-dotenv-1.1.0 typing-inspect-0.9.0

# %% [markdown]
# ### Approach Class:
#
# This is the class continued from notebook1

# %%
class Agent2:
    #same context overload notebook
    def __init__(self, context_map, model_name="mistralai/Mistral-7B-Instruct-v0.3", access_token="TOKEN-HERE"):
        self.context_map = context_map
        self.llm = HuggingFaceHub(
            repo_id=model_name,
            model_kwargs={"temperature": 0.3, "max_length": 200},
            huggingfacehub_api_token=access_token
        )
        self.current_prompt = None # NEW: ask user to input context and questions seperately. chunks will only be made of context.
        self.chunked_prompts = []
        self.responses = []

    def generate_response(self, prompt): #can use this function to get answer from 1 chunk, then 2nd chunk etc, all chunks and then proceed. with normal
        return self.llm(prompt)

    def get_context_questions(self, k=2, q=4):
      #same as context overload notebook
        contexts = []
        questions_answers = []
        selected_contexts = list(self.context_map.items())[:k]
        for context, qa_pairs in selected_contexts:
            contexts.append(context)
            selected_qa = qa_pairs[:q]
            questions_answers.append(selected_qa)
        return contexts, questions_answers

    def generate_Dataset_prompt(self, k=2, q=4):
        ''' This function generates and imitates a prompt from the dataset, later on, we will take questions and context as input from user.'''
        contexts, questions_answers_by_context = self.get_context_questions(k, q)
        combined_context = "\n\n".join(contexts)
        all_questions_answers = []
        for qa_pairs in questions_answers_by_context:
            all_questions_answers.extend(qa_pairs)
        prompt_lines = [
            "answer these questions:",
            "Answer as precisely as you can, in as minimum words as you can",
            "Format your answers with 'A1:', 'A2:', etc. at the beginning of each answer"
        ]
        for i, (question, _) in enumerate(all_questions_answers, 1):
            prompt_lines.append(f"Q{i}: {question}")
        prompt_lines.append("\nfrom this context:")
        prompt_lines.append(combined_context)
        prompt = "\n".join(prompt_lines)
        self.current_prompt = prompt
        char_length = len(prompt)
        token_count = len(prompt.split())
        # print(f"\n🧠 Combined Prompt:")
        # print(f"Length: {char_length} characters, approximately {token_count} tokens")
        # print(f"{prompt}\n")


    def chunk_current_prompt(self, max_words_per_chunk=800):
        """
        Splits the context into ~800-word chunks and constructs prompts accordingly.
        Stores the chunked prompts in self.chunked_prompts.
        """
        if not hasattr(self, 'current_prompt') or self.current_prompt is None:
            raise ValueError("current_prompt not set. Please run generate_Dataset_prompt first.")

        # Split current prompt into parts
        prompt_parts = self.current_prompt.split("\nfrom this context:\n")
        if len(prompt_parts) != 2:
            raise ValueError("Prompt is not formatted correctly.")

        question_block = prompt_parts[0]  # instructions + questions
        context_block = prompt_parts[1]   # full context text

        # Split context into roughly 800-word chunks
        context_words = context_block.split()
        chunks = [
            " ".join(context_words[i:i+max_words_per_chunk])
            for i in range(0, len(context_words), max_words_per_chunk)
        ]

        # Rebuild prompt for each chunk
        self.chunked_prompts = []
        for chunk in chunks:
            new_prompt = f"{question_block}\n\nfrom this context:\n{chunk}"
            self.chunked_prompts.append(new_prompt)

        return self.chunked_prompts


    def print_current_prompt(self):
        ''' This function prints the generated or inputted prompt'''
        print("=======================================================================PRINTING PROMPT======================================================================")
        print(f"\n🧠 Current Prompt:")
        print(f"{self.current_prompt}\n")
        char_length = len(self.current_prompt)
        token_count = len(self.current_prompt.split())
        print("=======================================================================PROMPT COUNTS======================================================================")
        print(f"Length: {char_length} characters, approximately {token_count} tokens")
        print("========================================================================END PRINTING======================================================================")


    def print_chunks(self):
        ''' This function prints each chunked prompt stored in self.chunked_prompts '''
        if not hasattr(self, 'chunked_prompts') or not self.chunked_prompts:
            print("No chunked prompts found. Please run chunk_current_prompt() first.")
            return
        print("=======================================================================PRINTING CHUNKED PROMPTS======================================================================")
        for i, chunk in enumerate(self.chunked_prompts, 1):
            print(f"\n🧠 Prompt Chunk {i}:")
            print(chunk)
            char_length = len(chunk)
            token_count = len(chunk.split())
            print("-----------------------------------------")
            print(f"Length: {char_length} characters, approximately {token_count} tokens")
            print("============================================================================================================================================================")
        print("=======================================================================END OF CHUNKS======================================================================")

# %%
# Playground:
# print(help(list))
testing = Agent2(context_map)
testing.generate_Dataset_prompt(k=5)
testing.print_current_prompt()
testing.chunk_current_prompt(max_words_per_chunk=400)
testing.print_chunks()
# Okay so... this chunking words fine :)
# Out:
# <ipython-input-3-03fcac20fa4f>:5: LangChainDeprecationWarning: The class `HuggingFaceHub` was deprecated in LangChain 0.0.21 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-huggingface package and should be used instead. To use it run `pip install -U :class:`~langchain-huggingface` and import as `from :class:`~langchain_huggingface import HuggingFaceEndpoint``.
#   self.llm = HuggingFaceHub(
# =======================================================================PRINTING PROMPT======================================================================
#
# 🧠 Current Prompt:
# answer these questions:
# Answer as precisely as you can, in as minimum words as you can
# Format your answers with 'A1:', 'A2:', etc. at the beginning of each answer
# Q1: To whom did the Virgin Mary allegedly appear in 1858 in Lourdes France?
# Q2: What is in front of the Notre Dame Main Building?
# Q3: The Basilica of the Sacred heart at Notre Dame is beside to which structure?
# Q4: What is the Grotto at Notre Dame?
# Q5: When did the Scholastic Magazine of Notre dame begin publishing?
# Q6: How often is Notre Dame's the Juggler published?
# Q7: What is the daily student paper at Notre Dame called?
# Q8: How many student news papers are found at Notre Dame?
# Q9: Where is the headquarters of the Congregation of the Holy Cross?
# Q10: What is the primary seminary of the Congregation of the Holy Cross?
# Q11: What is the oldest structure at Notre Dame?
# Q12: What individuals live at Fatima House at Notre Dame?
# Q13: How many BS level degrees are offered in the College of Engineering at Notre Dame?
# Q14: In what year was the College of Engineering at Notre Dame formed?
# Q15: Before the creation of the College of Engineering similar studies were carried out at which Notre Dame college?
# Q16: How many departments are within the Stinson-Remick Hall of Engineering?
# Q17: What entity provides help with the management of time for new students at Notre Dame?
# Q18: How many colleges for undergraduates are at Notre Dame?
# Q19: What was created at Notre Dame in 1962 to assist first year students?
# Q20: Which organization declared the First Year of Studies program at Notre Dame "outstanding?"
#
# from this context:
# Architecturally, the school has a Catholic character. Atop the Main Building's gold dome is a golden statue of the Virgin Mary. Immediately in front of the Main Building and facing it, is a copper statue of Christ with arms upraised with the legend "Venite Ad Me Omnes". Next to the Main Building is the Basilica of the Sacred Heart. Immediately behind the basilica is the Grotto, a Marian place of prayer and reflection. It is a replica of the grotto at Lourdes, France where the Virgin Mary reputedly appeared to Saint Bernadette Soubirous in 1858. At the end of the main drive (and in a direct line that connects through 3 statues and the Gold Dome), is a simple, modern stone statue of Mary.
#
# As at most other universities, Notre Dame's students run a number of news media outlets. The nine student-run outlets include three newspapers, both a radio and television station, and several magazines and journals. Begun as a one-page journal in September 1876, the Scholastic magazine is issued twice monthly and claims to be the oldest continuous collegiate publication in the United States. The other magazine, The Juggler, is released twice a year and focuses on student literature and artwork. The Dome yearbook is published annually. The newspapers have varying publication interests, with The Observer published daily and mainly reporting university and other news, and staffed by students from both Notre Dame and Saint Mary's College. Unlike Scholastic and The Dome, The Observer is an independent publication and does not have a faculty advisor or any editorial oversight from the University. In 1987, when some students believed that The Observer began to show a conservative bias, a liberal newspaper, Common Sense was published. Likewise, in 2003, when other students believed that the paper showed a liberal bias, the conservative paper Irish Rover went into production. Neither paper is published as often as The Observer; however, all three are distributed to all students. Finally, in Spring 2008 an undergraduate journal for political science research, Beyond Politics, made its debut.
#
# The university is the major seat of the Congregation of Holy Cross (albeit not its official headquarters, which are in Rome). Its main seminary, Moreau Seminary, is located on the campus across St. Joseph lake from the Main Building. Old College, the oldest building on campus and located near the shore of St. Mary lake, houses undergraduate seminarians. Retired priests and brothers reside in Fatima House (a former retreat center), Holy Cross House, as well as Columba Hall near the Grotto. The university through the Moreau Seminary has ties to theologian Frederick Buechner. While not Catholic, Buechner has praised writers from Notre Dame and Moreau Seminary created a Buechner Prize for Preaching.
#
# The College of Engineering was established in 1920, however, early courses in civil and mechanical engineering were a part of the College of Science since the 1870s. Today the college, housed in the Fitzpatrick, Cushing, and Stinson-Remick Halls of Engineering, includes five departments of study – aerospace and mechanical engineering, chemical and biomolecular engineering, civil engineering and geological sciences, computer science and engineering, and electrical engineering – with eight B.S. degrees offered. Additionally, the college offers five-year dual degree programs with the Colleges of Arts and Letters and of Business awarding additional B.A. and Master of Business Administration (MBA) degrees, respectively.
#
# All of Notre Dame's undergraduate students are a part of one of the five undergraduate colleges at the school or are in the First Year of Studies program. The First Year of Studies program was established in 1962 to guide incoming freshmen in their first year at the school before they have declared a major. Each student is given an academic advisor from the program who helps them to choose classes that give them exposure to any major in which they are interested. The program also includes a Learning Resource Center which provides time management, collaborative learning, and subject tutoring. This program has been recognized previously, by U.S. News & World Report, as outstanding.
#
# =======================================================================PROMPT COUNTS======================================================================
# Length: 5819 characters, approximately 946 tokens
# ========================================================================END PRINTING======================================================================
# =======================================================================PRINTING CHUNKED PROMPTS======================================================================
#
# 🧠 Prompt Chunk 1:
# answer these questions:
# Answer as precisely as you can, in as minimum words as you can
# Format your answers with 'A1:', 'A2:', etc. at the beginning of each answer
# Q1: To whom did the Virgin Mary allegedly appear in 1858 in Lourdes France?
# Q2: What is in front of the Notre Dame Main Building?
# Q3: The Basilica of the Sacred heart at Notre Dame is beside to which structure?
# Q4: What is the Grotto at Notre Dame?
# Q5: When did the Scholastic Magazine of Notre dame begin publishing?
# Q6: How often is Notre Dame's the Juggler published?
# Q7: What is the daily student paper at Notre Dame called?
# Q8: How many student news papers are found at Notre Dame?
# Q9: Where is the headquarters of the Congregation of the Holy Cross?
# Q10: What is the primary seminary of the Congregation of the Holy Cross?
# Q11: What is the oldest structure at Notre Dame?
# Q12: What individuals live at Fatima House at Notre Dame?
# Q13: How many BS level degrees are offered in the College of Engineering at Notre Dame?
# Q14: In what year was the College of Engineering at Notre Dame formed?
# Q15: Before the creation of the College of Engineering similar studies were carried out at which Notre Dame college?
# Q16: How many departments are within the Stinson-Remick Hall of Engineering?
# Q17: What entity provides help with the management of time for new students at Notre Dame?
# Q18: How many colleges for undergraduates are at Notre Dame?
# Q19: What was created at Notre Dame in 1962 to assist first year students?
# Q20: Which organization declared the First Year of Studies program at Notre Dame "outstanding?"
#
#
# from this context:
# Architecturally, the school has a Catholic character. Atop the Main Building's gold dome is a golden statue of the Virgin Mary. Immediately in front of the Main Building and facing it, is a copper statue of Christ with arms upraised with the legend "Venite Ad Me Omnes". Next to the Main Building is the Basilica of the Sacred Heart. Immediately behind the basilica is the Grotto, a Marian place of prayer and reflection. It is a replica of the grotto at Lourdes, France where the Virgin Mary reputedly appeared to Saint Bernadette Soubirous in 1858. At the end of the main drive (and in a direct line that connects through 3 statues and the Gold Dome), is a simple, modern stone statue of Mary. As at most other universities, Notre Dame's students run a number of news media outlets. The nine student-run outlets include three newspapers, both a radio and television station, and several magazines and journals. Begun as a one-page journal in September 1876, the Scholastic magazine is issued twice monthly and claims to be the oldest continuous collegiate publication in the United States. The other magazine, The Juggler, is released twice a year and focuses on student literature and artwork. The Dome yearbook is published annually. The newspapers have varying publication interests, with The Observer published daily and mainly reporting university and other news, and staffed by students from both Notre Dame and Saint Mary's College. Unlike Scholastic and The Dome, The Observer is an independent publication and does not have a faculty advisor or any editorial oversight from the University. In 1987, when some students believed that The Observer began to show a conservative bias, a liberal newspaper, Common Sense was published. Likewise, in 2003, when other students believed that the paper showed a liberal bias, the conservative paper Irish Rover went into production. Neither paper is published as often as The Observer; however, all three are distributed to all students. Finally, in Spring 2008 an undergraduate journal for political science research, Beyond Politics, made its debut. The university is the major seat of the Congregation of Holy Cross (albeit not its official headquarters, which are in Rome). Its main seminary, Moreau Seminary, is located on the campus across St. Joseph lake from the Main Building. Old College, the oldest building on campus and located near the shore of St. Mary lake, houses undergraduate seminarians. Retired priests
# -----------------------------------------
# Length: 4069 characters, approximately 679 tokens
# ============================================================================================================================================================
#
# 🧠 Prompt Chunk 2:
# answer these questions:
# Answer as precisely as you can, in as minimum words as you can
# Format your answers with 'A1:', 'A2:', etc. at the beginning of each answer
# Q1: To whom did the Virgin Mary allegedly appear in 1858 in Lourdes France?
# Q2: What is in front of the Notre Dame Main Building?
# Q3: The Basilica of the Sacred heart at Notre Dame is beside to which structure?
# Q4: What is the Grotto at Notre Dame?
# Q5: When did the Scholastic Magazine of Notre dame begin publishing?
# Q6: How often is Notre Dame's the Juggler published?
# Q7: What is the daily student paper at Notre Dame called?
# Q8: How many student news papers are found at Notre Dame?
# Q9: Where is the headquarters of the Congregation of the Holy Cross?
# Q10: What is the primary seminary of the Congregation of the Holy Cross?
# Q11: What is the oldest structure at Notre Dame?
# Q12: What individuals live at Fatima House at Notre Dame?
# Q13: How many BS level degrees are offered in the College of Engineering at Notre Dame?
# Q14: In what year was the College of Engineering at Notre Dame formed?
# Q15: Before the creation of the College of Engineering similar studies were carried out at which Notre Dame college?
# Q16: How many departments are within the Stinson-Remick Hall of Engineering?
# Q17: What entity provides help with the management of time for new students at Notre Dame?
# Q18: How many colleges for undergraduates are at Notre Dame?
# Q19: What was created at Notre Dame in 1962 to assist first year students?
# Q20: Which organization declared the First Year of Studies program at Notre Dame "outstanding?"
#
#
# from this context:
# and brothers reside in Fatima House (a former retreat center), Holy Cross House, as well as Columba Hall near the Grotto. The university through the Moreau Seminary has ties to theologian Frederick Buechner. While not Catholic, Buechner has praised writers from Notre Dame and Moreau Seminary created a Buechner Prize for Preaching. The College of Engineering was established in 1920, however, early courses in civil and mechanical engineering were a part of the College of Science since the 1870s. Today the college, housed in the Fitzpatrick, Cushing, and Stinson-Remick Halls of Engineering, includes five departments of study – aerospace and mechanical engineering, chemical and biomolecular engineering, civil engineering and geological sciences, computer science and engineering, and electrical engineering – with eight B.S. degrees offered. Additionally, the college offers five-year dual degree programs with the Colleges of Arts and Letters and of Business awarding additional B.A. and Master of Business Administration (MBA) degrees, respectively. All of Notre Dame's undergraduate students are a part of one of the five undergraduate colleges at the school or are in the First Year of Studies program. The First Year of Studies program was established in 1962 to guide incoming freshmen in their first year at the school before they have declared a major. Each student is given an academic advisor from the program who helps them to choose classes that give them exposure to any major in which they are interested. The program also includes a Learning Resource Center which provides time management, collaborative learning, and subject tutoring. This program has been recognized previously, by U.S. News & World Report, as outstanding.
# -----------------------------------------
# Length: 3342 characters, approximately 546 tokens
# ============================================================================================================================================================
# =======================================================================END OF CHUNKS======================================================================

# %% [markdown]
# ### Next Steps:
#
# okay now that we have written code to chunk the prompt into desired length, now moving onto actually performing some experiments.
#
# In the next codeblock, we will be completing the class

# %%
class Agent2:
    #same context overload notebook
    def __init__(self, context_map, model_name="mistralai/Mistral-7B-Instruct-v0.3", access_token="TOKEN-HERE"):
        self.context_map = context_map
        self.llm = HuggingFaceHub(
            repo_id=model_name,
            model_kwargs={"temperature": 0.3, "max_length": 200},
            huggingfacehub_api_token=access_token
        )
        self.current_prompt = None # NEW: ask user to input context and questions seperately. chunks will only be made of context.
        self.chunked_prompts = []

    def generate_response(self, prompt): #can use this function to get answer from 1 chunk, then 2nd chunk etc, all chunks and then proceed. with normal
        return self.llm(prompt)

    def get_context_questions(self, k=2, q=4):
      #same as context overload notebook
        contexts = []
        questions_answers = []
        selected_contexts = list(self.context_map.items())[:k]
        for context, qa_pairs in selected_contexts:
            contexts.append(context)
            selected_qa = qa_pairs[:q]
            questions_answers.append(selected_qa)
        return contexts, questions_answers

    def generate_Dataset_prompt(self, k=2, q=4):
        ''' This function generates and imitates a prompt from the dataset, later on, we will take questions and context as input from user.'''
        contexts, questions_answers_by_context = self.get_context_questions(k, q)
        combined_context = "\n\n".join(contexts)
        all_questions_answers = []
        for qa_pairs in questions_answers_by_context:
            all_questions_answers.extend(qa_pairs)
        # modified the prompt
        prompt_lines = [
            "Answer these questions as precisely as you can, in as minimum words as you can",
            "Format your answers with 'A1:', 'A2:', etc. at the beginning of each answer",
            "If you cannot find enough information in the provided context to answer a question, respond with 'Not specified'. Do NOT guess.",
        ]
        for i, (question, _) in enumerate(all_questions_answers, 1):
            prompt_lines.append(f"Q{i}: {question}")
        prompt_lines.append("\nfrom this context:")
        prompt_lines.append(combined_context)
        prompt = "\n".join(prompt_lines)
        self.current_prompt = prompt
        char_length = len(prompt)
        token_count = len(prompt.split())
        # print(f"\n🧠 Combined Prompt:")
        # print(f"Length: {char_length} characters, approximately {token_count} tokens")
        # print(f"{prompt}\n")


    def chunk_current_prompt(self, max_words_per_chunk=800):
        """
        Splits the context into ~800-word chunks and constructs prompts accordingly.
        Stores the chunked prompts in self.chunked_prompts.
        """
        if not hasattr(self, 'current_prompt') or self.current_prompt is None:
            raise ValueError("current_prompt not set. Please run generate_Dataset_prompt first.")

        # Split current prompt into parts
        prompt_parts = self.current_prompt.split("\nfrom this context:\n")
        if len(prompt_parts) != 2:
            raise ValueError("Prompt is not formatted correctly.")

        question_block = prompt_parts[0]  # instructions + questions
        context_block = prompt_parts[1]   # full context text

        # Split context into roughly 800-word chunks
        context_words = context_block.split()
        chunks = [
            " ".join(context_words[i:i+max_words_per_chunk])
            for i in range(0, len(context_words), max_words_per_chunk)
        ]

        # Rebuild prompt for each chunk
        self.chunked_prompts = []
        for chunk in chunks:
            new_prompt = f"{question_block}\n\nfrom this context:\n{chunk}"
            self.chunked_prompts.append(new_prompt)

        return self.chunked_prompts


    def run_all_chunks(self, verbose=True):
        """
        Calls the LLM for each chunked prompt and prints the responses.

        Args:
            verbose (bool): If True, prints each response.

        Returns:
            List of responses from the model for each chunked prompt.
        """
        if not self.chunked_prompts:
            raise ValueError("chunked_prompts not set. Please run chunk_current_prompt first.")

        self.responses = []
        for idx, prompt in enumerate(self.chunked_prompts, 1):
            response = self.generate_response(prompt)
            self.responses.append(response)
            if verbose:
                print(f"\n--- Response for Chunk {idx} ---\n")
                print(response)
                print("\n-------------------------------\n")
        return self.responses


    def print_current_prompt(self):
        ''' This function prints the generated or inputted prompt'''
        print("=======================================================================PRINTING PROMPT======================================================================")
        print(f"\n🧠 Current Prompt:")
        print(f"{self.current_prompt}\n")
        char_length = len(self.current_prompt)
        token_count = len(self.current_prompt.split())
        print("=======================================================================PROMPT COUNTS======================================================================")
        print(f"Length: {char_length} characters, approximately {token_count} tokens")
        print("========================================================================END PRINTING======================================================================")


    def print_chunks(self):
        ''' This function prints each chunked prompt stored in self.chunked_prompts '''
        if not hasattr(self, 'chunked_prompts') or not self.chunked_prompts:
            print("No chunked prompts found. Please run chunk_current_prompt() first.")
            return
        print("=======================================================================PRINTING CHUNKED PROMPTS======================================================================")
        for i, chunk in enumerate(self.chunked_prompts, 1):
            print(f"\n🧠 Prompt Chunk {i}:")
            print(chunk)
            char_length = len(chunk)
            token_count = len(chunk.split())
            print("-----------------------------------------")
            print(f"Length: {char_length} characters, approximately {token_count} tokens")
            print("============================================================================================================================================================")
        print("=======================================================================END OF CHUNKS======================================================================")

# %%
#Playground:
# agent = Agent2(context_map)
# agent.generate_Dataset_prompt(k=5)
# agent.chunk_current_prompt(max_words_per_chunk=200)
# agent.run_all_chunks()

# conclusion: This approach doesnt work with this specific llm as it is probably instruct tuned to not answer from the chunk.
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_deprecation.py:131: FutureWarning: 'post' (from 'huggingface_hub.inference._client') is deprecated and will be removed from version '0.31.0'. Making direct POST requests to the inference server is not supported anymore. Please use task methods instead (e.g. `InferenceClient.chat_completion`). If your use case is not supported, please open an issue in https://github.com/huggingface/huggingface_hub.
#   warnings.warn(warning_message, FutureWarning)
# --- Response for Chunk 1 ---
#
# Answer these questions as precisely as you can, in as minimum words as you can
# Format your answers with 'A1:', 'A2:', etc. at the beginning of each answer
# If you cannot find enough information in the provided context to answer a question, respond with 'Not specified'. Do NOT guess.
# Q1: To whom did the Virgin Mary allegedly appear in 1858 in Lourdes France?
# Q2: What is in front of the Notre Dame Main Building?
# Q3: The Basilica of the Sacred heart at Notre Dame is beside to which structure?
# Q4: What is the Grotto at Notre Dame?
# Q5: When did the Scholastic Magazine of Notre dame begin publishing?
# Q6: How often is Notre Dame's the Juggler published?
# Q7: What is the daily student paper at Notre Dame called?
# Q8: How many student news papers are found at Notre Dame?
# Q9: Where is the headquarters of the Congregation of the Holy Cross?
# Q10: What is the primary seminary of the Congregation of the Holy Cross?
# Q11: What is the oldest structure at Notre Dame?
# Q12: What individuals live at Fatima House at Notre Dame?
# Q13: How many BS level degrees are offered in the College of Engineering at Notre Dame?
# Q14: In what year was the College of Engineering at Notre Dame formed?
# Q15: Before the creation of the College of Engineering similar studies were carried out at which Notre Dame college?
# Q16: How many departments are within the Stinson-Remick Hall of Engineering?
# Q17: What entity provides help with the management of time for new students at Notre Dame?
# Q18: How many colleges for undergraduates are at Notre Dame?
# Q19: What was created at Notre Dame in 1962 to assist first year students?
# Q20: Which organization declared the First Year of Studies program at Notre Dame "outstanding?"
#
#
# from this context:
# Architecturally, the school has a Catholic character. Atop the Main Building's gold dome is a golden statue of the Virgin Mary. Immediately in front of the Main Building and facing it, is a copper statue of Christ with arms upraised with the legend "Venite Ad Me Omnes". Next to the Main Building is the Basilica of the Sacred Heart. Immediately behind the basilica is the Grotto, a Marian place of prayer and reflection. It is a replica of the grotto at Lourdes, France where the Virgin Mary reputedly appeared to Saint Bernadette Soubirous in 1858. At the end of the main drive (and in a direct line that connects through 3 statues and the Gold Dome), is a simple, modern stone statue of Mary. As at most other universities, Notre Dame's students run a number of news media outlets. The nine student-run outlets include three newspapers, both a radio and television station, and several magazines and journals. Begun as a one-page journal in September 1876, the Scholastic magazine is issued twice monthly and claims to be the oldest continuous collegiate publication in the United States. The other magazine, The Juggler, is released twice a year and focuses on student literature. The daily student paper is called The Observer, and it is the oldest daily student newspaper in the country.
#
# A1: The Virgin Mary allegedly appeared to Bernadette Soubirous in 1858 in Lourdes, France.
# A2: A copper statue of Christ with arms upraised with the legend "Venite Ad Me Omnes" is in front of the Main Building.
# A3: The Basilica of the Sacred Heart is beside the Main Building.
# A4: The Grotto at Notre Dame is a Marian place of prayer and reflection, a replica of the grotto at Lourdes, France.
# A5: The Scholastic Magazine of Notre Dame began publishing in September 1876.
# A6: The Juggler is published twice a year.
# A7: The daily student paper at Notre Dame is called The Observer.
# A8: There are three newspapers at Notre Dame.
# A9: The headquarters of the Congregation of the Holy Cross is Not specified.
# A10: The primary seminary of the Congregation of the Holy Cross is Notre Dame Seminary in New Orleans, Louisiana.
# A11: The oldest structure at Notre Dame is Not specified.
# A12: The individuals who live at Fatima House at Notre Dame are Not specified.
# A13: The number of BS level degrees offered in the College of Engineering at Notre Dame is Not specified.
# A14: The College of Engineering at Notre Dame was formed in 1892.
# A15: Similar studies were carried out at the College of Arts and Letters before the creation of the College of Engineering.
# A16: There are 13 departments within the Stinson-Remick Hall of Engineering.
# A17: The entity that provides help with the management of time for new students at Notre Dame is the First Year of Studies program.
# A18: There are 4 colleges for undergraduates at Notre Dame.
# A19: The First Year of Studies program was created at Notre Dame in 1962 to assist first year students.
# A20: The First Year of Studies program at Notre Dame was declared "outstanding" by the American Council on Education.
#
# -------------------------------
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_deprecation.py:131: FutureWarning: 'post' (from 'huggingface_hub.inference._client') is deprecated and will be removed from version '0.31.0'. Making direct POST requests to the inference server is not supported anymore. Please use task methods instead (e.g. `InferenceClient.chat_completion`). If your use case is not supported, please open an issue in https://github.com/huggingface/huggingface_hub.
#   warnings.warn(warning_message, FutureWarning)
# --- Response for Chunk 2 ---
#
# Answer these questions as precisely as you can, in as minimum words as you can
# Format your answers with 'A1:', 'A2:', etc. at the beginning of each answer
# If you cannot find enough information in the provided context to answer a question, respond with 'Not specified'. Do NOT guess.
# Q1: To whom did the Virgin Mary allegedly appear in 1858 in Lourdes France?
# Q2: What is in front of the Notre Dame Main Building?
# Q3: The Basilica of the Sacred heart at Notre Dame is beside to which structure?
# Q4: What is the Grotto at Notre Dame?
# Q5: When did the Scholastic Magazine of Notre dame begin publishing?
# Q6: How often is Notre Dame's the Juggler published?
# Q7: What is the daily student paper at Notre Dame called?
# Q8: How many student news papers are found at Notre Dame?
# Q9: Where is the headquarters of the Congregation of the Holy Cross?
# Q10: What is the primary seminary of the Congregation of the Holy Cross?
# Q11: What is the oldest structure at Notre Dame?
# Q12: What individuals live at Fatima House at Notre Dame?
# Q13: How many BS level degrees are offered in the College of Engineering at Notre Dame?
# Q14: In what year was the College of Engineering at Notre Dame formed?
# Q15: Before the creation of the College of Engineering similar studies were carried out at which Notre Dame college?
# Q16: How many departments are within the Stinson-Remick Hall of Engineering?
# Q17: What entity provides help with the management of time for new students at Notre Dame?
# Q18: How many colleges for undergraduates are at Notre Dame?
# Q19: What was created at Notre Dame in 1962 to assist first year students?
# Q20: Which organization declared the First Year of Studies program at Notre Dame "outstanding?"
#
#
# from this context:
# and artwork. The Dome yearbook is published annually. The newspapers have varying publication interests, with The Observer published daily and mainly reporting university and other news, and staffed by students from both Notre Dame and Saint Mary's College. Unlike Scholastic and The Dome, The Observer is an independent publication and does not have a faculty advisor or any editorial oversight from the University. In 1987, when some students believed that The Observer began to show a conservative bias, a liberal newspaper, Common Sense was published. Likewise, in 2003, when other students believed that the paper showed a liberal bias, the conservative paper Irish Rover went into production. Neither paper is published as often as The Observer; however, all three are distributed to all students. Finally, in Spring 2008 an undergraduate journal for political science research, Beyond Politics, made its debut. The university is the major seat of the Congregation of Holy Cross (albeit not its official headquarters, which are in Rome). Its main seminary, Moreau Seminary, is located on the campus across St. Joseph lake from the Main Building. Old College, the oldest building on campus and located near the shore of St. Mary lake, houses undergraduate seminarians. Retired priests live at Fatima House. The College of Engineering was established in 1892, and the College of Science in 1894. The College of Arts and Letters was established in 1919. The College of Engineering offers 14 BS level degrees. The College of Science offers 22 BS level degrees. The College of Arts and Letters offers 35 BS level degrees. The College of Engineering was originally housed in the Main Building, but in 1952 it was moved to the Stinson-Remick Hall of Engineering. The College of Science was originally housed in the Main Building, but in 1960 it was moved to the Main Building's basement. The College of Arts and Letters was originally housed in the Main Building, but in 1962 it was moved to the Main Building's basement and the new building, Jenkins Hall, was built. The First Year of Studies program was created in 1962 to assist first-year students. In 1962, the First Year of Studies program was declared "outstanding" by the National Association of Student Personnel Administrators.
#
# A1: The Virgin Mary allegedly appeared to Bernadette Soubirous in 1858 in Lourdes, France.
# A2: The Notre Dame Main Building is in front of a large open space.
# A3: The Basilica of the Sacred Heart at Notre Dame is beside the Main Building.
# A4: The Grotto at Notre Dame is a small cave-like structure on the campus, modeled after the one in Lourdes, France.
# A5: The Scholastic Magazine of Notre Dame began publishing in Not specified.
# A6: The Notre Dame's the Juggler is published Not specified.
# A7: The daily student paper at Notre Dame is called The Observer.
# A8: There are three student news papers found at Notre Dame.
# A9: The headquarters of the Congregation of the Holy Cross is in Rome.
# A10: The primary seminary of the Congregation of the Holy Cross is Moreau Seminary.
# A11: The oldest structure at Notre Dame is Old College.
# A12: Individuals who live at Fatima House at Notre Dame are retired priests.
# A13: The College of Engineering at Notre Dame offers 14 BS level degrees.
# A14: The College of Engineering at Notre Dame was formed in 1892.
# A15: Before the creation of the College of Engineering, similar studies were carried out at the College of Arts and Sciences.
# A16: There are Not specified departments within the Stinson-Remick Hall of Engineering.
# A17: The entity that provides help with the management of time for new students at Notre Dame is the First Year of Studies program.
# A18: There are 3 colleges for undergraduates at Notre Dame.
# A19: The First Year of Studies program was created at Notre Dame in 1962 to assist first-year students.
# A20: The First Year of Studies program at Notre Dame was declared "outstanding" by the National Association of Student Personnel Administrators in 1962.
#
# -------------------------------
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_deprecation.py:131: FutureWarning: 'post' (from 'huggingface_hub.inference._client') is deprecated and will be removed from version '0.31.0'. Making direct POST requests to the inference server is not supported anymore. Please use task methods instead (e.g. `InferenceClient.chat_completion`). If your use case is not supported, please open an issue in https://github.com/huggingface/huggingface_hub.
#   warnings.warn(warning_message, FutureWarning)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-15-bccfc65497d9> in <cell line: 0>()
#       3 agent.generate_Dataset_prompt(k=5)
#       4 agent.chunk_current_prompt(max_words_per_chunk=200)
# ----> 5 agent.run_all_chunks()
#
# <ipython-input-14-45ae42f6bc34> in run_all_chunks(self, verbose)
#      98         self.responses = []
#      99         for idx, prompt in enumerate(self.chunked_prompts, 1):
# --> 100             response = self.generate_response(prompt)
#     101             self.responses.append(response)
#     102             if verbose:
#
# <ipython-input-14-45ae42f6bc34> in generate_response(self, prompt)
#      12
#      13     def generate_response(self, prompt): #can use this function to get answer from 1 chunk, then 2nd chunk etc, all chunks and then proceed. with normal
# ---> 14         return self.llm(prompt)
#      15
#      16     def get_context_questions(self, k=2, q=4):
#
# /usr/local/lib/python3.11/dist-packages/langchain_core/_api/deprecation.py in warning_emitting_wrapper(*args, **kwargs)
#     189                 warned = True
#     190                 emit_warning()
# --> 191             return wrapped(*args, **kwargs)
#     192
#     193         async def awarning_emitting_wrapper(*args: Any, **kwargs: Any) -> Any:
#
# /usr/local/lib/python3.11/dist-packages/langchain_core/language_models/llms.py in __call__(self, prompt, stop, callbacks, tags, metadata, **kwargs)
#    1313             raise ValueError(msg)  # noqa: TRY004
#    1314         return (
# -> 1315             self.generate(
#    1316                 [prompt],
#    1317                 stop=stop,
#
# /usr/local/lib/python3.11/dist-packages/langchain_core/language_models/llms.py in generate(self, prompts, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     969                 )
#     970             ]
# --> 971             return self._generate_helper(
#     972                 prompts,
#     973                 stop,
#
# /usr/local/lib/python3.11/dist-packages/langchain_core/language_models/llms.py in _generate_helper(self, prompts, stop, run_managers, new_arg_supported, **kwargs)
#     788         try:
#     789             output = (
# --> 790                 self._generate(
#     791                     prompts,
#     792                     stop=stop,
#
# /usr/local/lib/python3.11/dist-packages/langchain_core/language_models/llms.py in _generate(self, prompts, stop, run_manager, **kwargs)
#    1543         for prompt in prompts:
#    1544             text = (
# -> 1545                 self._call(prompt, stop=stop, run_manager=run_manager, **kwargs)
#    1546                 if new_arg_supported
#    1547                 else self._call(prompt, stop=stop, **kwargs)
#
# /usr/local/lib/python3.11/dist-packages/langchain_community/llms/huggingface_hub.py in _call(self, prompt, stop, run_manager, **kwargs)
#     136         parameters = {**_model_kwargs, **kwargs}
#     137
# --> 138         response = self.client.post(
#     139             json={"inputs": prompt, "parameters": parameters}, task=self.task
#     140         )
#
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_deprecation.py in inner_f(*args, **kwargs)
#     130                 warning_message += " " + message
#     131             warnings.warn(warning_message, FutureWarning)
# --> 132             return f(*args, **kwargs)
#     133
#     134         return inner_f
#
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/inference/_client.py in post(self, json, data, model, task, stream)
#     303         url = provider_helper._prepare_url(self.token, mapped_model)  # type: ignore[arg-type]
#     304         headers = provider_helper._prepare_headers(self.headers, self.token)  # type: ignore[arg-type]
# --> 305         return self._inner_post(
#     306             request_parameters=RequestParameters(
#     307                 url=url,
#
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/inference/_client.py in _inner_post(self, request_parameters, stream)
#     340         with _open_as_binary(request_parameters.data) as data_as_binary:
#     341             try:
# --> 342                 response = get_session().post(
#     343                     request_parameters.url,
#     344                     json=request_parameters.json,
#
# /usr/local/lib/python3.11/dist-packages/requests/sessions.py in post(self, url, data, json, **kwargs)
#     635         """
#     636
# --> 637         return self.request("POST", url, data=data, json=json, **kwargs)
#     638
#     639     def put(self, url, data=None, **kwargs):
#
# /usr/local/lib/python3.11/dist-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     587         }
#     588         send_kwargs.update(settings)
# --> 589         resp = self.send(prep, **send_kwargs)
#     590
#     591         return resp
#
# /usr/local/lib/python3.11/dist-packages/requests/sessions.py in send(self, request, **kwargs)
#     701
#     702         # Send the request
# --> 703         r = adapter.send(request, **kwargs)
#     704
#     705         # Total elapsed time of the request (approximately)
#
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_http.py in send(self, request, *args, **kwargs)
#      94             logger.debug(f"Send: {_curlify(request)}")
#      95         try:
# ---> 96             return super().send(request, *args, **kwargs)
#      97         except requests.RequestException as e:
#      98             request_id = request.headers.get(X_AMZN_TRACE_ID)
#
# /usr/local/lib/python3.11/dist-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     665
#     666         try:
# --> 667             resp = conn.urlopen(
#     668                 method=request.method,
#     669                 url=url,
#
# /usr/local/lib/python3.11/dist-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     785
#     786             # Make the request on the HTTPConnection object
# --> 787             response = self._make_request(
#     788                 conn,
#     789                 method,
#
# /usr/local/lib/python3.11/dist-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     532         # Receive the response from the server
#     533         try:
# --> 534             response = conn.getresponse()
#     535         except (BaseSSLError, OSError) as e:
#     536             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# /usr/local/lib/python3.11/dist-packages/urllib3/connection.py in getresponse(self)
#     514
#     515         # Get the response from http.client.HTTPConnection
# --> 516         httplib_response = super().getresponse()
#     517
#     518         try:
#
# /usr/lib/python3.11/http/client.py in getresponse(self)
#    1393         try:
#    1394             try:
# -> 1395                 response.begin()
#    1396             except ConnectionError:
#    1397                 self.close()
#
# /usr/lib/python3.11/http/client.py in begin(self)
#     323         # read until we get a non-100 response
#     324         while True:
# --> 325             version, status, reason = self._read_status()
#     326             if status != CONTINUE:
#     327                 break
#
# /usr/lib/python3.11/http/client.py in _read_status(self)
#     284
#     285     def _read_status(self):
# --> 286         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     287         if len(line) > _MAXLINE:
#     288             raise LineTooLong("status line")
#
# /usr/lib/python3.11/socket.py in readinto(self, b)
#     716         while True:
#     717             try:
# --> 718                 return self._sock.recv_into(b)
#     719             except timeout:
#     720                 self._timeout_occurred = True
#
# /usr/lib/python3.11/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1312                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1313                   self.__class__)
# -> 1314             return self.read(nbytes, buffer)
#    1315         else:
#    1316             return super().recv_into(buffer, nbytes, flags)
#
# /usr/lib/python3.11/ssl.py in read(self, len, buffer)
#    1164         try:
#    1165             if buffer is not None:
# -> 1166                 return self._sslobj.read(len, buffer)
#    1167             else:
#    1168                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %% [markdown]
# ## Approach 2:
#
# so initially i was thinking of post processing the answers from llms to guege whether the answers are actually from the context or not, but this approach wont work as llm do answer something from whatever little context is provided to them.
#
# for example, both of the answer 20s:
#
# A20: The First Year of Studies program at Notre Dame was recognized as outstanding by U.S. News & World Report.
#
# A20: The First Year of Studies program at Notre Dame was declared "outstanding" by the American Council on Education.
#
# are correct, given their own contexts.
#
# So, for the updated approach, instead of post processing, we will try and do pre-processing and sort of based on keywords, assign the questions to their relevant chunks. and then call llms. will need to restructure some code as well.
#
# And this simple keyword matching approach seems to be working a bit too fine, yes we could take this further and use tf-idf or cosine similarity between embedding etc, but lets just leave it for future works.

# %%
import re
from collections import defaultdict
from typing import List, Tuple


class Agent2:
    #same context overload notebook
    def __init__(self, context_map, model_name="mistralai/Mistral-7B-Instruct-v0.3", access_token="TOKEN-HERE"):
        self.context_map = context_map
        self.llm = HuggingFaceHub(
            repo_id=model_name,
            model_kwargs={"temperature": 0.3, "max_length": 200},
            huggingfacehub_api_token=access_token
        )
        self.current_prompt = None # NEW: ask user to input context and questions seperately. chunks will only be made of context.
        self.chunked_prompts = []
        self.chunk_responses = []
        # new variables for storing questions, chunks and gold answers respectively.
        self.current_context_chunks = []
        self.current_questions = []
        self.current_gold_answers = []
        # this is for chunk assignment to each question
        self.chunk_assignments = defaultdict(list)

    def generate_response(self, prompt): #can use this function to get answer from 1 chunk, then 2nd chunk etc, all chunks and then proceed. with normal
        return self.llm(prompt)

    def get_context_questions(self, k=2, q=4):
      #same as context overload notebook
        contexts = []
        questions_answers = []
        selected_contexts = list(self.context_map.items())[:k]
        for context, qa_pairs in selected_contexts:
            contexts.append(context)
            selected_qa = qa_pairs[:q]
            questions_answers.append(selected_qa)
        return contexts, questions_answers

    def generate_Dataset_prompt(self, k=2, q=4):
        ''' This function generates and imitates a prompt from the dataset, later on, we will take questions and context as input from user.'''
        contexts, questions_answers_by_context = self.get_context_questions(k, q)
        combined_context = "\n\n".join(contexts)
        all_questions_answers = []
        for qa_pairs in questions_answers_by_context:
            all_questions_answers.extend(qa_pairs)
        # modified the prompt
        prompt_lines = [
            "Answer these questions as precisely as you can, in as minimum words as you can",
            "Format your answers with 'A1:', 'A2:', etc. at the beginning of each answer",
            "If you cannot find enough information in the provided context to answer a question, respond with 'Not specified'. Do NOT guess.",
        ]
        self.current_questions = []
        self.current_gold_answers = []
        for i, (question, answer) in enumerate(all_questions_answers, 1):
            self.current_questions.append(question)
            self.current_gold_answers.append(answer)
            prompt_lines.append(f"Q{i}: {question}")
        prompt_lines.append("\nfrom this context:")
        prompt_lines.append(combined_context)
        prompt = "\n".join(prompt_lines)
        self.current_prompt = prompt
        char_length = len(prompt)
        token_count = len(prompt.split())
        # print(f"\n🧠 Combined Prompt:")
        # print(f"Length: {char_length} characters, approximately {token_count} tokens")
        # print(f"{prompt}\n")


    def extract_keywords(self, questions: List[str]) -> List[List[str]]:
        """
        Given a list of questions, extract a list of keywords for each question.
        """
        # Common stopwords you might want to ignore
        stopwords = set([
            "the", "is", "at", "which", "on", "in", "a", "an", "of", "to", "for", "with",
            "and", "by", "from", "what", "who", "when", "where", "how", "does", "do",
            "did", "was", "were", "has", "have", "had"
        ])

        all_keywords = []

        for question in questions:
            # Remove punctuation
            question_clean = re.sub(r'[^\w\s]', '', question)
            words = question_clean.lower().split()
            # Filter stopwords and small words
            keywords = [word for word in words if word not in stopwords and len(word) > 2]
            all_keywords.append(keywords)

        return all_keywords

    def map_questions_to_chunks(self) -> List[Tuple[str, List[str]]]:
        """
        Map each context chunk to the most probable questions based on keyword matching.
        Returns a list of (context_chunk, assigned_questions) pairs.
        """
        if not self.current_context_chunks:
            raise ValueError("No context chunks available. Please run chunk_current_prompt first.")
        if not self.current_questions:
            raise ValueError("No questions available. Please populate current_questions first.")

        keywords_per_question = self.extract_keywords(self.current_questions)
        print(f"keywords per question: ", keywords_per_question) #so it returns a list of lists, the list has keywords of each question
        self.chunk_assignments = defaultdict(list)

        # Pre-lowercase context chunks
        lowered_chunks = [chunk.lower() for chunk in self.current_context_chunks]

        for q_idx, keywords in enumerate(keywords_per_question):
            question = self.current_questions[q_idx]
            best_chunk_idx = None
            best_match_count = 0

            # Check each chunk
            for idx, chunk in enumerate(lowered_chunks):
                match_count = sum(1 for keyword in keywords if keyword in chunk)

                if match_count > best_match_count:
                    best_match_count = match_count
                    best_chunk_idx = idx

            if best_chunk_idx is not None and best_match_count > 0:
                self.chunk_assignments[best_chunk_idx].append(question)

        # Build final result
        print(f"chunk assignments: ", self.chunk_assignments)
        result = []
        for idx, questions in self.chunk_assignments.items():
            result.append((self.current_context_chunks[idx], questions))

        return result

    def chunk_current_prompt(self, max_words_per_chunk=800):
        """
        Splits the context into ~800-word chunks and constructs prompts accordingly.
        Stores the chunked prompts in self.chunked_prompts.
        """
        if not hasattr(self, 'current_prompt') or self.current_prompt is None:
            raise ValueError("current_prompt not set. Please run generate_Dataset_prompt first.")

        # Split current prompt into parts
        prompt_parts = self.current_prompt.split("\nfrom this context:\n")
        if len(prompt_parts) != 2:
            raise ValueError("Prompt is not formatted correctly.")

        question_block = prompt_parts[0]  # instructions + questions
        context_block = prompt_parts[1]   # full context text

        # Split context into roughly 800-word chunks
        context_words = context_block.split()
        chunks = [
            " ".join(context_words[i:i+max_words_per_chunk])
            for i in range(0, len(context_words), max_words_per_chunk)
        ]

        # Rebuild prompt for each chunk
        self.chunked_prompts = []
        self.current_context_chunks = []
        for chunk in chunks:
            self.current_context_chunks.append(chunk)
            new_prompt = f"{question_block}\n\nfrom this context:\n{chunk}"
            self.chunked_prompts.append(new_prompt)

        return self.chunked_prompts

    def construct_individual_prompts_from_assignments(self):
        """
        Constructs individual prompts by pairing assigned questions with their corresponding context chunks.
        Formats the prompt according to specified rules: minimal word answers, labeled Q1, Q2..., and specific handling for unknowns.
        Stores results in self.individual_prompts as a list of prompt strings.
        """
        if not hasattr(self, 'chunk_assignments') or not self.chunk_assignments:
            raise ValueError("chunk_assignments not set. Please run map_questions_to_chunks first.")

        if not hasattr(self, 'current_context_chunks') or not self.current_context_chunks:
            raise ValueError("No context chunks available.")

        self.individual_prompts = []

        for idx, questions in self.chunk_assignments.items():
            chunk = self.current_context_chunks[idx]
            # Add Q1, Q2... prefix
            formatted_questions = [f"Q{i + 1}: {q}" for i, q in enumerate(questions)]
            question_block = "\n".join(formatted_questions)

            prompt = (
                "Answer these questions as precisely as you can, in as minimum words as you can\n"
                "Format your answers with 'A1:', 'A2:', etc. at the beginning of each answer\n"
                "If you cannot find enough information in the provided context to answer a question, respond with 'Not specified'. Do NOT guess.\n"
                f"{question_block}\n\nfrom this context:\n{chunk}"
            )
            self.individual_prompts.append(prompt)
        self.chunked_prompts = self.individual_prompts
        return self.individual_prompts


    def run_all_chunks(self, verbose=True):
        """
        Calls the LLM for each chunked prompt and prints the responses.

        Args:
            verbose (bool): If True, prints each response.

        Returns:
            List of responses from the model for each chunked prompt.
        """
        if not self.chunked_prompts:
            raise ValueError("chunked_prompts not set. Please run chunk_current_prompt first.")

        self.chunk_responses = []
        for idx, prompt in enumerate(self.chunked_prompts, 1):
            response = self.generate_response(prompt)
            self.chunk_responses.append(response)
            if verbose:
                print(f"\n--- Response for Chunk {idx} ---\n")
                print(response)
                print("\n-------------------------------\n")
        return self.chunk_responses


    def print_current_prompt(self):
        ''' This function prints the generated or inputted prompt'''
        print("=======================================================================PRINTING PROMPT======================================================================")
        print(f"\n🧠 Current Prompt:")
        print(f"{self.current_prompt}\n")
        char_length = len(self.current_prompt)
        token_count = len(self.current_prompt.split())
        print("=======================================================================PROMPT COUNTS======================================================================")
        print(f"Length: {char_length} characters, approximately {token_count} tokens")
        print("========================================================================END PRINTING======================================================================")


    def print_chunks(self):
        ''' This function prints each chunked prompt stored in self.chunked_prompts '''
        if not hasattr(self, 'chunked_prompts') or not self.chunked_prompts:
            print("No chunked prompts found. Please run chunk_current_prompt() first.")
            return
        print("=======================================================================PRINTING CHUNKED PROMPTS======================================================================")
        for i, chunk in enumerate(self.chunked_prompts, 1):
            print(f"\n🧠 Prompt Chunk {i}:")
            print(chunk)
            char_length = len(chunk)
            token_count = len(chunk.split())
            print("-----------------------------------------")
            print(f"Length: {char_length} characters, approximately {token_count} tokens")
            print("============================================================================================================================================================")
        print("=======================================================================END OF CHUNKS======================================================================")

# %%
#Playground:
agent = Agent2(context_map)
agent.generate_Dataset_prompt(k=5)
agent.print_current_prompt()
agent.chunk_current_prompt(max_words_per_chunk=400)
assignments = agent.map_questions_to_chunks()
# # Print or use assignments
# for chunk, assigned_questions in assignments:
#     print("Context Preview:", chunk)
#     print("Questions:")
#     for q in assigned_questions:
#         print("-", q)
#     print("\n")

individual_prompts = agent.construct_individual_prompts_from_assignments()

# You can now loop over the prompts and feed them to your LLM:
for prompt in individual_prompts:
    print("=== Prompt ===")
    print(prompt)
    print("==============\n")

# agent.run_all_chunks()
# Out:
# =======================================================================PRINTING PROMPT======================================================================
#
# 🧠 Current Prompt:
# Answer these questions as precisely as you can, in as minimum words as you can
# Format your answers with 'A1:', 'A2:', etc. at the beginning of each answer
# If you cannot find enough information in the provided context to answer a question, respond with 'Not specified'. Do NOT guess.
# Q1: To whom did the Virgin Mary allegedly appear in 1858 in Lourdes France?
# Q2: What is in front of the Notre Dame Main Building?
# Q3: The Basilica of the Sacred heart at Notre Dame is beside to which structure?
# Q4: What is the Grotto at Notre Dame?
# Q5: When did the Scholastic Magazine of Notre dame begin publishing?
# Q6: How often is Notre Dame's the Juggler published?
# Q7: What is the daily student paper at Notre Dame called?
# Q8: How many student news papers are found at Notre Dame?
# Q9: Where is the headquarters of the Congregation of the Holy Cross?
# Q10: What is the primary seminary of the Congregation of the Holy Cross?
# Q11: What is the oldest structure at Notre Dame?
# Q12: What individuals live at Fatima House at Notre Dame?
# Q13: How many BS level degrees are offered in the College of Engineering at Notre Dame?
# Q14: In what year was the College of Engineering at Notre Dame formed?
# Q15: Before the creation of the College of Engineering similar studies were carried out at which Notre Dame college?
# Q16: How many departments are within the Stinson-Remick Hall of Engineering?
# Q17: What entity provides help with the management of time for new students at Notre Dame?
# Q18: How many colleges for undergraduates are at Notre Dame?
# Q19: What was created at Notre Dame in 1962 to assist first year students?
# Q20: Which organization declared the First Year of Studies program at Notre Dame "outstanding?"
#
# from this context:
# Architecturally, the school has a Catholic character. Atop the Main Building's gold dome is a golden statue of the Virgin Mary. Immediately in front of the Main Building and facing it, is a copper statue of Christ with arms upraised with the legend "Venite Ad Me Omnes". Next to the Main Building is the Basilica of the Sacred Heart. Immediately behind the basilica is the Grotto, a Marian place of prayer and reflection. It is a replica of the grotto at Lourdes, France where the Virgin Mary reputedly appeared to Saint Bernadette Soubirous in 1858. At the end of the main drive (and in a direct line that connects through 3 statues and the Gold Dome), is a simple, modern stone statue of Mary.
#
# As at most other universities, Notre Dame's students run a number of news media outlets. The nine student-run outlets include three newspapers, both a radio and television station, and several magazines and journals. Begun as a one-page journal in September 1876, the Scholastic magazine is issued twice monthly and claims to be the oldest continuous collegiate publication in the United States. The other magazine, The Juggler, is released twice a year and focuses on student literature and artwork. The Dome yearbook is published annually. The newspapers have varying publication interests, with The Observer published daily and mainly reporting university and other news, and staffed by students from both Notre Dame and Saint Mary's College. Unlike Scholastic and The Dome, The Observer is an independent publication and does not have a faculty advisor or any editorial oversight from the University. In 1987, when some students believed that The Observer began to show a conservative bias, a liberal newspaper, Common Sense was published. Likewise, in 2003, when other students believed that the paper showed a liberal bias, the conservative paper Irish Rover went into production. Neither paper is published as often as The Observer; however, all three are distributed to all students. Finally, in Spring 2008 an undergraduate journal for political science research, Beyond Politics, made its debut.
#
# The university is the major seat of the Congregation of Holy Cross (albeit not its official headquarters, which are in Rome). Its main seminary, Moreau Seminary, is located on the campus across St. Joseph lake from the Main Building. Old College, the oldest building on campus and located near the shore of St. Mary lake, houses undergraduate seminarians. Retired priests and brothers reside in Fatima House (a former retreat center), Holy Cross House, as well as Columba Hall near the Grotto. The university through the Moreau Seminary has ties to theologian Frederick Buechner. While not Catholic, Buechner has praised writers from Notre Dame and Moreau Seminary created a Buechner Prize for Preaching.
#
# The College of Engineering was established in 1920, however, early courses in civil and mechanical engineering were a part of the College of Science since the 1870s. Today the college, housed in the Fitzpatrick, Cushing, and Stinson-Remick Halls of Engineering, includes five departments of study – aerospace and mechanical engineering, chemical and biomolecular engineering, civil engineering and geological sciences, computer science and engineering, and electrical engineering – with eight B.S. degrees offered. Additionally, the college offers five-year dual degree programs with the Colleges of Arts and Letters and of Business awarding additional B.A. and Master of Business Administration (MBA) degrees, respectively.
#
# All of Notre Dame's undergraduate students are a part of one of the five undergraduate colleges at the school or are in the First Year of Studies program. The First Year of Studies program was established in 1962 to guide incoming freshmen in their first year at the school before they have declared a major. Each student is given an academic advisor from the program who helps them to choose classes that give them exposure to any major in which they are interested. The program also includes a Learning Resource Center which provides time management, collaborative learning, and subject tutoring. This program has been recognized previously, by U.S. News & World Report, as outstanding.
#
# =======================================================================PROMPT COUNTS======================================================================
# Length: 5939 characters, approximately 966 tokens
# ========================================================================END PRINTING======================================================================
# keywords per question:  [['whom', 'virgin', 'mary', 'allegedly', 'appear', '1858', 'lourdes', 'france'], ['front', 'notre', 'dame', 'main', 'building'], ['basilica', 'sacred', 'heart', 'notre', 'dame', 'beside', 'structure'], ['grotto', 'notre', 'dame'], ['scholastic', 'magazine', 'notre', 'dame', 'begin', 'publishing'], ['often', 'notre', 'dames', 'juggler', 'published'], ['daily', 'student', 'paper', 'notre', 'dame', 'called'], ['many', 'student', 'news', 'papers', 'are', 'found', 'notre', 'dame'], ['headquarters', 'congregation', 'holy', 'cross'], ['primary', 'seminary', 'congregation', 'holy', 'cross'], ['oldest', 'structure', 'notre', 'dame'], ['individuals', 'live', 'fatima', 'house', 'notre', 'dame'], ['many', 'level', 'degrees', 'are', 'offered', 'college', 'engineering', 'notre', 'dame'], ['year', 'college', 'engineering', 'notre', 'dame', 'formed'], ['before', 'creation', 'college', 'engineering', 'similar', 'studies', 'carried', 'out', 'notre', 'dame', 'college'], ['many', 'departments', 'are', 'within', 'stinsonremick', 'hall', 'engineering'], ['entity', 'provides', 'help', 'management', 'time', 'new', 'students', 'notre', 'dame'], ['many', 'colleges', 'undergraduates', 'are', 'notre', 'dame'], ['created', 'notre', 'dame', '1962', 'assist', 'first', 'year', 'students'], ['organization', 'declared', 'first', 'year', 'studies', 'program', 'notre', 'dame', 'outstanding']]
# chunk assignments:  defaultdict(<class 'list'>, {0: ['To whom did the Virgin Mary allegedly appear in 1858 in Lourdes France?', 'What is in front of the Notre Dame Main Building?', 'The Basilica of the Sacred heart at Notre Dame is beside to which structure?', 'What is the Grotto at Notre Dame?', 'When did the Scholastic Magazine of Notre dame begin publishing?', "How often is Notre Dame's the Juggler published?", 'What is the daily student paper at Notre Dame called?', 'How many student news papers are found at Notre Dame?', 'Where is the headquarters of the Congregation of the Holy Cross?', 'What is the primary seminary of the Congregation of the Holy Cross?', 'What is the oldest structure at Notre Dame?'], 1: ['What individuals live at Fatima House at Notre Dame?', 'How many BS level degrees are offered in the College of Engineering at Notre Dame?', 'In what year was the College of Engineering at Notre Dame formed?', 'Before the creation of the College of Engineering similar studies were carried out at which Notre Dame college?', 'How many departments are within the Stinson-Remick Hall of Engineering?', 'What entity provides help with the management of time for new students at Notre Dame?', 'How many colleges for undergraduates are at Notre Dame?', 'What was created at Notre Dame in 1962 to assist first year students?', 'Which organization declared the First Year of Studies program at Notre Dame "outstanding?"']})
# === Prompt ===
# Answer these questions as precisely as you can, in as minimum words as you can
# Format your answers with 'A1:', 'A2:', etc. at the beginning of each answer
# If you cannot find enough information in the provided context to answer a question, respond with 'Not specified'. Do NOT guess.
# Q1: To whom did the Virgin Mary allegedly appear in 1858 in Lourdes France?
# Q2: What is in front of the Notre Dame Main Building?
# Q3: The Basilica of the Sacred heart at Notre Dame is beside to which structure?
# Q4: What is the Grotto at Notre Dame?
# Q5: When did the Scholastic Magazine of Notre dame begin publishing?
# Q6: How often is Notre Dame's the Juggler published?
# Q7: What is the daily student paper at Notre Dame called?
# Q8: How many student news papers are found at Notre Dame?
# Q9: Where is the headquarters of the Congregation of the Holy Cross?
# Q10: What is the primary seminary of the Congregation of the Holy Cross?
# Q11: What is the oldest structure at Notre Dame?
#
# from this context:
# Architecturally, the school has a Catholic character. Atop the Main Building's gold dome is a golden statue of the Virgin Mary. Immediately in front of the Main Building and facing it, is a copper statue of Christ with arms upraised with the legend "Venite Ad Me Omnes". Next to the Main Building is the Basilica of the Sacred Heart. Immediately behind the basilica is the Grotto, a Marian place of prayer and reflection. It is a replica of the grotto at Lourdes, France where the Virgin Mary reputedly appeared to Saint Bernadette Soubirous in 1858. At the end of the main drive (and in a direct line that connects through 3 statues and the Gold Dome), is a simple, modern stone statue of Mary. As at most other universities, Notre Dame's students run a number of news media outlets. The nine student-run outlets include three newspapers, both a radio and television station, and several magazines and journals. Begun as a one-page journal in September 1876, the Scholastic magazine is issued twice monthly and claims to be the oldest continuous collegiate publication in the United States. The other magazine, The Juggler, is released twice a year and focuses on student literature and artwork. The Dome yearbook is published annually. The newspapers have varying publication interests, with The Observer published daily and mainly reporting university and other news, and staffed by students from both Notre Dame and Saint Mary's College. Unlike Scholastic and The Dome, The Observer is an independent publication and does not have a faculty advisor or any editorial oversight from the University. In 1987, when some students believed that The Observer began to show a conservative bias, a liberal newspaper, Common Sense was published. Likewise, in 2003, when other students believed that the paper showed a liberal bias, the conservative paper Irish Rover went into production. Neither paper is published as often as The Observer; however, all three are distributed to all students. Finally, in Spring 2008 an undergraduate journal for political science research, Beyond Politics, made its debut. The university is the major seat of the Congregation of Holy Cross (albeit not its official headquarters, which are in Rome). Its main seminary, Moreau Seminary, is located on the campus across St. Joseph lake from the Main Building. Old College, the oldest building on campus and located near the shore of St. Mary lake, houses undergraduate seminarians. Retired priests
# ==============
#
# === Prompt ===
# Answer these questions as precisely as you can, in as minimum words as you can
# Format your answers with 'A1:', 'A2:', etc. at the beginning of each answer
# If you cannot find enough information in the provided context to answer a question, respond with 'Not specified'. Do NOT guess.
# Q1: What individuals live at Fatima House at Notre Dame?
# Q2: How many BS level degrees are offered in the College of Engineering at Notre Dame?
# Q3: In what year was the College of Engineering at Notre Dame formed?
# Q4: Before the creation of the College of Engineering similar studies were carried out at which Notre Dame college?
# Q5: How many departments are within the Stinson-Remick Hall of Engineering?
# Q6: What entity provides help with the management of time for new students at Notre Dame?
# Q7: How many colleges for undergraduates are at Notre Dame?
# Q8: What was created at Notre Dame in 1962 to assist first year students?
# Q9: Which organization declared the First Year of Studies program at Notre Dame "outstanding?"
#
# from this context:
# and brothers reside in Fatima House (a former retreat center), Holy Cross House, as well as Columba Hall near the Grotto. The university through the Moreau Seminary has ties to theologian Frederick Buechner. While not Catholic, Buechner has praised writers from Notre Dame and Moreau Seminary created a Buechner Prize for Preaching. The College of Engineering was established in 1920, however, early courses in civil and mechanical engineering were a part of the College of Science since the 1870s. Today the college, housed in the Fitzpatrick, Cushing, and Stinson-Remick Halls of Engineering, includes five departments of study – aerospace and mechanical engineering, chemical and biomolecular engineering, civil engineering and geological sciences, computer science and engineering, and electrical engineering – with eight B.S. degrees offered. Additionally, the college offers five-year dual degree programs with the Colleges of Arts and Letters and of Business awarding additional B.A. and Master of Business Administration (MBA) degrees, respectively. All of Notre Dame's undergraduate students are a part of one of the five undergraduate colleges at the school or are in the First Year of Studies program. The First Year of Studies program was established in 1962 to guide incoming freshmen in their first year at the school before they have declared a major. Each student is given an academic advisor from the program who helps them to choose classes that give them exposure to any major in which they are interested. The program also includes a Learning Resource Center which provides time management, collaborative learning, and subject tutoring. This program has been recognized previously, by U.S. News & World Report, as outstanding.
# ==============
# <ipython-input-8-0643fa1839e1>:26: LangChainDeprecationWarning: The method `BaseLLM.__call__` was deprecated in langchain-core 0.1.7 and will be removed in 1.0. Use :meth:`~invoke` instead.
#   return self.llm(prompt)
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_deprecation.py:131: FutureWarning: 'post' (from 'huggingface_hub.inference._client') is deprecated and will be removed from version '0.31.0'. Making direct POST requests to the inference server is not supported anymore. Please use task methods instead (e.g. `InferenceClient.chat_completion`). If your use case is not supported, please open an issue in https://github.com/huggingface/huggingface_hub.
#   warnings.warn(warning_message, FutureWarning)
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# --- Response for Chunk 1 ---
#
# Answer these questions as precisely as you can, in as minimum words as you can
# Format your answers with 'A1:', 'A2:', etc. at the beginning of each answer
# If you cannot find enough information in the provided context to answer a question, respond with 'Not specified'. Do NOT guess.
# Q1: To whom did the Virgin Mary allegedly appear in 1858 in Lourdes France?
# Q2: What is in front of the Notre Dame Main Building?
# Q3: The Basilica of the Sacred heart at Notre Dame is beside to which structure?
# Q4: What is the Grotto at Notre Dame?
# Q5: When did the Scholastic Magazine of Notre dame begin publishing?
# Q6: How often is Notre Dame's the Juggler published?
# Q7: What is the daily student paper at Notre Dame called?
# Q8: How many student news papers are found at Notre Dame?
# Q9: Where is the headquarters of the Congregation of the Holy Cross?
# Q10: What is the primary seminary of the Congregation of the Holy Cross?
# Q11: What is the oldest structure at Notre Dame?
#
# from this context:
# Architecturally, the school has a Catholic character. Atop the Main Building's gold dome is a golden statue of the Virgin Mary. Immediately in front of the Main Building and facing it, is a copper statue of Christ with arms upraised with the legend "Venite Ad Me Omnes". Next to the Main Building is the Basilica of the Sacred Heart. Immediately behind the basilica is the Grotto, a Marian place of prayer and reflection. It is a replica of the grotto at Lourdes, France where the Virgin Mary reputedly appeared to Saint Bernadette Soubirous in 1858. At the end of the main drive (and in a direct line that connects through 3 statues and the Gold Dome), is a simple, modern stone statue of Mary. As at most other universities, Notre Dame's students run a number of news media outlets. The nine student-run outlets include three newspapers, both a radio and television station, and several magazines and journals. Begun as a one-page journal in September 1876, the Scholastic magazine is issued twice monthly and claims to be the oldest continuous collegiate publication in the United States. The other magazine, The Juggler, is released twice a year and focuses on student literature and artwork. The Dome yearbook is published annually. The newspapers have varying publication interests, with The Observer published daily and mainly reporting university and other news, and staffed by students from both Notre Dame and Saint Mary's College. Unlike Scholastic and The Dome, The Observer is an independent publication and does not have a faculty advisor or any editorial oversight from the University. In 1987, when some students believed that The Observer began to show a conservative bias, a liberal newspaper, Common Sense was published. Likewise, in 2003, when other students believed that the paper showed a liberal bias, the conservative paper Irish Rover went into production. Neither paper is published as often as The Observer; however, all three are distributed to all students. Finally, in Spring 2008 an undergraduate journal for political science research, Beyond Politics, made its debut. The university is the major seat of the Congregation of Holy Cross (albeit not its official headquarters, which are in Rome). Its main seminary, Moreau Seminary, is located on the campus across St. Joseph lake from the Main Building. Old College, the oldest building on campus and located near the shore of St. Mary lake, houses undergraduate seminarians. Retired priests live in Moreau Seminary.
#
# A1: The Virgin Mary allegedly appeared to Saint Bernadette Soubirous in 1858 in Lourdes, France.
# A2: A copper statue of Christ with arms upraised with the legend "Venite Ad Me Omnes" is in front of the Notre Dame Main Building.
# A3: The Basilica of the Sacred Heart is beside the Notre Dame Main Building.
# A4: The Grotto at Notre Dame is a replica of the grotto at Lourdes, France where the Virgin Mary allegedly appeared to Saint Bernadette Soubirous in 1858.
# A5: The Scholastic Magazine of Notre Dame began publishing in September 1876.
# A6: The Juggler is published twice a year.
# A7: The daily student paper at Notre Dame is called The Observer.
# A8: There are 3 student news papers found at Notre Dame.
# A9: The headquarters of the Congregation of the Holy Cross is in Rome.
# A10: The primary seminary of the Congregation of the Holy Cross is Moreau Seminary.
# A11: Old College is the oldest structure at Notre Dame.
#
# -------------------------------
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_deprecation.py:131: FutureWarning: 'post' (from 'huggingface_hub.inference._client') is deprecated and will be removed from version '0.31.0'. Making direct POST requests to the inference server is not supported anymore. Please use task methods instead (e.g. `InferenceClient.chat_completion`). If your use case is not supported, please open an issue in https://github.com/huggingface/huggingface_hub.
#   warnings.warn(warning_message, FutureWarning)
# --- Response for Chunk 2 ---
#
# Answer these questions as precisely as you can, in as minimum words as you can
# Format your answers with 'A1:', 'A2:', etc. at the beginning of each answer
# If you cannot find enough information in the provided context to answer a question, respond with 'Not specified'. Do NOT guess.
# Q1: What individuals live at Fatima House at Notre Dame?
# Q2: How many BS level degrees are offered in the College of Engineering at Notre Dame?
# Q3: In what year was the College of Engineering at Notre Dame formed?
# Q4: Before the creation of the College of Engineering similar studies were carried out at which Notre Dame college?
# Q5: How many departments are within the Stinson-Remick Hall of Engineering?
# Q6: What entity provides help with the management of time for new students at Notre Dame?
# Q7: How many colleges for undergraduates are at Notre Dame?
# Q8: What was created at Notre Dame in 1962 to assist first year students?
# Q9: Which organization declared the First Year of Studies program at Notre Dame "outstanding?"
#
# from this context:
# and brothers reside in Fatima House (a former retreat center), Holy Cross House, as well as Columba Hall near the Grotto. The university through the Moreau Seminary has ties to theologian Frederick Buechner. While not Catholic, Buechner has praised writers from Notre Dame and Moreau Seminary created a Buechner Prize for Preaching. The College of Engineering was established in 1920, however, early courses in civil and mechanical engineering were a part of the College of Science since the 1870s. Today the college, housed in the Fitzpatrick, Cushing, and Stinson-Remick Halls of Engineering, includes five departments of study – aerospace and mechanical engineering, chemical and biomolecular engineering, civil engineering and geological sciences, computer science and engineering, and electrical engineering – with eight B.S. degrees offered. Additionally, the college offers five-year dual degree programs with the Colleges of Arts and Letters and of Business awarding additional B.A. and Master of Business Administration (MBA) degrees, respectively. All of Notre Dame's undergraduate students are a part of one of the five undergraduate colleges at the school or are in the First Year of Studies program. The First Year of Studies program was established in 1962 to guide incoming freshmen in their first year at the school before they have declared a major. Each student is given an academic advisor from the program who helps them to choose classes that give them exposure to any major in which they are interested. The program also includes a Learning Resource Center which provides time management, collaborative learning, and subject tutoring. This program has been recognized previously, by U.S. News & World Report, as outstanding.
#
# A1: Individuals who live at Fatima House at Notre Dame are brothers.
# A2: The College of Engineering at Notre Dame offers 8 BS level degrees.
# A3: The College of Engineering at Notre Dame was formed in 1920.
# A4: Before the creation of the College of Engineering, similar studies were carried out at the College of Science.
# A5: There are 5 departments within the Stinson-Remick Hall of Engineering.
# A6: The entity that provides help with the management of time for new students at Notre Dame is the First Year of Studies program.
# A7: There are 6 colleges for undergraduates at Notre Dame (including the First Year of Studies program).
# A8: The First Year of Studies program was created at Notre Dame in 1962.
# A9: The First Year of Studies program at Notre Dame was declared "outstanding" by U.S. News & World Report.
#
# -------------------------------
# ['Answer these questions as precisely as you can, in as minimum words as you can\nFormat your answers with \'A1:\', \'A2:\', etc. at the beginning of each answer\nIf you cannot find enough information in the provided context to answer a question, respond with \'Not specified\'. Do NOT guess.\nQ1: To whom did the Virgin Mary allegedly appear in 1858 in Lourdes France?\nQ2: What is in front of the Notre Dame Main Building?\nQ3: The Basilica of the Sacred heart at Notre Dame is beside to which structure?\nQ4: What is the Grotto at Notre Dame?\nQ5: When did the Scholastic Magazine of Notre dame begin publishing?\nQ6: How often is Notre Dame\'s the Juggler published?\nQ7: What is the daily student paper at Notre Dame called?\nQ8: How many student news papers are found at Notre Dame?\nQ9: Where is the headquarters of the Congregation of the Holy Cross?\nQ10: What is the primary seminary of the Congregation of the Holy Cross?\nQ11: What is the oldest structure at Notre Dame?\n\nfrom this context:\nArchitecturally, the school has a Catholic character. Atop the Main Building\'s gold dome is a golden statue of the Virgin Mary. Immediately in front of the Main Building and facing it, is a copper statue of Christ with arms upraised with the legend "Venite Ad Me Omnes". Next to the Main Building is the Basilica of the Sacred Heart. Immediately behind the basilica is the Grotto, a Marian place of prayer and reflection. It is a replica of the grotto at Lourdes, France where the Virgin Mary reputedly appeared to Saint Bernadette Soubirous in 1858. At the end of the main drive (and in a direct line that connects through 3 statues and the Gold Dome), is a simple, modern stone statue of Mary. As at most other universities, Notre Dame\'s students run a number of news media outlets. The nine student-run outlets include three newspapers, both a radio and television station, and several magazines and journals. Begun as a one-page journal in September 1876, the Scholastic magazine is issued twice monthly and claims to be the oldest continuous collegiate publication in the United States. The other magazine, The Juggler, is released twice a year and focuses on student literature and artwork. The Dome yearbook is published annually. The newspapers have varying publication interests, with The Observer published daily and mainly reporting university and other news, and staffed by students from both Notre Dame and Saint Mary\'s College. Unlike Scholastic and The Dome, The Observer is an independent publication and does not have a faculty advisor or any editorial oversight from the University. In 1987, when some students believed that The Observer began to show a conservative bias, a liberal newspaper, Common Sense was published. Likewise, in 2003, when other students believed that the paper showed a liberal bias, the conservative paper Irish Rover went into production. Neither paper is published as often as The Observer; however, all three are distributed to all students. Finally, in Spring 2008 an undergraduate journal for political science research, Beyond Politics, made its debut. The university is the major seat of the Congregation of Holy Cross (albeit not its official headquarters, which are in Rome). Its main seminary, Moreau Seminary, is located on the campus across St. Joseph lake from the Main Building. Old College, the oldest building on campus and located near the shore of St. Mary lake, houses undergraduate seminarians. Retired priests live in Moreau Seminary.\n\nA1: The Virgin Mary allegedly appeared to Saint Bernadette Soubirous in 1858 in Lourdes, France.\nA2: A copper statue of Christ with arms upraised with the legend "Venite Ad Me Omnes" is in front of the Notre Dame Main Building.\nA3: The Basilica of the Sacred Heart is beside the Notre Dame Main Building.\nA4: The Grotto at Notre Dame is a replica of the grotto at Lourdes, France where the Virgin Mary allegedly appeared to Saint Bernadette Soubirous in 1858.\nA5: The Scholastic Magazi ...
#  'Answer these questions as precisely as you can, in as minimum words as you can\nFormat your answers with \'A1:\', \'A2:\', etc. at the beginning of each answer\nIf you cannot find enough information in the provided context to answer a question, respond with \'Not specified\'. Do NOT guess.\nQ1: What individuals live at Fatima House at Notre Dame?\nQ2: How many BS level degrees are offered in the College of Engineering at Notre Dame?\nQ3: In what year was the College of Engineering at Notre Dame formed?\nQ4: Before the creation of the College of Engineering similar studies were carried out at which Notre Dame college?\nQ5: How many departments are within the Stinson-Remick Hall of Engineering?\nQ6: What entity provides help with the management of time for new students at Notre Dame?\nQ7: How many colleges for undergraduates are at Notre Dame?\nQ8: What was created at Notre Dame in 1962 to assist first year students?\nQ9: Which organization declared the First Year of Studies program at Notre Dame "outstanding?"\n\nfrom this context:\nand brothers reside in Fatima House (a former retreat center), Holy Cross House, as well as Columba Hall near the Grotto. The university through the Moreau Seminary has ties to theologian Frederick Buechner. While not Catholic, Buechner has praised writers from Notre Dame and Moreau Seminary created a Buechner Prize for Preaching. The College of Engineering was established in 1920, however, early courses in civil and mechanical engineering were a part of the College of Science since the 1870s. Today the college, housed in the Fitzpatrick, Cushing, and Stinson-Remick Halls of Engineering, includes five departments of study – aerospace and mechanical engineering, chemical and biomolecular engineering, civil engineering and geological sciences, computer science and engineering, and electrical engineering – with eight B.S. degrees offered. Additionally, the college offers five-year dual degree programs with the Colleges of Arts and Letters and of Business awarding additional B.A. and Master of Business Administration (MBA) degrees, respectively. All of Notre Dame\'s undergraduate students are a part of one of the five undergraduate colleges at the school or are in the First Year of Studies program. The First Year of Studies program was established in 1962 to guide incoming freshmen in their first year at the school before they have declared a major. Each student is given an academic advisor from the program who helps them to choose classes that give them exposure to any major in which they are interested. The program also includes a Learning Resource Center which provides time management, collaborative learning, and subject tutoring. This program has been recognized previously, by U.S. News & World Report, as outstanding.\n\nA1: Individuals who live at Fatima House at Notre Dame are brothers.\nA2: The College of Engineering at Notre Dame offers 8 BS level degrees.\nA3: The College of Engineering at Notre Dame was formed in 1920.\nA4: Before the creation of the College of Engineering, similar studies were carried out at the College of Science.\nA5: There are 5 departments within the Stinson-Remick Hall of Engineering.\nA6: The entity that provides help with the management of time for new students at Notre Dame is the First Year of Studies program.\nA7: There are 6 colleges for undergraduates at Notre Dame (including the First Year of Studies program).\nA8: The First Year of Studies program was created at Notre Dame in 1962.\nA9: The First Year of Studies program at Notre Dame was declared "outstanding" by U.S. News & World Report.']

# %% [markdown]
# ### Refining class
#
# okay so now, given that the approach of assigning questions to chunks seems to be working fine, we will now proceed to cleaning the process and output etc.

# %%
import re
from collections import defaultdict
from typing import List, Tuple


class Agent2:
    #same context overload notebook
    def __init__(self, context_map, model_name="mistralai/Mistral-7B-Instruct-v0.3", access_token="TOKEN-HERE"):
        self.context_map = context_map
        self.llm = HuggingFaceHub(
            repo_id=model_name,
            model_kwargs={"temperature": 0.3, "max_length": 200},
            huggingfacehub_api_token=access_token
        )
        self.current_prompt = None # NEW: ask user to input context and questions seperately. chunks will only be made of context.
        self.chunked_prompts = []
        self.chunk_responses = ['Answer these questions as precisely as you can, in as minimum words as you can\nFormat your answers with \'A1:\', \'A2:\', etc. at the beginning of each answer\nIf you cannot find enough information in the provided context to answer a question, respond with \'Not specified\'. Do NOT guess.\nQ1: To whom did the Virgin Mary allegedly appear in 1858 in Lourdes France?\nQ2: What is in front of the Notre Dame Main Building?\nQ3: The Basilica of the Sacred heart at Notre Dame is beside to which structure?\nQ4: What is the Grotto at Notre Dame?\nQ5: When did the Scholastic Magazine of Notre dame begin publishing?\nQ6: How often is Notre Dame\'s the Juggler published?\nQ7: What is the daily student paper at Notre Dame called?\nQ8: How many student news papers are found at Notre Dame?\nQ9: Where is the headquarters of the Congregation of the Holy Cross?\nQ10: What is the primary seminary of the Congregation of the Holy Cross?\nQ11: What is the oldest structure at Notre Dame?\n\nfrom this context:\nArchitecturally, the school has a Catholic character. Atop the Main Building\'s gold dome is a golden statue of the Virgin Mary. Immediately in front of the Main Building and facing it, is a copper statue of Christ with arms upraised with the legend "Venite Ad Me Omnes". Next to the Main Building is the Basilica of the Sacred Heart. Immediately behind the basilica is the Grotto, a Marian place of prayer and reflection. It is a replica of the grotto at Lourdes, France where the Virgin Mary reputedly appeared to Saint Bernadette Soubirous in 1858. At the end of the main drive (and in a direct line that connects through 3 statues and the Gold Dome), is a simple, modern stone statue of Mary. As at most other universities, Notre Dame\'s students run a number of news media outlets. The nine student-run outlets include three newspapers, both a radio and television station, and several magazines and journals. Begun as a one-page journal in September 1876, the Scholastic magazine is issued twice monthly and claims to be the oldest continuous collegiate publication in the United States. The other magazine, The Juggler, is released twice a year and focuses on student literature and artwork. The Dome yearbook is published annually. The newspapers have varying publication interests, with The Observer published daily and mainly reporting university and other news, and staffed by students from both Notre Dame and Saint Mary\'s College. Unlike Scholastic and The Dome, The Observer is an independent publication and does not have a faculty advisor or any editorial oversight from the University. In 1987, when some students believed that The Observer began to show a conservative bias, a liberal newspaper, Common Sense was published. Likewise, in 2003, when other students believed that the paper showed a liberal bias, the conservative paper Irish Rover went into production. Neither paper is published as often as The Observer; however, all three are distributed to all students. Finally, in Spring 2008 an undergraduate journal for political science research, Beyond Politics, made its debut. The university is the major seat of the Congregation of Holy Cross (albeit not its official headquarters, which are in Rome). Its main seminary, Moreau Seminary, is located on the campus across St. Joseph lake from the Main Building. Old College, the oldest building on campus and located near the shore of St. Mary lake, houses undergraduate seminarians. Retired priests live in Moreau Seminary.\n\nA1: The Virgin Mary allegedly appeared to Saint Bernadette Soubirous in 1858 in Lourdes, France.\nA2: A copper statue of Christ with arms upraised with the legend "Venite Ad Me Omnes" is in front of the Notre Dame Main Building.\nA3: The Basilica of the Sacred Heart is beside the Notre Dame Main Building.\nA4: The Grotto at Notre Dame is a replica of the grotto at Lourdes, France where the Virgin Mary allegedly appeared to Saint Bernadette Soubirous in 1858.\nA5: The Scholastic Magazine of Notre Dame began publishing in September 1876.\nA6: The Juggler is published twice a year.\nA7: The daily student paper at Notre Dame is called The Observer.\nA8: There are 3 student news papers found at Notre Dame.\nA9: The headquarters of the Congregation of the Holy Cross is in Rome.\nA10: The primary seminary of the Congregation of the Holy Cross is Moreau Seminary.\nA11: Old College is the oldest structure at Notre Dame.',
 'Answer these questions as precisely as you can, in as minimum words as you can\nFormat your answers with \'A1:\', \'A2:\', etc. at the beginning of each answer\nIf you cannot find enough information in the provided context to answer a question, respond with \'Not specified\'. Do NOT guess.\nQ1: What individuals live at Fatima House at Notre Dame?\nQ2: How many BS level degrees are offered in the College of Engineering at Notre Dame?\nQ3: In what year was the College of Engineering at Notre Dame formed?\nQ4: Before the creation of the College of Engineering similar studies were carried out at which Notre Dame college?\nQ5: How many departments are within the Stinson-Remick Hall of Engineering?\nQ6: What entity provides help with the management of time for new students at Notre Dame?\nQ7: How many colleges for undergraduates are at Notre Dame?\nQ8: What was created at Notre Dame in 1962 to assist first year students?\nQ9: Which organization declared the First Year of Studies program at Notre Dame "outstanding?"\n\nfrom this context:\nand brothers reside in Fatima House (a former retreat center), Holy Cross House, as well as Columba Hall near the Grotto. The university through the Moreau Seminary has ties to theologian Frederick Buechner. While not Catholic, Buechner has praised writers from Notre Dame and Moreau Seminary created a Buechner Prize for Preaching. The College of Engineering was established in 1920, however, early courses in civil and mechanical engineering were a part of the College of Science since the 1870s. Today the college, housed in the Fitzpatrick, Cushing, and Stinson-Remick Halls of Engineering, includes five departments of study – aerospace and mechanical engineering, chemical and biomolecular engineering, civil engineering and geological sciences, computer science and engineering, and electrical engineering – with eight B.S. degrees offered. Additionally, the college offers five-year dual degree programs with the Colleges of Arts and Letters and of Business awarding additional B.A. and Master of Business Administration (MBA) degrees, respectively. All of Notre Dame\'s undergraduate students are a part of one of the five undergraduate colleges at the school or are in the First Year of Studies program. The First Year of Studies program was established in 1962 to guide incoming freshmen in their first year at the school before they have declared a major. Each student is given an academic advisor from the program who helps them to choose classes that give them exposure to any major in which they are interested. The program also includes a Learning Resource Center which provides time management, collaborative learning, and subject tutoring. This program has been recognized previously, by U.S. News & World Report, as outstanding.\n\nA1: Individuals who live at Fatima House at Notre Dame are brothers.\nA2: The College of Engineering at Notre Dame offers 8 BS level degrees.\nA3: The College of Engineering at Notre Dame was formed in 1920.\nA4: Before the creation of the College of Engineering, similar studies were carried out at the College of Science.\nA5: There are 5 departments within the Stinson-Remick Hall of Engineering.\nA6: The entity that provides help with the management of time for new students at Notre Dame is the First Year of Studies program.\nA7: There are 6 colleges for undergraduates at Notre Dame (including the First Year of Studies program).\nA8: The First Year of Studies program was created at Notre Dame in 1962.\nA9: The First Year of Studies program at Notre Dame was declared "outstanding" by U.S. News & World Report.']
        # new variables for storing questions, chunks and gold answers respectively.
        self.current_context_chunks = []
        self.current_questions = []
        self.current_gold_answers = []
        # this is for chunk assignment to each question
        self.chunk_assignments = defaultdict(list)
        # for parsing and storing question answer pairs from chunk prompts:
        self.question_answer_map = {}

    def generate_response(self, prompt): #can use this function to get answer from 1 chunk, then 2nd chunk etc, all chunks and then proceed. with normal
        return self.llm(prompt)

    def get_context_questions(self, k=2, q=4):
      #same as context overload notebook
        contexts = []
        questions_answers = []
        selected_contexts = list(self.context_map.items())[:k]
        for context, qa_pairs in selected_contexts:
            contexts.append(context)
            selected_qa = qa_pairs[:q]
            questions_answers.append(selected_qa)
        return contexts, questions_answers

    def generate_Dataset_prompt(self, k=2, q=4):
        ''' This function generates and imitates a prompt from the dataset, later on, we will take questions and context as input from user.'''
        contexts, questions_answers_by_context = self.get_context_questions(k, q)
        combined_context = "\n\n".join(contexts)
        all_questions_answers = []
        for qa_pairs in questions_answers_by_context:
            all_questions_answers.extend(qa_pairs)
        # modified the prompt
        prompt_lines = [
            "Answer these questions as precisely as you can, in as minimum words as you can",
            "Format your answers with 'A1:', 'A2:', etc. at the beginning of each answer",
            "If you cannot find enough information in the provided context to answer a question, respond with 'Not specified'. Do NOT guess.",
        ]
        self.current_questions = []
        self.current_gold_answers = []
        for i, (question, answer) in enumerate(all_questions_answers, 1):
            self.current_questions.append(question)
            self.current_gold_answers.append(answer)
            prompt_lines.append(f"Q{i}: {question}")
        prompt_lines.append("\nfrom this context:")
        prompt_lines.append(combined_context)
        prompt = "\n".join(prompt_lines)
        self.current_prompt = prompt
        char_length = len(prompt)
        token_count = len(prompt.split())


    def extract_keywords(self, questions: List[str]) -> List[List[str]]:
        """
        Given a list of questions, extract a list of keywords for each question.
        """
        stopwords = set([
            "the", "is", "at", "which", "on", "in", "a", "an", "of", "to", "for", "with",
            "and", "by", "from", "what", "who", "when", "where", "how", "does", "do",
            "did", "was", "were", "has", "have", "had"
        ])
        all_keywords = []
        for question in questions:
            # Remove punctuation
            question_clean = re.sub(r'[^\w\s]', '', question)
            words = question_clean.lower().split()
            # Filter stopwords and small words
            keywords = [word for word in words if word not in stopwords and len(word) > 2]
            all_keywords.append(keywords)
        return all_keywords

    def map_questions_to_chunks(self) -> List[Tuple[str, List[str]]]:
        """
        Map each context chunk to the most probable questions based on keyword matching.
        Returns a list of (context_chunk, assigned_questions) pairs.
        """
        if not self.current_context_chunks:
            raise ValueError("No context chunks available. Please run chunk_current_prompt first.")
        if not self.current_questions:
            raise ValueError("No questions available. Please populate current_questions first.")
        keywords_per_question = self.extract_keywords(self.current_questions)
        # print(f"keywords per question: ", keywords_per_question) #so it returns a list of lists, the list has keywords of each question
        self.chunk_assignments = defaultdict(list)
        lowered_chunks = [chunk.lower() for chunk in self.current_context_chunks]
        for q_idx, keywords in enumerate(keywords_per_question):
            question = self.current_questions[q_idx]
            best_chunk_idx = None
            best_match_count = 0
            for idx, chunk in enumerate(lowered_chunks):
                match_count = sum(1 for keyword in keywords if keyword in chunk)
                if match_count > best_match_count:
                    best_match_count = match_count
                    best_chunk_idx = idx
            if best_chunk_idx is not None and best_match_count > 0:
                self.chunk_assignments[best_chunk_idx].append(question)
        # print(f"chunk assignments: ", self.chunk_assignments)

    def chunk_current_prompt(self, max_words_per_chunk=800):
        """
        Splits the context into ~800-word chunks and constructs prompts accordingly.
        Stores the chunked prompts in self.chunked_prompts.
        """
        if not hasattr(self, 'current_prompt') or self.current_prompt is None:
            raise ValueError("current_prompt not set. Please run generate_Dataset_prompt first.")
        prompt_parts = self.current_prompt.split("\nfrom this context:\n")
        if len(prompt_parts) != 2:
            raise ValueError("Prompt is not formatted correctly.")
        question_block = prompt_parts[0]  # instructions + questions
        context_block = prompt_parts[1]   # full context text
        context_words = context_block.split()
        chunks = [
            " ".join(context_words[i:i+max_words_per_chunk])
            for i in range(0, len(context_words), max_words_per_chunk)
        ]
        self.chunked_prompts = []
        self.current_context_chunks = []
        for chunk in chunks:
            self.current_context_chunks.append(chunk)
            new_prompt = f"{question_block}\n\nfrom this context:\n{chunk}"
            self.chunked_prompts.append(new_prompt)


    def construct_individual_prompts_from_assignments(self):
        """
        Constructs individual prompts by pairing assigned questions with their corresponding context chunks.
        Formats the prompt according to specified rules: minimal word answers, labeled Q1, Q2..., and specific handling for unknowns.
        Stores results in self.individual_prompts as a list of prompt strings.
        """
        if not hasattr(self, 'chunk_assignments') or not self.chunk_assignments:
            raise ValueError("chunk_assignments not set. Please run map_questions_to_chunks first.")

        if not hasattr(self, 'current_context_chunks') or not self.current_context_chunks:
            raise ValueError("No context chunks available.")

        self.individual_prompts = []
        for idx, questions in self.chunk_assignments.items():
            chunk = self.current_context_chunks[idx]
            # Add Q1, Q2... prefix
            formatted_questions = [f"Q{i + 1}: {q}" for i, q in enumerate(questions)]
            question_block = "\n".join(formatted_questions)

            prompt = (
                "Answer these questions as precisely as you can, in as minimum words as you can\n"
                "Format your answers with 'A1:', 'A2:', etc. at the beginning of each answer\n"
                "If you cannot find enough information in the provided context to answer a question, respond with 'Not specified'. Do NOT guess.\n"
                f"{question_block}\n\nfrom this context:\n{chunk}"
            )
            self.individual_prompts.append(prompt)
        self.chunked_prompts = self.individual_prompts


    def run_all_chunks(self, verbose=True):
        """
        Calls the LLM for each chunked prompt and prints the responses.

        Args:
            verbose (bool): If True, prints each response.

        Returns:
            List of responses from the model for each chunked prompt.
        """
        if not self.chunked_prompts:
            raise ValueError("chunked_prompts not set. Please run chunk_current_prompt first.")
        self.chunk_responses = []
        for idx, prompt in enumerate(self.chunked_prompts, 1):
            response = self.generate_response(prompt)
            self.chunk_responses.append(response)
            if verbose:
                print(f"\n--- Response for Chunk {idx} ---\n")
                print(response)
                print("\n-------------------------------\n")

    def extract_questions_and_answers(self, verbose=True):
        self.question_answer_map = {}

        for chunk_idx, response in enumerate(self.chunk_responses):
            questions = self.chunk_assignments.get(chunk_idx, [])

            # Remove any part before the FIRST 'Q1:' to skip prompt/instructions
            question_block_start = re.search(r'\bQ1:', response)
            if not question_block_start:
                if verbose:
                    print(f"[Warning] No 'Q1:' found in chunk {chunk_idx}, skipping")
                continue

            cleaned_response = response[question_block_start.start():]

            # Extract answers (A1:, A2:, ...) — multiline with DOTALL
            answers = re.findall(r'A\d+:\s*(.*?)(?=\nA\d+:|\Z)', cleaned_response, re.DOTALL)

            if verbose and len(answers) != len(questions):
                print(f"[Warning] Mismatch: {len(questions)} questions vs {len(answers)} answers in chunk {chunk_idx}")

            for i, answer in enumerate(answers):
                if i < len(questions):
                    question = questions[i]
                    self.question_answer_map[question] = answer.strip()
                else:
                    break  # More answers than questions

        return self.question_answer_map


    def print_current_prompt(self):
        ''' This function prints the generated or inputted prompt'''
        print("=======================================================================PRINTING PROMPT======================================================================")
        print(f"\n🧠 Current Prompt:")
        print(f"{self.current_prompt}\n")
        char_length = len(self.current_prompt)
        token_count = len(self.current_prompt.split())
        print("=======================================================================PROMPT COUNTS======================================================================")
        print(f"Length: {char_length} characters, approximately {token_count} tokens")
        print("========================================================================END PRINTING======================================================================")


    def print_chunks(self):
        ''' This function prints each chunked prompt stored in self.chunked_prompts '''
        if not hasattr(self, 'chunked_prompts') or not self.chunked_prompts:
            print("No chunked prompts found. Please run chunk_current_prompt() first.")
            return
        print("=======================================================================PRINTING CHUNKED PROMPTS======================================================================")
        for i, chunk in enumerate(self.chunked_prompts, 1):
            print(f"\n🧠 Prompt Chunk {i}:")
            print(chunk)
            char_length = len(chunk)
            token_count = len(chunk.split())
            print("-----------------------------------------")
            print(f"Length: {char_length} characters, approximately {token_count} tokens")
            print("============================================================================================================================================================")
        print("=======================================================================END OF CHUNKS======================================================================")

    def print_parsed_qa_pairs(self):
        if not hasattr(self, 'question_answer_map') or not self.question_answer_map:
            print("No question-answer pairs found. Please run extract_questions_and_answers() first.")
            return

        print("Parsed Question-Answer Pairs:\n")
        for idx, (question, answer) in enumerate(self.question_answer_map.items(), 1):
            print(f"{idx}. Q: {question}\n   A: {answer}\n")

    def print_qa_pair_comparison(self):
        if not hasattr(self, 'question_answer_map') or not self.question_answer_map:
            print("No question-answer pairs found. Please run extract_questions_and_answers() first.")
            return

        if not hasattr(self, 'current_gold_answers') or not self.current_gold_answers:
            print("No gold answers found. Please set self.current_gold_answers before comparing.")
            return

        questions = list(self.question_answer_map.keys())
        predicted_answers = list(self.question_answer_map.values())
        gold_answers = self.current_gold_answers

        print("Question | Predicted Answer | Gold Answer")
        print("-" * 80)

        for idx, question in enumerate(questions):
            predicted = predicted_answers[idx] if idx < len(predicted_answers) else "N/A"
            gold = gold_answers[idx] if idx < len(gold_answers) else "N/A"

            print(f"Q{idx+1}: {question}")
            print(f"  🤖 Predicted: {predicted}")
            print(f"  ✅ Gold     : {gold}")
            print()

    def print_qa_pairs(self):

        if not hasattr(self, 'current_gold_answers') or not self.current_gold_answers:
            print("No gold answers found. Please set self.current_gold_answers before comparing.")
            return

        questions = list(self.current_questions)
        gold_answers = self.current_gold_answers

        print("Question | Predicted Answer | Gold Answer")
        print("-" * 80)

        for idx, question in enumerate(questions):
            gold = gold_answers[idx] if idx < len(gold_answers) else "N/A"

            print(f"Q{idx+1}: {question}")
            print(f"  ✅ Gold     : {gold}")
            print()

# %% [markdown]
# # K8Q5

# %%
#driver code:
agent = Agent2(context_map)
agent.generate_Dataset_prompt(k=8, q=5)
# agent.print_current_prompt()
agent.chunk_current_prompt(max_words_per_chunk=700)
agent.map_questions_to_chunks()
agent.construct_individual_prompts_from_assignments()
agent.run_all_chunks()
agent.extract_questions_and_answers()
# agent.print_parsed_qa_pairs()
agent.print_qa_pair_comparison()
# Out:
# <ipython-input-2-259988e07c46>:10: LangChainDeprecationWarning: The class `HuggingFaceHub` was deprecated in LangChain 0.0.21 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-huggingface package and should be used instead. To use it run `pip install -U :class:`~langchain-huggingface` and import as `from :class:`~langchain_huggingface import HuggingFaceEndpoint``.
#   self.llm = HuggingFaceHub(
# <ipython-input-2-259988e07c46>:29: LangChainDeprecationWarning: The method `BaseLLM.__call__` was deprecated in langchain-core 0.1.7 and will be removed in 1.0. Use :meth:`~invoke` instead.
#   return self.llm(prompt)
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_deprecation.py:131: FutureWarning: 'post' (from 'huggingface_hub.inference._client') is deprecated and will be removed from version '0.31.0'. Making direct POST requests to the inference server is not supported anymore. Please use task methods instead (e.g. `InferenceClient.chat_completion`). If your use case is not supported, please open an issue in https://github.com/huggingface/huggingface_hub.
#   warnings.warn(warning_message, FutureWarning)
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# --- Response for Chunk 1 ---
#
# Answer these questions as precisely as you can, in as minimum words as you can
# Format your answers with 'A1:', 'A2:', etc. at the beginning of each answer
# If you cannot find enough information in the provided context to answer a question, respond with 'Not specified'. Do NOT guess.
# Q1: To whom did the Virgin Mary allegedly appear in 1858 in Lourdes France?
# Q2: What is in front of the Notre Dame Main Building?
# Q3: The Basilica of the Sacred heart at Notre Dame is beside to which structure?
# Q4: What is the Grotto at Notre Dame?
# Q5: What sits on top of the Main Building at Notre Dame?
# Q6: When did the Scholastic Magazine of Notre dame begin publishing?
# Q7: How often is Notre Dame's the Juggler published?
# Q8: What is the daily student paper at Notre Dame called?
# Q9: How many student news papers are found at Notre Dame?
# Q10: In what year did the student paper Common Sense begin publication at Notre Dame?
# Q11: Where is the headquarters of the Congregation of the Holy Cross?
# Q12: What is the primary seminary of the Congregation of the Holy Cross?
# Q13: What is the oldest structure at Notre Dame?
# Q14: What individuals live at Fatima House at Notre Dame?
# Q15: Which prize did Frederick Buechner create?
# Q16: How many BS level degrees are offered in the College of Engineering at Notre Dame?
# Q17: In what year was the College of Engineering at Notre Dame formed?
# Q18: Before the creation of the College of Engineering similar studies were carried out at which Notre Dame college?
# Q19: How many departments are within the Stinson-Remick Hall of Engineering?
# Q20: The College of Science began to offer civil engineering courses beginning at what time at Notre Dame?
# Q21: What entity provides help with the management of time for new students at Notre Dame?
# Q22: How many colleges for undergraduates are at Notre Dame?
# Q23: What was created at Notre Dame in 1962 to assist first year students?
# Q24: Which organization declared the First Year of Studies program at Notre Dame "outstanding?"
# Q25: The granting of Doctorate degrees first occurred in what year at Notre Dame?
# Q26: What type of degree is an M.Div.?
# Q27: In what year was a Master of Arts course first offered at Notre Dame?
# Q28: Which department at Notre Dame is the only one to not offer a PhD program?
#
# from this context:
# Architecturally, the school has a Catholic character. Atop the Main Building's gold dome is a golden statue of the Virgin Mary. Immediately in front of the Main Building and facing it, is a copper statue of Christ with arms upraised with the legend "Venite Ad Me Omnes". Next to the Main Building is the Basilica of the Sacred Heart. Immediately behind the basilica is the Grotto, a Marian place of prayer and reflection. It is a replica of the grotto at Lourdes, France where the Virgin Mary reputedly appeared to Saint Bernadette Soubirous in 1858. At the end of the main drive (and in a direct line that connects through 3 statues and the Gold Dome), is a simple, modern stone statue of Mary. As at most other universities, Notre Dame's students run a number of news media outlets. The nine student-run outlets include three newspapers, both a radio and television station, and several magazines and journals. Begun as a one-page journal in September 1876, the Scholastic magazine is issued twice monthly and claims to be the oldest continuous collegiate publication in the United States. The other magazine, The Juggler, is released twice a year and focuses on student literature and artwork. The Dome yearbook is published annually. The newspapers have varying publication interests, with The Observer published daily and mainly reporting university and other news, and staffed by students from both Notre Dame and Saint Mary's College. Unlike Scholastic and The Dome, The Observer is an independent publication and does not have a faculty advisor or any editorial oversight from the University. In 1987, when some students believed that The Observer began to show a conservative bias, a liberal newspaper, Common Sense was published. Likewise, in 2003, when other students believed that the paper showed a liberal bias, the conservative paper Irish Rover went into production. Neither paper is published as often as The Observer; however, all three are distributed to all students. Finally, in Spring 2008 an undergraduate journal for political science research, Beyond Politics, made its debut. The university is the major seat of the Congregation of Holy Cross (albeit not its official headquarters, which are in Rome). Its main seminary, Moreau Seminary, is located on the campus across St. Joseph lake from the Main Building. Old College, the oldest building on campus and located near the shore of St. Mary lake, houses undergraduate seminarians. Retired priests and brothers reside in Fatima House (a former retreat center), Holy Cross House, as well as Columba Hall near the Grotto. The university through the Moreau Seminary has ties to theologian Frederick Buechner. While not Catholic, Buechner has praised writers from Notre Dame and Moreau Seminary created a Buechner Prize for Preaching. The College of Engineering was established in 1920, however, early courses in civil and mechanical engineering were a part of the College of Science since the 1870s. Today the college, housed in the Fitzpatrick, Cushing, and Stinson-Remick Halls of Engineering, includes five departments of study – aerospace and mechanical engineering, chemical and biomolecular engineering, civil engineering and geological sciences, computer science and engineering, and electrical engineering – with eight B.S. degrees offered. Additionally, the college offers five-year dual degree programs with the Colleges of Arts and Letters and of Business awarding additional B.A. and Master of Business Administration (MBA) degrees, respectively. All of Notre Dame's undergraduate students are a part of one of the five undergraduate colleges at the school or are in the First Year of Studies program. The First Year of Studies program was established in 1962 to guide incoming freshmen in their first year at the school before they have declared a major. Each student is given an academic advisor from the program who helps them to choose classes that give them exposure to any major in which they are interested.  ...
#
# A1: The Virgin Mary allegedly appeared to Bernadette Soubirous in 1858 in Lourdes, France.
# A2: A copper statue of Christ with arms upraised with the legend "Venite Ad Me Omnes" is in front of the Notre Dame Main Building.
# A3: The Basilica of the Sacred heart at Notre Dame is beside the Main Building.
# A4: The Grotto at Notre Dame is a Marian place of prayer and reflection, a replica of the grotto at Lourdes, France.
# A5: A golden statue of the Virgin Mary sits on top of the Main Building at Notre Dame.
# A6: The Scholastic Magazine of Notre Dame began publishing in September 1876.
# A7: The Juggler is published twice a year.
# A8: The daily student paper at Notre Dame is called The Observer.
# A9: There are 3 student news papers at Notre Dame.
# A10: The student paper Common Sense began publication at Notre Dame in 1987.
# A11: The headquarters of the Congregation of the Holy Cross is in Rome.
# A12: The primary seminary of the Congregation of the Holy Cross is Moreau Seminary.
# A13: Old College, the oldest building on campus, is the oldest structure at Notre Dame.
# A14: Individuals who live at Fatima House at Notre Dame are retired priests and brothers.
# A15: Frederick Buechner created the Buechner Prize for Preaching.
# A16: The College of Engineering at Notre Dame offers 8 BS level degrees.
# A17: The College of Engineering at Notre Dame was formed in 1920.
# A18: Early courses in civil and mechanical engineering were a part of the College of Science since the 1870s.
# A19: There are 5 departments within the Stinson-Remick Hall of Engineering.
# A20: The College of Science began to offer civil engineering courses in the 1870s.
# A21: The entity that provides help with the management of time for new students at Notre Dame is the First Year of Studies program.
# A22: There are 5 undergraduate colleges at Notre Dame.
# A23: The First Year of Studies program was established in 1962.
# A24: The First Year of Studies program at Notre Dame was recognized as "outstanding" by U.S. News & World Report.
# A25: The granting of Doctorate degrees first occurred in 1897 at Notre Dame.
# A26: An M.Div. is a Master of Divinity degree.
# A27: A Master of Arts course first offered at Notre Dame was in the 1854–1855 academic year.
# A28: The only department at Notre Dame to not offer a PhD program is the Department of Theology.
#
# -------------------------------
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_deprecation.py:131: FutureWarning: 'post' (from 'huggingface_hub.inference._client') is deprecated and will be removed from version '0.31.0'. Making direct POST requests to the inference server is not supported anymore. Please use task methods instead (e.g. `InferenceClient.chat_completion`). If your use case is not supported, please open an issue in https://github.com/huggingface/huggingface_hub.
#   warnings.warn(warning_message, FutureWarning)
# --- Response for Chunk 2 ---
#
# Answer these questions as precisely as you can, in as minimum words as you can
# Format your answers with 'A1:', 'A2:', etc. at the beginning of each answer
# If you cannot find enough information in the provided context to answer a question, respond with 'Not specified'. Do NOT guess.
# Q1: Which program at Notre Dame offers a Master of Education degree?
# Q2: What institute at Notre Dame studies  the reasons for violent conflict?
# Q3: What is the title of Notre Dame's Theodore Hesburgh?
# Q4: In what year was the Joan B. Kroc Institute for International Peace Studies founded?
# Q5: To whom was John B. Kroc married?
# Q6: What company did Ray Kroc own?
# Q7: How many stories tall is the main library at Notre Dame?
# Q8: What is the name of the main library at Notre Dame?
# Q9: In what year was the Theodore M. Hesburgh Library at Notre Dame finished?
# Q10: Which artist created the mural on the Theodore M. Hesburgh Library?
# Q11: What is a common name to reference the mural created by Millard Sheets at Notre Dame?
#
# from this context:
# Engineering in its early stages of growth, before a formal graduate school education was developed with a thesis not required to receive the degrees. This changed in 1924 with formal requirements developed for graduate degrees, including offering Doctorate (PhD) degrees. Today each of the five colleges offer graduate education. Most of the departments from the College of Arts and Letters offer PhD programs, while a professional Master of Divinity (M.Div.) program also exists. All of the departments in the College of Science offer PhD programs, except for the Department of Pre-Professional Studies. The School of Architecture offers a Master of Architecture, while each of the departments of the College of Engineering offer PhD programs. The College of Business offers multiple professional programs including MBA and Master of Science in Accountancy programs. It also operates facilities in Chicago and Cincinnati for its executive MBA program. Additionally, the Alliance for Catholic Education program offers a Master of Education program where students study at the university during the summer and teach in Catholic elementary schools, middle schools, and high schools across the Southern United States for two school years. The Joan B. Kroc Institute for International Peace Studies at the University of Notre Dame is dedicated to research, education and outreach on the causes of violent conflict and the conditions for sustainable peace. It offers PhD, Master's, and undergraduate degrees in peace studies. It was founded in 1986 through the donations of Joan B. Kroc, the widow of McDonald's owner Ray Kroc. The institute was inspired by the vision of the Rev. Theodore M. Hesburgh CSC, President Emeritus of the University of Notre Dame. The institute has contributed to international policy discussions about peace building practices. The library system of the university is divided between the main library and each of the colleges and schools. The main building is the 14-story Theodore M. Hesburgh Library, completed in 1963, which is the third building to house the main collection of books. The front of the library is adorned with the Word of Life mural designed by artist Millard Sheets. This mural is popularly known as "Touchdown Jesus" because of its proximity to Notre Dame Stadium and Jesus' arms appearing to make the signal for a touchdown.
#
# A1: The Alliance for Catholic Education program offers a Master of Education program.
# A2: The Joan B. Kroc Institute for International Peace Studies studies the reasons for violent conflict.
# A3: The title of Notre Dame's Theodore Hesburgh is President Emeritus.
# A4: The Joan B. Kroc Institute for International Peace Studies was founded in 1986.
# A5: John B. Kroc was married to Joan B. Kroc.
# A6: Ray Kroc owned McDonald's.
# A7: The main library at Notre Dame is 14 stories tall.
# A8: The main library at Notre Dame is the Theodore M. Hesburgh Library.
# A9: The Theodore M. Hesburgh Library at Notre Dame was finished in 1963.
# A10: Millard Sheets created the mural on the Theodore M. Hesburgh Library.
# A11: The mural created by Millard Sheets at Notre Dame is commonly known as "Touchdown Jesus".
#
# -------------------------------
#
# Question | Predicted Answer | Gold Answer
# --------------------------------------------------------------------------------
# Q1: To whom did the Virgin Mary allegedly appear in 1858 in Lourdes France?
#   🤖 Predicted: The Virgin Mary allegedly appeared to Bernadette Soubirous in 1858 in Lourdes, France.
#   ✅ Gold     : Saint Bernadette Soubirous
#
# Q2: What is in front of the Notre Dame Main Building?
#   🤖 Predicted: A copper statue of Christ with arms upraised with the legend "Venite Ad Me Omnes" is in front of the Notre Dame Main Building.
#   ✅ Gold     : a copper statue of Christ
#
# Q3: The Basilica of the Sacred heart at Notre Dame is beside to which structure?
#   🤖 Predicted: The Basilica of the Sacred heart at Notre Dame is beside the Main Building.
#   ✅ Gold     : the Main Building
#
# Q4: What is the Grotto at Notre Dame?
#   🤖 Predicted: The Grotto at Notre Dame is a Marian place of prayer and reflection, a replica of the grotto at Lourdes, France.
#   ✅ Gold     : a Marian place of prayer and reflection
#
# Q5: What sits on top of the Main Building at Notre Dame?
#   🤖 Predicted: A golden statue of the Virgin Mary sits on top of the Main Building at Notre Dame.
#   ✅ Gold     : a golden statue of the Virgin Mary
#
# Q6: When did the Scholastic Magazine of Notre dame begin publishing?
#   🤖 Predicted: The Scholastic Magazine of Notre Dame began publishing in September 1876.
#   ✅ Gold     : September 1876
#
# Q7: How often is Notre Dame's the Juggler published?
#   🤖 Predicted: The Juggler is published twice a year.
#   ✅ Gold     : twice
#
# Q8: What is the daily student paper at Notre Dame called?
#   🤖 Predicted: The daily student paper at Notre Dame is called The Observer.
#   ✅ Gold     : The Observer
#
# Q9: How many student news papers are found at Notre Dame?
#   🤖 Predicted: There are 3 student news papers at Notre Dame.
#   ✅ Gold     : three
#
# Q10: In what year did the student paper Common Sense begin publication at Notre Dame?
#   🤖 Predicted: The student paper Common Sense began publication at Notre Dame in 1987.
#   ✅ Gold     : 1987
#
# Q11: Where is the headquarters of the Congregation of the Holy Cross?
#   🤖 Predicted: The headquarters of the Congregation of the Holy Cross is in Rome.
#   ✅ Gold     : Rome
#
# Q12: What is the primary seminary of the Congregation of the Holy Cross?
#   🤖 Predicted: The primary seminary of the Congregation of the Holy Cross is Moreau Seminary.
#   ✅ Gold     : Moreau Seminary
#
# Q13: What is the oldest structure at Notre Dame?
#   🤖 Predicted: Old College, the oldest building on campus, is the oldest structure at Notre Dame.
#   ✅ Gold     : Old College
#
# Q14: What individuals live at Fatima House at Notre Dame?
#   🤖 Predicted: Individuals who live at Fatima House at Notre Dame are retired priests and brothers.
#   ✅ Gold     : Retired priests and brothers
#
# Q15: Which prize did Frederick Buechner create?
#   🤖 Predicted: Frederick Buechner created the Buechner Prize for Preaching.
#   ✅ Gold     : Buechner Prize for Preaching
#
# Q16: How many BS level degrees are offered in the College of Engineering at Notre Dame?
#   🤖 Predicted: The College of Engineering at Notre Dame offers 8 BS level degrees.
#   ✅ Gold     : eight
#
# Q17: In what year was the College of Engineering at Notre Dame formed?
#   🤖 Predicted: The College of Engineering at Notre Dame was formed in 1920.
#   ✅ Gold     : 1920
#
# Q18: Before the creation of the College of Engineering similar studies were carried out at which Notre Dame college?
#   🤖 Predicted: Early courses in civil and mechanical engineering were a part of the College of Science since the 1870s.
#   ✅ Gold     : the College of Science
#
# Q19: How many departments are within the Stinson-Remick Hall of Engineering?
#   🤖 Predicted: There are 5 departments within the Stinson-Remick Hall of Engineering.
#   ✅ Gold     : five
#
# Q20: The College of Science began to offer civil engineering courses beginning at what time at Notre Dame?
#   🤖 Predicted: The College of Science began to offer civil engineering courses in the 1870s.
#   ✅ Gold     : the 1870s
#
# Q21: What entity provides help with the management of time for new students at Notre Dame?
#   🤖 Predicted: The entity that provides help with the management of time for new students at Notre Dame is the First Year of Studies program.
#   ✅ Gold     : Learning Resource Center
#
# Q22: How many colleges for undergraduates are at Notre Dame?
#   🤖 Predicted: There are 5 undergraduate colleges at Notre Dame.
#   ✅ Gold     : five
#
# Q23: What was created at Notre Dame in 1962 to assist first year students?
#   🤖 Predicted: The First Year of Studies program was established in 1962.
#   ✅ Gold     : The First Year of Studies program
#
# Q24: Which organization declared the First Year of Studies program at Notre Dame "outstanding?"
#   🤖 Predicted: The First Year of Studies program at Notre Dame was recognized as "outstanding" by U.S. News & World Report.
#   ✅ Gold     : U.S. News & World Report
#
# Q25: The granting of Doctorate degrees first occurred in what year at Notre Dame?
#   🤖 Predicted: The granting of Doctorate degrees first occurred in 1897 at Notre Dame.
#   ✅ Gold     : 1924
#
# Q26: What type of degree is an M.Div.?
#   🤖 Predicted: An M.Div. is a Master of Divinity degree.
#   ✅ Gold     : Master of Divinity
#
# Q27: In what year was a Master of Arts course first offered at Notre Dame?
#   🤖 Predicted: A Master of Arts course first offered at Notre Dame was in the 1854–1855 academic year.
#   ✅ Gold     : Alliance for Catholic Education
#
# Q28: Which department at Notre Dame is the only one to not offer a PhD program?
#   🤖 Predicted: The only department at Notre Dame to not offer a PhD program is the Department of Theology.
#   ✅ Gold     : 1854
#
# Q29: Which program at Notre Dame offers a Master of Education degree?
#   🤖 Predicted: The Alliance for Catholic Education program offers a Master of Education program.
#   ✅ Gold     : Department of Pre-Professional Studies
#
# Q30: What institute at Notre Dame studies  the reasons for violent conflict?
#   🤖 Predicted: The Joan B. Kroc Institute for International Peace Studies studies the reasons for violent conflict.
#   ✅ Gold     : Joan B. Kroc Institute for International Peace Studies
#
# Q31: What is the title of Notre Dame's Theodore Hesburgh?
#   🤖 Predicted: The title of Notre Dame's Theodore Hesburgh is President Emeritus.
#   ✅ Gold     : President Emeritus of the University of Notre Dame
#
# Q32: In what year was the Joan B. Kroc Institute for International Peace Studies founded?
#   🤖 Predicted: The Joan B. Kroc Institute for International Peace Studies was founded in 1986.
#   ✅ Gold     : 1986
#
# Q33: To whom was John B. Kroc married?
#   🤖 Predicted: John B. Kroc was married to Joan B. Kroc.
#   ✅ Gold     : Ray Kroc
#
# Q34: What company did Ray Kroc own?
#   🤖 Predicted: Ray Kroc owned McDonald's.
#   ✅ Gold     : McDonald's
#
# Q35: How many stories tall is the main library at Notre Dame?
#   🤖 Predicted: The main library at Notre Dame is 14 stories tall.
#   ✅ Gold     : 14
#
# Q36: What is the name of the main library at Notre Dame?
#   🤖 Predicted: The main library at Notre Dame is the Theodore M. Hesburgh Library.
#   ✅ Gold     : Theodore M. Hesburgh Library
#
# Q37: In what year was the Theodore M. Hesburgh Library at Notre Dame finished?
#   🤖 Predicted: The Theodore M. Hesburgh Library at Notre Dame was finished in 1963.
#   ✅ Gold     : 1963
#
# Q38: Which artist created the mural on the Theodore M. Hesburgh Library?
#   🤖 Predicted: Millard Sheets created the mural on the Theodore M. Hesburgh Library.
#   ✅ Gold     : Millard Sheets
#
# Q39: What is a common name to reference the mural created by Millard Sheets at Notre Dame?
#   🤖 Predicted: The mural created by Millard Sheets at Notre Dame is commonly known as "Touchdown Jesus".
#   ✅ Gold     : Touchdown Jesus

# %% [markdown]
# ### Experiments
#
# Okay so the previous code was all about checking the code and our technique. now, we will try to run experiments, same as we did before and compare and contrast and document their results

# %% [markdown]
# # K16Q5

# %%
#driver code:
agent = Agent2(context_map)
agent.generate_Dataset_prompt(k=16, q=5)
# agent.print_current_prompt()
agent.chunk_current_prompt(max_words_per_chunk=700)
agent.map_questions_to_chunks()
agent.construct_individual_prompts_from_assignments()
agent.print_chunks()
# agent.run_all_chunks()
agent.extract_questions_and_answers()
# agent.print_parsed_qa_pairs()
agent.print_qa_pair_comparison()
# Out:
# =======================================================================PRINTING CHUNKED PROMPTS======================================================================
#
# 🧠 Prompt Chunk 1:
# Answer these questions as precisely as you can, in as minimum words as you can
# Format your answers with 'A1:', 'A2:', etc. at the beginning of each answer
# If you cannot find enough information in the provided context to answer a question, respond with 'Not specified'. Do NOT guess.
# Q1: To whom did the Virgin Mary allegedly appear in 1858 in Lourdes France?
# Q2: What is in front of the Notre Dame Main Building?
# Q3: The Basilica of the Sacred heart at Notre Dame is beside to which structure?
# Q4: What is the Grotto at Notre Dame?
# Q5: What sits on top of the Main Building at Notre Dame?
# Q6: When did the Scholastic Magazine of Notre dame begin publishing?
# Q7: How often is Notre Dame's the Juggler published?
# Q8: What is the daily student paper at Notre Dame called?
# Q9: How many student news papers are found at Notre Dame?
# Q10: In what year did the student paper Common Sense begin publication at Notre Dame?
# Q11: Where is the headquarters of the Congregation of the Holy Cross?
# Q12: What is the primary seminary of the Congregation of the Holy Cross?
# Q13: What is the oldest structure at Notre Dame?
# Q14: What individuals live at Fatima House at Notre Dame?
# Q15: Which prize did Frederick Buechner create?
# Q16: How many BS level degrees are offered in the College of Engineering at Notre Dame?
# Q17: Before the creation of the College of Engineering similar studies were carried out at which Notre Dame college?
# Q18: How many departments are within the Stinson-Remick Hall of Engineering?
# Q19: The College of Science began to offer civil engineering courses beginning at what time at Notre Dame?
# Q20: What entity provides help with the management of time for new students at Notre Dame?
# Q21: What was created at Notre Dame in 1962 to assist first year students?
# Q22: Which organization declared the First Year of Studies program at Notre Dame "outstanding?"
# Q23: What type of degree is an M.Div.?
# Q24: In what year was a Master of Arts course first offered at Notre Dame?
# Q25: Forbes.com placed Notre Dame at what position compared to other US research universities?
# Q26: Which individual worked on projects at Notre Dame that eventually created neoprene?
# Q27: What percentage of students at Notre Dame are the children of former Notre Dame students?
#
# from this context:
# Architecturally, the school has a Catholic character. Atop the Main Building's gold dome is a golden statue of the Virgin Mary. Immediately in front of the Main Building and facing it, is a copper statue of Christ with arms upraised with the legend "Venite Ad Me Omnes". Next to the Main Building is the Basilica of the Sacred Heart. Immediately behind the basilica is the Grotto, a Marian place of prayer and reflection. It is a replica of the grotto at Lourdes, France where the Virgin Mary reputedly appeared to Saint Bernadette Soubirous in 1858. At the end of the main drive (and in a direct line that connects through 3 statues and the Gold Dome), is a simple, modern stone statue of Mary. As at most other universities, Notre Dame's students run a number of news media outlets. The nine student-run outlets include three newspapers, both a radio and television station, and several magazines and journals. Begun as a one-page journal in September 1876, the Scholastic magazine is issued twice monthly and claims to be the oldest continuous collegiate publication in the United States. The other magazine, The Juggler, is released twice a year and focuses on student literature and artwork. The Dome yearbook is published annually. The newspapers have varying publication interests, with The Observer published daily and mainly reporting university and other news, and staffed by students from both Notre Dame and Saint Mary's College. Unlike Scholastic and The Dome, The Observer is an independent publication and does not have a faculty advisor or any editorial oversight from the University. In 1987, when some students believed that The Observer began to show a conservative bias, a liberal newspaper, Common Sense was published. Likewise, in 2003, when other students believed that the paper showed a liberal bias, the conservative paper Irish Rover went into production. Neither paper is published as often as The Observer; however, all three are distributed to all students. Finally, in Spring 2008 an undergraduate journal for political science research, Beyond Politics, made its debut. The university is the major seat of the Congregation of Holy Cross (albeit not its official headquarters, which are in Rome). Its main seminary, Moreau Seminary, is located on the campus across St. Joseph lake from the Main Building. Old College, the oldest building on campus and located near the shore of St. Mary lake, houses undergraduate seminarians. Retired priests and brothers reside in Fatima House (a former retreat center), Holy Cross House, as well as Columba Hall near the Grotto. The university through the Moreau Seminary has ties to theologian Frederick Buechner. While not Catholic, Buechner has praised writers from Notre Dame and Moreau Seminary created a Buechner Prize for Preaching. The College of Engineering was established in 1920, however, early courses in civil and mechanical engineering were a part of the College of Science since the 1870s. Today the college, housed in the Fitzpatrick, Cushing, and Stinson-Remick Halls of Engineering, includes five departments of study – aerospace and mechanical engineering, chemical and biomolecular engineering, civil engineering and geological sciences, computer science and engineering, and electrical engineering – with eight B.S. degrees offered. Additionally, the college offers five-year dual degree programs with the Colleges of Arts and Letters and of Business awarding additional B.A. and Master of Business Administration (MBA) degrees, respectively. All of Notre Dame's undergraduate students are a part of one of the five undergraduate colleges at the school or are in the First Year of Studies program. The First Year of Studies program was established in 1962 to guide incoming freshmen in their first year at the school before they have declared a major. Each student is given an academic advisor from the program who helps them to choose classes that give them exposure to any major in which they are interested.  ...
# -----------------------------------------
# Length: 6687 characters, approximately 1094 tokens
# ============================================================================================================================================================
#
# 🧠 Prompt Chunk 2:
# Answer these questions as precisely as you can, in as minimum words as you can
# Format your answers with 'A1:', 'A2:', etc. at the beginning of each answer
# If you cannot find enough information in the provided context to answer a question, respond with 'Not specified'. Do NOT guess.
# Q1: In what year was the College of Engineering at Notre Dame formed?
# Q2: How many colleges for undergraduates are at Notre Dame?
# Q3: Which department at Notre Dame is the only one to not offer a PhD program?
# Q4: To whom was John B. Kroc married?
# Q5: What person was the Director of the Science Museum at Notre Dame in the late 19th century?
# Q6: What was the lifespan of John Augustine Zahm?
# Q7: What program did John Augustine Zahm come to co-direct at Nore Dame?
# Q8: What book did John Zahm write in 1896?
# Q9: What professorship did Father Josh Carrier hold at Notre Dame?
# Q10: In what year did Albert Zahm begin comparing aeronatical models at Notre Dame?
# Q11: Which professor sent the first wireless message in the USA?
# Q12: In what year did Jerome Green send his first wireless message?
# -----------------------------------------
# Length: 6589 characters, approximately 1075 tokens
# ============================================================================================================================================================
#
# 🧠 Prompt Chunk 3:
# Answer these questions as precisely as you can, in as minimum words as you can
# Format your answers with 'A1:', 'A2:', etc. at the beginning of each answer
# If you cannot find enough information in the provided context to answer a question, respond with 'Not specified'. Do NOT guess.
# Q1: The granting of Doctorate degrees first occurred in what year at Notre Dame?
# Q2: Which program at Notre Dame offers a Master of Education degree?
# Q3: What institute at Notre Dame studies  the reasons for violent conflict?
# Q4: What is the title of Notre Dame's Theodore Hesburgh?
# Q5: In what year was the Joan B. Kroc Institute for International Peace Studies founded?
# Q6: What company did Ray Kroc own?
# Q7: How many stories tall is the main library at Notre Dame?
# Q8: What is the name of the main library at Notre Dame?
# Q9: In what year was the Theodore M. Hesburgh Library at Notre Dame finished?
# Q10: Which artist created the mural on the Theodore M. Hesburgh Library?
# Q11: What is a common name to reference the mural created by Millard Sheets at Notre Dame?
# Q12: How many incoming students did Notre Dame admit in fall 2015?
# Q13: What percentage of students were admitted to Notre Dame in fall 2015?
# Q14: Where does Notre Dame rank in terms of academic profile among research universities in the US?
# Q15: What percentage of students at Notre Dame participated in the Early Action program?
# Q16: How many miles does the average student at Notre Dame travel to study there?
# Q17: Where did U.S. News & World Report rank Notre Dame in its 2015-2016 university rankings?
# Q18: The undergrad school at the Mendoza College of Business was ranked where according to BusinessWeek?
# Q19: In 2014 what entity named Notre Dame 10th best of all American universities?
# Q20: What percentage of Notre Dame students decide to study abroad?
# Q21: When did study of a germ-free-life begin at Notre Dame?
# Q22: What does the Kroc Institute at Notre Dame focus on?
#
# from this context:
# Engineering in its early stages of growth, before a formal graduate school education was developed with a thesis not required to receive the degrees. This changed in 1924 with formal requirements developed for graduate degrees, including offering Doctorate (PhD) degrees. Today each of the five colleges offer graduate education. Most of the departments from the College of Arts and Letters offer PhD programs, while a professional Master of Divinity (M.Div.) program also exists. All of the departments in the College of Science offer PhD programs, except for the Department of Pre-Professional Studies. The School of Architecture offers a Master of Architecture, while each of the departments of the College of Engineering offer PhD programs. The College of Business offers multiple professional programs including MBA and Master of Science in Accountancy programs. It also operates facilities in Chicago and Cincinnati for its executive MBA program. Additionally, the Alliance for Catholic Education program offers a Master of Education program where students study at the university during the summer and teach in Catholic elementary schools, middle schools, and high schools across the Southern United States for two school years. The Joan B. Kroc Institute for International Peace Studies at the University of Notre Dame is dedicated to research, education and outreach on the causes of violent conflict and the conditions for sustainable peace. It offers PhD, Master's, and undergraduate degrees in peace studies. It was founded in 1986 through the donations of Joan B. Kroc, the widow of McDonald's owner Ray Kroc. The institute was inspired by the vision of the Rev. Theodore M. Hesburgh CSC, President Emeritus of the University of Notre Dame. The institute has contributed to international policy discussions about peace building practices. The library system of the university is divided between the main library and each of the colleges and schools. The main building is the 14-story Theodore M. Hesburgh Library, completed in 1963, which is the third building to house the main collection of books. The front of the library is adorned with the Word of Life mural designed by artist Millard Sheets. This mural is popularly known as "Touchdown Jesus" because of its proximity to Notre Dame Stadium and Jesus' arms appearing to make the signal for a touchdown. Notre Dame is known for its competitive admissions, with the incoming class enrolling in fall 2015 admitting 3,577 from a pool of 18,156 (19.7%). The academic profile of the enrolled class continues to rate among the top 10 to 15 in the nation for national research universities. The university practices a non-restrictive early action policy that allows admitted students to consider admission to Notre Dame as well as any other colleges to which they were accepted. 1,400 of the 3,577 (39.1%) were admitted under the early action plan. Admitted students came from 1,311 high schools and the average student traveled more than 750 miles to Notre Dame, making it arguably the most representative university in the United States. While all entering students begin in the College of the First Year of Studies, 25% have indicated they plan to study in the liberal arts or social sciences, 24% in engineering, 24% in business, 24% in science, and 3% in architecture. In 2015-2016, Notre Dame ranked 18th overall among "national universities" in the United States in U.S. News & World Report's Best Colleges 2016. In 2014, USA Today ranked Notre Dame 10th overall for American universities based on data from College Factual. Forbes.com's America's Best Colleges ranks Notre Dame 13th among colleges in the United States in 2015, 8th among Research Universities, and 1st in the Midwest. U.S. News & World Report also lists Notre Dame Law School as 22nd overall. BusinessWeek ranks Mendoza College of Business undergraduate school as 1st overall. It ranks the MBA program as 20th overall. The Philosophical Gourmet Report ranks Notre  ...
# -----------------------------------------
# Length: 6407 characters, approximately 1039 tokens
# ============================================================================================================================================================
#
# 🧠 Prompt Chunk 4:
# Answer these questions as precisely as you can, in as minimum words as you can
# Format your answers with 'A1:', 'A2:', etc. at the beginning of each answer
# If you cannot find enough information in the provided context to answer a question, respond with 'Not specified'. Do NOT guess.
# Q1: How many teams participate in the Notre Dame Bookstore Basketball tournament?
# Q2: For what cause is money raised at the Bengal Bouts tournament at Notre Dame?
#
# from this context:
# Dame student body consisted of 12,179 students, with 8,448 undergraduates, 2,138 graduate and professional and 1,593 professional (Law, M.Div., Business, M.Ed.) students. Around 21–24% of students are children of alumni, and although 37% of students come from the Midwestern United States, the student body represents all 50 states and 100 countries. As of March 2007[update] The Princeton Review ranked the school as the fifth highest 'dream school' for parents to send their children. As of March 2015[update] The Princeton Review ranked Notre Dame as the ninth highest. The school has been previously criticized for its lack of diversity, and The Princeton Review ranks the university highly among schools at which "Alternative Lifestyles [are] Not an Alternative." It has also been commended by some diversity oriented publications; Hispanic Magazine in 2004 ranked the university ninth on its list of the top–25 colleges for Latinos, and The Journal of Blacks in Higher Education recognized the university in 2006 for raising enrollment of African-American students. With 6,000 participants, the university's intramural sports program was named in 2004 by Sports Illustrated as the best program in the country, while in 2007 The Princeton Review named it as the top school where "Everyone Plays Intramural Sports." The annual Bookstore Basketball tournament is the largest outdoor five-on-five tournament in the world with over 700 teams participating each year, while the Notre Dame Men's Boxing Club hosts the annual Bengal Bouts tournament that raises money for the Holy Cross Missions in Bangladesh.
# -----------------------------------------
# Length: 2074 characters, approximately 324 tokens
# ============================================================================================================================================================
# =======================================================================END OF CHUNKS======================================================================
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_deprecation.py:131: FutureWarning: 'post' (from 'huggingface_hub.inference._client') is deprecated and will be removed from version '0.31.0'. Making direct POST requests to the inference server is not supported anymore. Please use task methods instead (e.g. `InferenceClient.chat_completion`). If your use case is not supported, please open an issue in https://github.com/huggingface/huggingface_hub.
#   warnings.warn(warning_message, FutureWarning)
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_http.py in hf_raise_for_status(response, endpoint_name)
#     408     try:
# --> 409         response.raise_for_status()
#     410     except HTTPError as e:
#
# /usr/local/lib/python3.11/dist-packages/requests/models.py in raise_for_status(self)
#    1023         if http_error_msg:
# -> 1024             raise HTTPError(http_error_msg, response=self)
#    1025
#
# HTTPError: 402 Client Error: Payment Required for url: https://router.huggingface.co/hf-inference/models/mistralai/Mistral-7B-Instruct-v0.3
#
# The above exception was the direct cause of the following exception:
#
# HfHubHTTPError                            Traceback (most recent call last)
# <ipython-input-5-48062357f2ed> in <cell line: 0>()
#       7 agent.construct_individual_prompts_from_assignments()
#       8 agent.print_chunks()
# ----> 9 agent.run_all_chunks()
#      10 agent.extract_questions_and_answers()
#      11 # agent.print_parsed_qa_pairs()
#
# <ipython-input-2-259988e07c46> in run_all_chunks(self, verbose)
#     180         self.chunk_responses = []
#     181         for idx, prompt in enumerate(self.chunked_prompts, 1):
# --> 182             response = self.generate_response(prompt)
#     183             self.chunk_responses.append(response)
#     184             if verbose:
#
# <ipython-input-2-259988e07c46> in generate_response(self, prompt)
#      27
#      28     def generate_response(self, prompt): #can use this function to get answer from 1 chunk, then 2nd chunk etc, all chunks and then proceed. with normal
# ---> 29         return self.llm(prompt)
#      30
#      31     def get_context_questions(self, k=2, q=4):
#
# /usr/local/lib/python3.11/dist-packages/langchain_core/_api/deprecation.py in warning_emitting_wrapper(*args, **kwargs)
#     189                 warned = True
#     190                 emit_warning()
# --> 191             return wrapped(*args, **kwargs)
#     192
#     193         async def awarning_emitting_wrapper(*args: Any, **kwargs: Any) -> Any:
#
# /usr/local/lib/python3.11/dist-packages/langchain_core/language_models/llms.py in __call__(self, prompt, stop, callbacks, tags, metadata, **kwargs)
#    1313             raise ValueError(msg)  # noqa: TRY004
#    1314         return (
# -> 1315             self.generate(
#    1316                 [prompt],
#    1317                 stop=stop,
#
# /usr/local/lib/python3.11/dist-packages/langchain_core/language_models/llms.py in generate(self, prompts, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     969                 )
#     970             ]
# --> 971             return self._generate_helper(
#     972                 prompts,
#     973                 stop,
#
# /usr/local/lib/python3.11/dist-packages/langchain_core/language_models/llms.py in _generate_helper(self, prompts, stop, run_managers, new_arg_supported, **kwargs)
#     788         try:
#     789             output = (
# --> 790                 self._generate(
#     791                     prompts,
#     792                     stop=stop,
#
# /usr/local/lib/python3.11/dist-packages/langchain_core/language_models/llms.py in _generate(self, prompts, stop, run_manager, **kwargs)
#    1543         for prompt in prompts:
#    1544             text = (
# -> 1545                 self._call(prompt, stop=stop, run_manager=run_manager, **kwargs)
#    1546                 if new_arg_supported
#    1547                 else self._call(prompt, stop=stop, **kwargs)
#
# /usr/local/lib/python3.11/dist-packages/langchain_community/llms/huggingface_hub.py in _call(self, prompt, stop, run_manager, **kwargs)
#     136         parameters = {**_model_kwargs, **kwargs}
#     137
# --> 138         response = self.client.post(
#     139             json={"inputs": prompt, "parameters": parameters}, task=self.task
#     140         )
#
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_deprecation.py in inner_f(*args, **kwargs)
#     130                 warning_message += " " + message
#     131             warnings.warn(warning_message, FutureWarning)
# --> 132             return f(*args, **kwargs)
#     133
#     134         return inner_f
#
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/inference/_client.py in post(self, json, data, model, task, stream)
#     303         url = provider_helper._prepare_url(self.token, mapped_model)  # type: ignore[arg-type]
#     304         headers = provider_helper._prepare_headers(self.headers, self.token)  # type: ignore[arg-type]
# --> 305         return self._inner_post(
#     306             request_parameters=RequestParameters(
#     307                 url=url,
#
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/inference/_client.py in _inner_post(self, request_parameters, stream)
#     355
#     356         try:
# --> 357             hf_raise_for_status(response)
#     358             return response.iter_lines() if stream else response.content
#     359         except HTTPError as error:
#
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_http.py in hf_raise_for_status(response, endpoint_name)
#     480         # Convert `HTTPError` into a `HfHubHTTPError` to display request information
#     481         # as well (request id and/or server error message)
# --> 482         raise _format(HfHubHTTPError, str(e), response) from e
#     483
#     484
#
# HfHubHTTPError: 402 Client Error: Payment Required for url: https://router.huggingface.co/hf-inference/models/mistralai/Mistral-7B-Instruct-v0.3 (Request ID: Root=1-6813114f-7effc2a3650cc66360af9d47;b40fb9c7-a353-4ea3-a555-5cb4f3256024)
#
# You have exceeded your monthly included credits for Inference Providers. Subscribe to PRO to get 20x more monthly included credits.

# %%
agent = Agent2(context_map)
agent.generate_Dataset_prompt(k=16, q=5)
# agent.print_current_prompt()
agent.chunk_current_prompt(max_words_per_chunk=700)
agent.map_questions_to_chunks()
agent.construct_individual_prompts_from_assignments()
agent.print_qa_pairs()
# Out:
# Question | Predicted Answer | Gold Answer
# --------------------------------------------------------------------------------
# Q1: To whom did the Virgin Mary allegedly appear in 1858 in Lourdes France?
#   ✅ Gold     : Saint Bernadette Soubirous
#
# Q2: What is in front of the Notre Dame Main Building?
#   ✅ Gold     : a copper statue of Christ
#
# Q3: The Basilica of the Sacred heart at Notre Dame is beside to which structure?
#   ✅ Gold     : the Main Building
#
# Q4: What is the Grotto at Notre Dame?
#   ✅ Gold     : a Marian place of prayer and reflection
#
# Q5: What sits on top of the Main Building at Notre Dame?
#   ✅ Gold     : a golden statue of the Virgin Mary
#
# Q6: When did the Scholastic Magazine of Notre dame begin publishing?
#   ✅ Gold     : September 1876
#
# Q7: How often is Notre Dame's the Juggler published?
#   ✅ Gold     : twice
#
# Q8: What is the daily student paper at Notre Dame called?
#   ✅ Gold     : The Observer
#
# Q9: How many student news papers are found at Notre Dame?
#   ✅ Gold     : three
#
# Q10: In what year did the student paper Common Sense begin publication at Notre Dame?
#   ✅ Gold     : 1987
#
# Q11: Where is the headquarters of the Congregation of the Holy Cross?
#   ✅ Gold     : Rome
#
# Q12: What is the primary seminary of the Congregation of the Holy Cross?
#   ✅ Gold     : Moreau Seminary
#
# Q13: What is the oldest structure at Notre Dame?
#   ✅ Gold     : Old College
#
# Q14: What individuals live at Fatima House at Notre Dame?
#   ✅ Gold     : Retired priests and brothers
#
# Q15: Which prize did Frederick Buechner create?
#   ✅ Gold     : Buechner Prize for Preaching
#
# Q16: How many BS level degrees are offered in the College of Engineering at Notre Dame?
#   ✅ Gold     : eight
#
# Q17: In what year was the College of Engineering at Notre Dame formed?
#   ✅ Gold     : 1920
#
# Q18: Before the creation of the College of Engineering similar studies were carried out at which Notre Dame college?
#   ✅ Gold     : the College of Science
#
# Q19: How many departments are within the Stinson-Remick Hall of Engineering?
#   ✅ Gold     : five
#
# Q20: The College of Science began to offer civil engineering courses beginning at what time at Notre Dame?
#   ✅ Gold     : the 1870s
#
# Q21: What entity provides help with the management of time for new students at Notre Dame?
#   ✅ Gold     : Learning Resource Center
#
# Q22: How many colleges for undergraduates are at Notre Dame?
#   ✅ Gold     : five
#
# Q23: What was created at Notre Dame in 1962 to assist first year students?
#   ✅ Gold     : The First Year of Studies program
#
# Q24: Which organization declared the First Year of Studies program at Notre Dame "outstanding?"
#   ✅ Gold     : U.S. News & World Report
#
# Q25: The granting of Doctorate degrees first occurred in what year at Notre Dame?
#   ✅ Gold     : 1924
#
# Q26: What type of degree is an M.Div.?
#   ✅ Gold     : Master of Divinity
#
# Q27: Which program at Notre Dame offers a Master of Education degree?
#   ✅ Gold     : Alliance for Catholic Education
#
# Q28: In what year was a Master of Arts course first offered at Notre Dame?
#   ✅ Gold     : 1854
#
# Q29: Which department at Notre Dame is the only one to not offer a PhD program?
#   ✅ Gold     : Department of Pre-Professional Studies
#
# Q30: What institute at Notre Dame studies  the reasons for violent conflict?
#   ✅ Gold     : Joan B. Kroc Institute for International Peace Studies
#
# Q31: What is the title of Notre Dame's Theodore Hesburgh?
#   ✅ Gold     : President Emeritus of the University of Notre Dame
#
# Q32: In what year was the Joan B. Kroc Institute for International Peace Studies founded?
#   ✅ Gold     : 1986
#
# Q33: To whom was John B. Kroc married?
#   ✅ Gold     : Ray Kroc
#
# Q34: What company did Ray Kroc own?
#   ✅ Gold     : McDonald's
#
# Q35: How many stories tall is the main library at Notre Dame?
#   ✅ Gold     : 14
#
# Q36: What is the name of the main library at Notre Dame?
#   ✅ Gold     : Theodore M. Hesburgh Library
#
# Q37: In what year was the Theodore M. Hesburgh Library at Notre Dame finished?
#   ✅ Gold     : 1963
#
# Q38: Which artist created the mural on the Theodore M. Hesburgh Library?
#   ✅ Gold     : Millard Sheets
#
# Q39: What is a common name to reference the mural created by Millard Sheets at Notre Dame?
#   ✅ Gold     : Touchdown Jesus
#
# Q40: How many incoming students did Notre Dame admit in fall 2015?
#   ✅ Gold     : 3,577
#
# Q41: What percentage of students were admitted to Notre Dame in fall 2015?
#   ✅ Gold     : 19.7%
#
# Q42: Where does Notre Dame rank in terms of academic profile among research universities in the US?
#   ✅ Gold     : the top 10 to 15 in the nation
#
# Q43: What percentage of students at Notre Dame participated in the Early Action program?
#   ✅ Gold     : 39.1%
#
# Q44: How many miles does the average student at Notre Dame travel to study there?
#   ✅ Gold     : more than 750 miles
#
# Q45: Where did U.S. News & World Report rank Notre Dame in its 2015-2016 university rankings?
#   ✅ Gold     : 18th overall
#
# Q46: Forbes.com placed Notre Dame at what position compared to other US research universities?
#   ✅ Gold     : 8th
#
# Q47: The undergrad school at the Mendoza College of Business was ranked where according to BusinessWeek?
#   ✅ Gold     : 1st overall
#
# Q48: In 2014 what entity named Notre Dame 10th best of all American universities?
#   ✅ Gold     : USA Today
#
# Q49: What percentage of Notre Dame students decide to study abroad?
#   ✅ Gold     : 57.6%
#
# Q50: What person was the Director of the Science Museum at Notre Dame in the late 19th century?
#   ✅ Gold     : Father Joseph Carrier, C.S.C.
#
# Q51: What was the lifespan of John Augustine Zahm?
#   ✅ Gold     : 1851–1921
#
# Q52: What program did John Augustine Zahm come to co-direct at Nore Dame?
#   ✅ Gold     : the Science Department
#
# Q53: What book did John Zahm write in 1896?
#   ✅ Gold     : Evolution and Dogma
#
# Q54: What professorship did Father Josh Carrier hold at Notre Dame?
#   ✅ Gold     : Professor of Chemistry and Physics
#
# Q55: In what year did Albert Zahm begin comparing aeronatical models at Notre Dame?
#   ✅ Gold     : 1882
#
# Q56: Which professor sent the first wireless message in the USA?
#   ✅ Gold     : Professor Jerome Green
#
# Q57: In what year did Jerome Green send his first wireless message?
#   ✅ Gold     : Around 1899
#
# Q58: Which individual worked on projects at Notre Dame that eventually created neoprene?
#   ✅ Gold     : Father Julius Nieuwland
#
# Q59: What did the brother of John Zahm construct at Notre Dame?
#   ✅ Gold     : an early wind tunnel
#
# Q60: Work on a germ-free-life ended up in the creation of which Notre Dame institute?
#   ✅ Gold     : The Lobund Institute
#
# Q61: Around what time did Lobund of Notre Dame become independent?
#   ✅ Gold     : the 1940s
#
# Q62: In what year did Lobund at Notre Dame become an Institute?
#   ✅ Gold     : 1950
#
# Q63: The Lobund Institute was merged into the Department of Biology at Notre Dame in what year?
#   ✅ Gold     : 1958
#
# Q64: When did study of a germ-free-life begin at Notre Dame?
#   ✅ Gold     : 1928
#
# Q65: Gurian created what in 1939 at Notre Dame?
#   ✅ Gold     : The Review of Politics
#
# Q66: What was the Review of Politics inspired by?
#   ✅ Gold     : German Catholic journals
#
# Q67: Over how many years did Gurian edit the Review of Politics at Notre Dame?
#   ✅ Gold     : 44
#
# Q68: Thomas Stritch was an editor of which publican from Notre Dame?
#   ✅ Gold     : Review of Politics
#
# Q69: Who was the president of Notre Dame in 2012?
#   ✅ Gold     : John Jenkins
#
# Q70: The Kellogg Institute for International Studies is part of which university?
#   ✅ Gold     : Notre Dame
#
# Q71: What does the Kroc Institute at Notre Dame focus on?
#   ✅ Gold     : International Peace studies
#
# Q72: In what year did Notre Dame begin to host the Global Adaptation Index?
#   ✅ Gold     : 2013
#
# Q73: What threat does the Global Adaptation Index study?
#   ✅ Gold     : climate change
#
# Q74: How many undergrads were attending Notre Dame in 2014?
#   ✅ Gold     : 8,448
#
# Q75: What percentage of students at Notre Dame are the children of former Notre Dame students?
#   ✅ Gold     : 21–24%
#
# Q76: How many teams participate in the Notre Dame Bookstore Basketball tournament?
#   ✅ Gold     : over 700
#
# Q77: For what cause is money raised at the Bengal Bouts tournament at Notre Dame?
#   ✅ Gold     : the Holy Cross Missions in Bangladesh
#
# Q78: How many students in total were at Notre Dame in 2014?
#   ✅ Gold     : 12,179

# %% [markdown]
# ### Fixing the parsing issue:

# %%
import re
from collections import defaultdict
from typing import List, Tuple


class Agent2:
    #same context overload notebook
    def __init__(self, context_map, model_name="mistralai/Mistral-7B-Instruct-v0.3", access_token="TOKEN-HERE"):
        self.context_map = context_map
        self.llm = HuggingFaceHub(
            repo_id=model_name,
            model_kwargs={"temperature": 0.3, "max_length": 200},
            huggingfacehub_api_token=access_token
        )
        self.current_prompt = None # NEW: ask user to input context and questions seperately. chunks will only be made of context.
        self.chunked_prompts = []
        self.chunk_responses = ['Answer these questions as precisely as you can, in as minimum words as you can\nFormat your answers with \'A1:\', \'A2:\', etc. at the beginning of each answer\nIf you cannot find enough information in the provided context to answer a question, respond with \'Not specified\'. Do NOT guess.\nQ1: To whom did the Virgin Mary allegedly appear in 1858 in Lourdes France?\nQ2: What is in front of the Notre Dame Main Building?\nQ3: The Basilica of the Sacred heart at Notre Dame is beside to which structure?\nQ4: What is the Grotto at Notre Dame?\nQ5: When did the Scholastic Magazine of Notre dame begin publishing?\nQ6: How often is Notre Dame\'s the Juggler published?\nQ7: What is the daily student paper at Notre Dame called?\nQ8: How many student news papers are found at Notre Dame?\nQ9: Where is the headquarters of the Congregation of the Holy Cross?\nQ10: What is the primary seminary of the Congregation of the Holy Cross?\n\n\nfrom this context:\nArchitecturally, the school has a Catholic character. Atop the Main Building\'s gold dome is a golden statue of the Virgin Mary. Immediately in front of the Main Building and facing it, is a copper statue of Christ with arms upraised with the legend "Venite Ad Me Omnes". Next to the Main Building is the Basilica of the Sacred Heart. Immediately behind the basilica is the Grotto, a Marian place of prayer and reflection. It is a replica of the grotto at Lourdes, France where the Virgin Mary reputedly appeared to Saint Bernadette Soubirous in 1858. At the end of the main drive (and in a direct line that connects through 3 statues and the Gold Dome), is a simple, modern stone statue of Mary. As at most other universities, Notre Dame\'s students run a number of news media outlets. The nine student-run outlets include three newspapers, both a radio and television station, and several magazines and journals. Begun as a one-page journal in September 1876, the Scholastic magazine is issued twice monthly and claims to be the oldest continuous collegiate publication in the United States. The other magazine, The Juggler, is released twice a year and focuses on student literature and artwork. The Dome yearbook is published annually. The newspapers have varying publication interests, with The Observer published daily and mainly reporting university and other news, and staffed by students from both Notre Dame and Saint Mary\'s College. Unlike Scholastic and The Dome, The Observer is an independent publication and does not have a faculty advisor or any editorial oversight from the University. In 1987, when some students believed that The Observer began to show a conservative bias, a liberal newspaper, Common Sense was published. Likewise, in 2003, when other students believed that the paper showed a liberal bias, the conservative paper Irish Rover went into production. Neither paper is published as often as The Observer; however, all three are distributed to all students. Finally, in Spring 2008 an undergraduate journal for political science research, Beyond Politics, made its debut. The university is the major seat of the Congregation of Holy Cross (albeit not its official headquarters, which are in Rome). Its main seminary, Moreau Seminary, is located on the campus across St. Joseph lake from the Main Building. Old College, the oldest building on campus and located near the shore of St. Mary lake, houses undergraduate seminarians. Retired priests live in Moreau Seminary.\n\nA1: The Virgin Mary allegedly appeared to Saint Bernadette Soubirous in 1858 in Lourdes, France.\nA2: A copper statue of Christ with arms upraised with the legend "Venite Ad Me Omnes" is in front of the Notre Dame Main Building.\nA3: The Basilica of the Sacred Heart is beside the Notre Dame Main Building.\nA4: The Grotto at Notre Dame is a replica of the grotto at Lourdes, France where the Virgin Mary allegedly appeared to Saint Bernadette Soubirous in 1858.\nA5: The Scholastic Magazine of Notre Dame began publishing in September 1876.\nA6: The Juggler is published twice a year.\nA7: The daily student paper at Notre Dame is called The Observer.\nA8: There are 3 student news papers found at Notre Dame.\nA9: The headquarters of the Congregation of the Holy Cross is in Rome.\nA10: The primary seminary of the Congregation of the Holy Cross is Moreau Seminary.',
 'Answer these questions as precisely as you can, in as minimum words as you can\nFormat your answers with \'A1:\', \'A2:\', etc. at the beginning of each answer\nIf you cannot find enough information in the provided context to answer a question, respond with \'Not specified\'. Do NOT guess.\nQ1: What individuals live at Fatima House at Notre Dame?\nQ2: How many BS level degrees are offered in the College of Engineering at Notre Dame?\nQ3: In what year was the College of Engineering at Notre Dame formed?\nQ4: Before the creation of the College of Engineering similar studies were carried out at which Notre Dame college?\nQ5: How many departments are within the Stinson-Remick Hall of Engineering?\nQ6: What entity provides help with the management of time for new students at Notre Dame?\nQ7: How many colleges for undergraduates are at Notre Dame?\nQ8: What was created at Notre Dame in 1962 to assist first year students?\nQ9: Which organization declared the First Year of Studies program at Notre Dame "outstanding?"\nQ10: What is the oldest structure at Notre Dame?\n\nfrom this context:\nand brothers reside in Fatima House (a former retreat center), Holy Cross House, as well as Columba Hall near the Grotto. The university through the Moreau Seminary has ties to theologian Frederick Buechner. While not Catholic, Buechner has praised writers from Notre Dame and Moreau Seminary created a Buechner Prize for Preaching. The College of Engineering was established in 1920, however, early courses in civil and mechanical engineering were a part of the College of Science since the 1870s. Today the college, housed in the Fitzpatrick, Cushing, and Stinson-Remick Halls of Engineering, includes five departments of study – aerospace and mechanical engineering, chemical and biomolecular engineering, civil engineering and geological sciences, computer science and engineering, and electrical engineering – with eight B.S. degrees offered. Additionally, the college offers five-year dual degree programs with the Colleges of Arts and Letters and of Business awarding additional B.A. and Master of Business Administration (MBA) degrees, respectively. All of Notre Dame\'s undergraduate students are a part of one of the five undergraduate colleges at the school or are in the First Year of Studies program. The First Year of Studies program was established in 1962 to guide incoming freshmen in their first year at the school before they have declared a major. Each student is given an academic advisor from the program who helps them to choose classes that give them exposure to any major in which they are interested. The program also includes a Learning Resource Center which provides time management, collaborative learning, and subject tutoring. This program has been recognized previously, by U.S. News & World Report, as outstanding.\n\nA1: Individuals who live at Fatima House at Notre Dame are brothers.\nA2: The College of Engineering at Notre Dame offers 8 BS level degrees.\nA3: The College of Engineering at Notre Dame was formed in 1920.\nA4: Before the creation of the College of Engineering, similar studies were carried out at the College of Science.\nA5: There are 5 departments within the Stinson-Remick Hall of Engineering.\nA6: The entity that provides help with the management of time for new students at Notre Dame is the First Year of Studies program.\nA7: There are 6 colleges for undergraduates at Notre Dame (including the First Year of Studies program).\nA8: The First Year of Studies program was created at Notre Dame in 1962.\nA9: The First Year of Studies program at Notre Dame was declared "outstanding" by U.S. News & World Report.\nA10: Old College is the oldest structure at Notre Dame.']
        # new variables for storing questions, chunks and gold answers respectively.
        self.current_context_chunks = []
        self.current_questions = []
        self.current_gold_answers = []
        # this is for chunk assignment to each question
        self.chunk_assignments = defaultdict(list)
        # for parsing and storing question answer pairs from chunk prompts:
        self.question_answer_map = {}

    def generate_response(self, prompt): #can use this function to get answer from 1 chunk, then 2nd chunk etc, all chunks and then proceed. with normal
        return self.llm(prompt)

    def get_context_questions(self, k=2, q=4):
      #same as context overload notebook
        contexts = []
        questions_answers = []
        selected_contexts = list(self.context_map.items())[:k]
        for context, qa_pairs in selected_contexts:
            contexts.append(context)
            selected_qa = qa_pairs[:q]
            questions_answers.append(selected_qa)
        return contexts, questions_answers

    def generate_Dataset_prompt(self, k=2, q=4):
        ''' This function generates and imitates a prompt from the dataset, later on, we will take questions and context as input from user.'''
        contexts, questions_answers_by_context = self.get_context_questions(k, q)
        combined_context = "\n\n".join(contexts)
        all_questions_answers = []
        for qa_pairs in questions_answers_by_context:
            all_questions_answers.extend(qa_pairs)
        # modified the prompt
        prompt_lines = [
            "Answer these questions as precisely as you can, in as minimum words as you can",
            "Format your answers with 'A1:', 'A2:', etc. at the beginning of each answer",
            "If you cannot find enough information in the provided context to answer a question, respond with 'Not specified'. Do NOT guess.",
        ]
        self.current_questions = []
        self.current_gold_answers = []
        for i, (question, answer) in enumerate(all_questions_answers, 1):
            self.current_questions.append(question)
            self.current_gold_answers.append(answer)
            prompt_lines.append(f"Q{i}: {question}")
        prompt_lines.append("\nfrom this context:")
        prompt_lines.append(combined_context)
        prompt = "\n".join(prompt_lines)
        self.current_prompt = prompt


    def extract_keywords(self, questions: List[str]) -> List[List[str]]:
        """
        Given a list of questions, extract a list of keywords for each question.
        """
        stopwords = set([
            "the", "is", "at", "which", "on", "in", "a", "an", "of", "to", "for", "with",
            "and", "by", "from", "what", "who", "when", "where", "how", "does", "do",
            "did", "was", "were", "has", "have", "had"
        ])
        all_keywords = []
        for question in questions:
            # Remove punctuation
            question_clean = re.sub(r'[^\w\s]', '', question)
            words = question_clean.lower().split()
            # Filter stopwords and small words
            keywords = [word for word in words if word not in stopwords and len(word) > 2]
            all_keywords.append(keywords)
        return all_keywords

    def map_questions_to_chunks(self) -> List[Tuple[str, List[str]]]:
        """
        Map each context chunk to the most probable questions based on keyword matching.
        Returns a list of (context_chunk, assigned_questions) pairs.
        """
        if not self.current_context_chunks:
            raise ValueError("No context chunks available. Please run chunk_current_prompt first.")
        if not self.current_questions:
            raise ValueError("No questions available. Please populate current_questions first.")
        keywords_per_question = self.extract_keywords(self.current_questions)
        # print(f"keywords per question: ", keywords_per_question) #so it returns a list of lists, the list has keywords of each question
        self.chunk_assignments = defaultdict(list)
        lowered_chunks = [chunk.lower() for chunk in self.current_context_chunks]
        for q_idx, keywords in enumerate(keywords_per_question):
            question = self.current_questions[q_idx]
            best_chunk_idx = None
            best_match_count = 0
            for idx, chunk in enumerate(lowered_chunks):
                match_count = sum(1 for keyword in keywords if keyword in chunk)
                if match_count > best_match_count:
                    best_match_count = match_count
                    best_chunk_idx = idx
            if best_chunk_idx is not None and best_match_count > 0:
                self.chunk_assignments[best_chunk_idx].append(question)
        # print(f"chunk assignments: ", self.chunk_assignments)

    def chunk_current_prompt(self, max_words_per_chunk=800):
        """
        Splits the context into ~800-word chunks and constructs prompts accordingly.
        Stores the chunked prompts in self.chunked_prompts.
        """
        if not hasattr(self, 'current_prompt') or self.current_prompt is None:
            raise ValueError("current_prompt not set. Please run generate_Dataset_prompt first.")
        prompt_parts = self.current_prompt.split("\nfrom this context:\n")
        if len(prompt_parts) != 2:
            raise ValueError("Prompt is not formatted correctly.")
        question_block = prompt_parts[0]  # instructions + questions
        context_block = prompt_parts[1]   # full context text
        context_words = context_block.split()
        chunks = [
            " ".join(context_words[i:i+max_words_per_chunk])
            for i in range(0, len(context_words), max_words_per_chunk)
        ]
        self.chunked_prompts = []
        self.current_context_chunks = []
        for chunk in chunks:
            self.current_context_chunks.append(chunk)
            new_prompt = f"{question_block}\n\nfrom this context:\n{chunk}"
            self.chunked_prompts.append(new_prompt)


    def construct_individual_prompts_from_assignments(self):
        """
        Constructs individual prompts by pairing assigned questions with their corresponding context chunks.
        Formats the prompt according to specified rules: minimal word answers, labeled Q1, Q2..., and specific handling for unknowns.
        Stores results in self.individual_prompts as a list of prompt strings.
        """
        if not hasattr(self, 'chunk_assignments') or not self.chunk_assignments:
            raise ValueError("chunk_assignments not set. Please run map_questions_to_chunks first.")

        if not hasattr(self, 'current_context_chunks') or not self.current_context_chunks:
            raise ValueError("No context chunks available.")

        self.individual_prompts = []
        for idx, questions in self.chunk_assignments.items():
            chunk = self.current_context_chunks[idx]
            # Add Q1, Q2... prefix
            formatted_questions = [f"Q{i + 1}: {q}" for i, q in enumerate(questions)]
            question_block = "\n".join(formatted_questions)

            prompt = (
                "Answer these questions as precisely as you can, in as minimum words as you can\n"
                "Format your answers with 'A1:', 'A2:', etc. at the beginning of each answer\n"
                "If you cannot find enough information in the provided context to answer a question, respond with 'Not specified'. Do NOT guess.\n"
                f"{question_block}\n\nfrom this context:\n{chunk}"
            )
            self.individual_prompts.append(prompt)
        self.chunked_prompts = self.individual_prompts


    def run_all_chunks(self, verbose=True):
        """
        Calls the LLM for each chunked prompt and prints the responses.

        Args:
            verbose (bool): If True, prints each response.

        Returns:
            List of responses from the model for each chunked prompt.
        """
        if not self.chunked_prompts:
            raise ValueError("chunked_prompts not set. Please run chunk_current_prompt first.")
        self.chunk_responses = []
        for idx, prompt in enumerate(self.chunked_prompts, 1):
            response = self.generate_response(prompt)
            self.chunk_responses.append(response)
            if verbose:
                print(f"\n--- Response for Chunk {idx} ---\n")
                print(response)
                print("\n-------------------------------\n")
        print("LOGGING chunk responses:")
        print(self.chunk_responses)

    def get_gold_answer_for_question(self, question):
        """
        Finds the gold answer for a given question.

        :param question: The question string to look up.
        :return: The corresponding gold answer string.
        :raises ValueError: If the question is not found in the current_questions list.
        """
        try:
            index = self.current_questions.index(question)
            return self.current_gold_answers[index]
        except ValueError:
            raise ValueError("Question not found in current_questions.")

    def extract_questions_and_answers(self, verbose=True):
        self.question_answer_map = {}
        for chunk_idx, response in enumerate(self.chunk_responses):
            question_block_start = re.search(r'\bQ1:', response)
            if not question_block_start:
                if verbose:
                    print(f"[Warning] No 'Q1:' found in chunk {chunk_idx}, skipping")
                continue
            cleaned_response = response[question_block_start.start():]
            # print("cleaned_Response is: ", cleaned_response) #so this skips all the prompt lines and starts from Q1
            questions = re.findall(r'Q\d+:\s*([^\n]*)', cleaned_response) #modified this to read from Q or A till a \n newline appeared as the last question also read the entire context.
            answers = re.findall(r'A\d+:\s*([^\n]*)', cleaned_response)
            print("answers: ", answers)
            print("questions: ", questions)
            if verbose and len(answers) != len(questions):
                print(f"[Warning] Mismatch: {len(questions)} questions vs {len(answers)} answers in chunk {chunk_idx}")

            for idx, question in enumerate(questions):
                gold_answer = self.get_gold_answer_for_question(question)
                self.question_answer_map[question] = (answers[idx].strip(), gold_answer)

        return self.question_answer_map


    def print_current_prompt(self):
        ''' This function prints the generated or inputted prompt'''
        print("=======================================================================PRINTING PROMPT======================================================================")
        print(f"\n🧠 Current Prompt:")
        print(f"{self.current_prompt}\n")
        char_length = len(self.current_prompt)
        token_count = len(self.current_prompt.split())
        print("=======================================================================PROMPT COUNTS======================================================================")
        print(f"Length: {char_length} characters, approximately {token_count} tokens")
        print("========================================================================END PRINTING======================================================================")


    def print_chunks(self):
        ''' This function prints each chunked prompt stored in self.chunked_prompts '''
        if not hasattr(self, 'chunked_prompts') or not self.chunked_prompts:
            print("No chunked prompts found. Please run chunk_current_prompt() first.")
            return
        print("=======================================================================PRINTING CHUNKED PROMPTS======================================================================")
        for i, chunk in enumerate(self.chunked_prompts, 1):
            print(f"\n🧠 Prompt Chunk {i}:")
            print(chunk)
            char_length = len(chunk)
            token_count = len(chunk.split())
            print("-----------------------------------------")
            print(f"Length: {char_length} characters, approximately {token_count} tokens")
            print("============================================================================================================================================================")
        print("=======================================================================END OF CHUNKS======================================================================")

    def print_parsed_qa_pairs(self):
        if not hasattr(self, 'question_answer_map') or not self.question_answer_map:
            print("No question-answer pairs found. Please run extract_questions_and_answers() first.")
            return

        print("Parsed Question-Answer Pairs:\n")
        for idx, (question, answer) in enumerate(self.question_answer_map.items(), 1):
            print(f"{idx}. Q: {question}\n   A: {answer}\n")

    def print_qa_pair_comparison(self):
        if not hasattr(self, 'question_answer_map') or not self.question_answer_map:
            print("No question-answer pairs found. Please run extract_questions_and_answers() first.")
            return

        if not hasattr(self, 'current_gold_answers') or not self.current_gold_answers:
            print("No gold answers found. Please set self.current_gold_answers before comparing.")
            return

        print("Question | Predicted Answer | Gold Answer")
        print("-" * 80)

        sorted_items = sorted(
        self.question_answer_map.items(),
        key=lambda item: self.current_questions.index(item[0]) if item[0] in self.current_questions else float('inf')
        )

        for idx, (question, (predicted_answer, gold_answer)) in enumerate(sorted_items):
            print(f"Q{idx+1}: {question}")
            print(f"LLM Answer: {predicted_answer}")
            print(f"Ground Truth: {gold_answer}")
            print()

    def print_qa_pairs(self):

        if not hasattr(self, 'current_gold_answers') or not self.current_gold_answers:
            print("No gold answers found. Please set self.current_gold_answers before comparing.")
            return

        questions = list(self.current_questions)
        gold_answers = self.current_gold_answers

        print("Question | Predicted Answer | Gold Answer")
        print("-" * 80)

        for idx, question in enumerate(questions):
            gold = gold_answers[idx] if idx < len(gold_answers) else "N/A"

            print(f"Q{idx+1}: {question}")
            print(f"  ✅ Gold     : {gold}")
            print()

# %%
#playground:
agent = Agent2(context_map)
agent.generate_Dataset_prompt(k=5)
# agent.print_current_prompt()
agent.chunk_current_prompt(max_words_per_chunk=400)
agent.map_questions_to_chunks()
agent.construct_individual_prompts_from_assignments()
# agent.print_chunks()
agent.extract_questions_and_answers()
# print("self.questions: ", agent.current_questions)
# print("self.answerrs: ", agent.current_gold_answers)
agent.print_qa_pair_comparison()
# Out:
# answers:  ['The Virgin Mary allegedly appeared to Saint Bernadette Soubirous in 1858 in Lourdes, France.', 'A copper statue of Christ with arms upraised with the legend "Venite Ad Me Omnes" is in front of the Notre Dame Main Building.', 'The Basilica of the Sacred Heart is beside the Notre Dame Main Building.', 'The Grotto at Notre Dame is a replica of the grotto at Lourdes, France where the Virgin Mary allegedly appeared to Saint Bernadette Soubirous in 1858.', 'The Scholastic Magazine of Notre Dame began publishing in September 1876.', 'The Juggler is published twice a year.', 'The daily student paper at Notre Dame is called The Observer.', 'There are 3 student news papers found at Notre Dame.', 'The headquarters of the Congregation of the Holy Cross is in Rome.', 'The primary seminary of the Congregation of the Holy Cross is Moreau Seminary.']
# questions:  ['To whom did the Virgin Mary allegedly appear in 1858 in Lourdes France?', 'What is in front of the Notre Dame Main Building?', 'The Basilica of the Sacred heart at Notre Dame is beside to which structure?', 'What is the Grotto at Notre Dame?', 'When did the Scholastic Magazine of Notre dame begin publishing?', "How often is Notre Dame's the Juggler published?", 'What is the daily student paper at Notre Dame called?', 'How many student news papers are found at Notre Dame?', 'Where is the headquarters of the Congregation of the Holy Cross?', 'What is the primary seminary of the Congregation of the Holy Cross?']
# answers:  ['Individuals who live at Fatima House at Notre Dame are brothers.', 'The College of Engineering at Notre Dame offers 8 BS level degrees.', 'The College of Engineering at Notre Dame was formed in 1920.', 'Before the creation of the College of Engineering, similar studies were carried out at the College of Science.', 'There are 5 departments within the Stinson-Remick Hall of Engineering.', 'The entity that provides help with the management of time for new students at Notre Dame is the First Year of Studies program.', 'There are 6 colleges for undergraduates at Notre Dame (including the First Year of Studies program).', 'The First Year of Studies program was created at Notre Dame in 1962.', 'The First Year of Studies program at Notre Dame was declared "outstanding" by U.S. News & World Report.', 'Old College is the oldest structure at Notre Dame.']
# questions:  ['What individuals live at Fatima House at Notre Dame?', 'How many BS level degrees are offered in the College of Engineering at Notre Dame?', 'In what year was the College of Engineering at Notre Dame formed?', 'Before the creation of the College of Engineering similar studies were carried out at which Notre Dame college?', 'How many departments are within the Stinson-Remick Hall of Engineering?', 'What entity provides help with the management of time for new students at Notre Dame?', 'How many colleges for undergraduates are at Notre Dame?', 'What was created at Notre Dame in 1962 to assist first year students?', 'Which organization declared the First Year of Studies program at Notre Dame "outstanding?"', 'What is the oldest structure at Notre Dame?']
# Question | Predicted Answer | Gold Answer
# --------------------------------------------------------------------------------
# Q1: To whom did the Virgin Mary allegedly appear in 1858 in Lourdes France?
# LLM Answer: The Virgin Mary allegedly appeared to Saint Bernadette Soubirous in 1858 in Lourdes, France.
# Ground Truth: Saint Bernadette Soubirous
#
# Q2: What is in front of the Notre Dame Main Building?
# LLM Answer: A copper statue of Christ with arms upraised with the legend "Venite Ad Me Omnes" is in front of the Notre Dame Main Building.
# Ground Truth: a copper statue of Christ
#
# Q3: The Basilica of the Sacred heart at Notre Dame is beside to which structure?
# LLM Answer: The Basilica of the Sacred Heart is beside the Notre Dame Main Building.
# Ground Truth: the Main Building
#
# Q4: What is the Grotto at Notre Dame?
# LLM Answer: The Grotto at Notre Dame is a replica of the grotto at Lourdes, France where the Virgin Mary allegedly appeared to Saint Bernadette Soubirous in 1858.
# Ground Truth: a Marian place of prayer and reflection
#
# Q5: When did the Scholastic Magazine of Notre dame begin publishing?
# LLM Answer: The Scholastic Magazine of Notre Dame began publishing in September 1876.
# Ground Truth: September 1876
#
# Q6: How often is Notre Dame's the Juggler published?
# LLM Answer: The Juggler is published twice a year.
# Ground Truth: twice
#
# Q7: What is the daily student paper at Notre Dame called?
# LLM Answer: The daily student paper at Notre Dame is called The Observer.
# Ground Truth: The Observer
#
# Q8: How many student news papers are found at Notre Dame?
# LLM Answer: There are 3 student news papers found at Notre Dame.
# Ground Truth: three
#
# Q9: Where is the headquarters of the Congregation of the Holy Cross?
# LLM Answer: The headquarters of the Congregation of the Holy Cross is in Rome.
# Ground Truth: Rome
#
# Q10: What is the primary seminary of the Congregation of the Holy Cross?
# LLM Answer: The primary seminary of the Congregation of the Holy Cross is Moreau Seminary.
# Ground Truth: Moreau Seminary
#
# Q11: What is the oldest structure at Notre Dame?
# LLM Answer: Old College is the oldest structure at Notre Dame.
# Ground Truth: Old College
#
# Q12: What individuals live at Fatima House at Notre Dame?
# LLM Answer: Individuals who live at Fatima House at Notre Dame are brothers.
# Ground Truth: Retired priests and brothers
#
# Q13: How many BS level degrees are offered in the College of Engineering at Notre Dame?
# LLM Answer: The College of Engineering at Notre Dame offers 8 BS level degrees.
# Ground Truth: eight
#
# Q14: In what year was the College of Engineering at Notre Dame formed?
# LLM Answer: The College of Engineering at Notre Dame was formed in 1920.
# Ground Truth: 1920
#
# Q15: Before the creation of the College of Engineering similar studies were carried out at which Notre Dame college?
# LLM Answer: Before the creation of the College of Engineering, similar studies were carried out at the College of Science.
# Ground Truth: the College of Science
#
# Q16: How many departments are within the Stinson-Remick Hall of Engineering?
# LLM Answer: There are 5 departments within the Stinson-Remick Hall of Engineering.
# Ground Truth: five
#
# Q17: What entity provides help with the management of time for new students at Notre Dame?
# LLM Answer: The entity that provides help with the management of time for new students at Notre Dame is the First Year of Studies program.
# Ground Truth: Learning Resource Center
#
# Q18: How many colleges for undergraduates are at Notre Dame?
# LLM Answer: There are 6 colleges for undergraduates at Notre Dame (including the First Year of Studies program).
# Ground Truth: five
#
# Q19: What was created at Notre Dame in 1962 to assist first year students?
# LLM Answer: The First Year of Studies program was created at Notre Dame in 1962.
# Ground Truth: The First Year of Studies program
#
# Q20: Which organization declared the First Year of Studies program at Notre Dame "outstanding?"
# LLM Answer: The First Year of Studies program at Notre Dame was declared "outstanding" by U.S. News & World Report.
# Ground Truth: U.S. News & World Report

# %% [markdown]
# # K32 Q5

# %%
#driver code:
agent = Agent2(context_map)
agent.generate_Dataset_prompt(k=32, q=5)
agent.print_current_prompt()
agent.chunk_current_prompt(max_words_per_chunk=700)
agent.map_questions_to_chunks()
agent.construct_individual_prompts_from_assignments()
agent.print_chunks()
agent.run_all_chunks()
agent.extract_questions_and_answers()
agent.print_qa_pair_comparison()
# Out:
# =======================================================================PRINTING PROMPT======================================================================
#
# 🧠 Current Prompt:
# Answer these questions as precisely as you can, in as minimum words as you can
# Format your answers with 'A1:', 'A2:', etc. at the beginning of each answer
# If you cannot find enough information in the provided context to answer a question, respond with 'Not specified'. Do NOT guess.
# Q1: To whom did the Virgin Mary allegedly appear in 1858 in Lourdes France?
# Q2: What is in front of the Notre Dame Main Building?
# Q3: The Basilica of the Sacred heart at Notre Dame is beside to which structure?
# Q4: What is the Grotto at Notre Dame?
# Q5: What sits on top of the Main Building at Notre Dame?
# Q6: When did the Scholastic Magazine of Notre dame begin publishing?
# Q7: How often is Notre Dame's the Juggler published?
# Q8: What is the daily student paper at Notre Dame called?
# Q9: How many student news papers are found at Notre Dame?
# Q10: In what year did the student paper Common Sense begin publication at Notre Dame?
# Q11: Where is the headquarters of the Congregation of the Holy Cross?
# Q12: What is the primary seminary of the Congregation of the Holy Cross?
# Q13: What is the oldest structure at Notre Dame?
# Q14: What individuals live at Fatima House at Notre Dame?
# Q15: Which prize did Frederick Buechner create?
# Q16: How many BS level degrees are offered in the College of Engineering at Notre Dame?
# Q17: In what year was the College of Engineering at Notre Dame formed?
# Q18: Before the creation of the College of Engineering similar studies were carried out at which Notre Dame college?
# Q19: How many departments are within the Stinson-Remick Hall of Engineering?
# Q20: The College of Science began to offer civil engineering courses beginning at what time at Notre Dame?
# Q21: What entity provides help with the management of time for new students at Notre Dame?
# Q22: How many colleges for undergraduates are at Notre Dame?
# Q23: What was created at Notre Dame in 1962 to assist first year students?
# Q24: Which organization declared the First Year of Studies program at Notre Dame "outstanding?"
# Q25: The granting of Doctorate degrees first occurred in what year at Notre Dame?
# Q26: What type of degree is an M.Div.?
# Q27: Which program at Notre Dame offers a Master of Education degree?
# Q28: In what year was a Master of Arts course first offered at Notre Dame?
# Q29: Which department at Notre Dame is the only one to not offer a PhD program?
# Q30: What institute at Notre Dame studies  the reasons for violent conflict?
# Q31: What is the title of Notre Dame's Theodore Hesburgh?
# Q32: In what year was the Joan B. Kroc Institute for International Peace Studies founded?
# Q33: To whom was John B. Kroc married?
# Q3: The Basilica of the Sacred heart at Notre Dame is beside to which structure?
# Q4: What is the Grotto at Notre Dame?
# Q5: What sits on top of the Main Building at Notre Dame?
# Q6: When did the Scholastic Magazine of Notre dame begin publishing?
# Q7: How often is Notre Dame's the Juggler published?
# Q8: What is the daily student paper at Notre Dame called?
# Q9: How many student news papers are found at Notre Dame?
# Q10: In what year did the student paper Common Sense begin publication at Notre Dame?
# Q11: Where is the headquarters of the Congregation of the Holy Cross?
# Q12: What is the primary seminary of the Congregation of the Holy Cross?
# Q13: What is the oldest structure at Notre Dame?
# Q14: What individuals live at Fatima House at Notre Dame?
# Q15: Which prize did Frederick Buechner create?
# Q16: How many BS level degrees are offered in the College of Engineering at Notre Dame?
# Q17: Before the creation of the College of Engineering similar studies were carried out at which Notre Dame college?
# Q18: The College of Science began to offer civil engineering courses beginning at what time at Notre Dame?
# Q19: What entity provides help with the management of time for new students at Notre Dame?
# Q20: What was created at Notre Dame in 1962 to assist first year students?
# Q21: Which organization declared the First Year of Studies program at Notre Dame "outstanding?"
# Q22: What type of degree is an M.Div.?
# Q23: In what year was a Master of Arts course first offered at Notre Dame?
# Q24: Forbes.com placed Notre Dame at what position compared to other US research universities?
# Q25: Which individual worked on projects at Notre Dame that eventually created neoprene?
# Q26: What percentage of students at Notre Dame are the children of former Notre Dame students?
# Q27: Irvin Abell was given what award by Notre Dame?
# Q28: Which year was the Laetare Medal first given out at Notre Dame?
# Q29: Which congregation is in charge of the Old College at Notre Dame?
# Q30: In which architectural style is the Basilica of the Sacred Heart at Notre Dame made?
#
# from this context:
# ...
#
# A1: Not specified
# A2: Not specified
# A3: Main Library
# A4: 700
# A5: For the Holy Cross Missions in Bangladesh
# A6: 80%
# A7: 15
# A8: Not specified
# A9: 14
# A10: Congregatio a Sancta Cruce
# A11: Over 100 times
# A12: 57
# A13: Over 93%
# A14: 1879
# A15: The Rev. William Corby
# A16: May 17th
# A17: Administration Building
# A18: Not specified
# A19: Not specified
# A20: 29
# A21: Not specified
# A22: Jenkins Nanovic Halls
# A23: Not specified
#
# -------------------------------
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_deprecation.py:131: FutureWarning: 'post' (from 'huggingface_hub.inference._client') is deprecated and will be removed from version '0.31.0'. Making direct POST requests to the inference server is not supported anymore. Please use task methods instead (e.g. `InferenceClient.chat_completion`). If your use case is not supported, please open an issue in https://github.com/huggingface/huggingface_hub.
#   warnings.warn(warning_message, FutureWarning)
# --- Response for Chunk 5 ---
#
# Answer these questions as precisely as you can, in as minimum words as you can
# Format your answers with 'A1:', 'A2:', etc. at the beginning of each answer
# If you cannot find enough information in the provided context to answer a question, respond with 'Not specified'. Do NOT guess.
# Q1: The granting of Doctorate degrees first occurred in what year at Notre Dame?
# Q2: Which program at Notre Dame offers a Master of Education degree?
# Q3: What institute at Notre Dame studies  the reasons for violent conflict?
# Q4: What is the title of Notre Dame's Theodore Hesburgh?
# Q5: In what year was the Joan B. Kroc Institute for International Peace Studies founded?
# Q6: What company did Ray Kroc own?
# Q7: In what year was the Theodore M. Hesburgh Library at Notre Dame finished?
# Q8: Which artist created the mural on the Theodore M. Hesburgh Library?
# Q9: What is a common name to reference the mural created by Millard Sheets at Notre Dame?
# Q10: How many incoming students did Notre Dame admit in fall 2015?
# Q11: What percentage of students were admitted to Notre Dame in fall 2015?
# Q12: Where does Notre Dame rank in terms of academic profile among research universities in the US?
# Q13: What percentage of students at Notre Dame participated in the Early Action program?
# Q14: How many miles does the average student at Notre Dame travel to study there?
# Q15: Where did U.S. News & World Report rank Notre Dame in its 2015-2016 university rankings
# A14: The average student at Notre Dame travels more than 750 miles to study there.
# A15: U.S. News & World Report ranked Notre Dame 18th in its 2015-2016 university rankings.
# A16: The undergrad school at the Mendoza College of Business was ranked 1st overall by BusinessWeek.
# A17: In 2014, USA Today named Notre Dame 10th best of all American universities.
# A18: 57.6% of Notre Dame students decide to study abroad.
# A19: The study of a germ-free-life began at Notre Dame in Not specified.
# A20: The Kroc Institute at Notre Dame focuses on peace studies.
# A21: 81% of Notre Dame students feel they are Christian.
# A22: Before its embracing of national standards, Notre Dame pushed a classical education.
# A23: The president of Notre Dame in 1947 was John O'Hara.
# A24: Theodore Hesburgh lived from 1917 to 2015.
# A25: Theodore Hesburgh was president of Notre Dame from 1952 to 1987.
#
# -------------------------------
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_deprecation.py:131: FutureWarning: 'post' (from 'huggingface_hub.inference._client') is deprecated and will be removed from version '0.31.0'. Making direct POST requests to the inference server is not supported anymore. Please use task methods instead (e.g. `InferenceClient.chat_completion`). If your use case is not supported, please open an issue in https://github.com/huggingface/huggingface_hub.
#   warnings.warn(warning_message, FutureWarning)
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_http.py in hf_raise_for_status(response, endpoint_name)
#     408     try:
# --> 409         response.raise_for_status()
#     410     except HTTPError as e:
#
# /usr/local/lib/python3.11/dist-packages/requests/models.py in raise_for_status(self)
#    1023         if http_error_msg:
# -> 1024             raise HTTPError(http_error_msg, response=self)
#    1025
#
# HTTPError: 504 Server Error: Gateway Time-out for url: https://router.huggingface.co/hf-inference/models/mistralai/Mistral-7B-Instruct-v0.3
#
# The above exception was the direct cause of the following exception:
#
# HfHubHTTPError                            Traceback (most recent call last)
# <ipython-input-37-bb30e6c4ac37> in <cell line: 0>()
#       7 agent.construct_individual_prompts_from_assignments()
#       8 agent.print_chunks()
# ----> 9 agent.run_all_chunks()
#      10 agent.extract_questions_and_answers()
#      11 agent.print_qa_pair_comparison()
#
# <ipython-input-36-9381b25bdd97> in run_all_chunks(self, verbose)
#     178         self.chunk_responses = []
#     179         for idx, prompt in enumerate(self.chunked_prompts, 1):
# --> 180             response = self.generate_response(prompt)
#     181             self.chunk_responses.append(response)
#     182             if verbose:
#
# <ipython-input-36-9381b25bdd97> in generate_response(self, prompt)
#      27
#      28     def generate_response(self, prompt): #can use this function to get answer from 1 chunk, then 2nd chunk etc, all chunks and then proceed. with normal
# ---> 29         return self.llm(prompt)
#      30
#      31     def get_context_questions(self, k=2, q=4):
#
# /usr/local/lib/python3.11/dist-packages/langchain_core/_api/deprecation.py in warning_emitting_wrapper(*args, **kwargs)
#     189                 warned = True
#     190                 emit_warning()
# --> 191             return wrapped(*args, **kwargs)
#     192
#     193         async def awarning_emitting_wrapper(*args: Any, **kwargs: Any) -> Any:
#
# /usr/local/lib/python3.11/dist-packages/langchain_core/language_models/llms.py in __call__(self, prompt, stop, callbacks, tags, metadata, **kwargs)
#    1313             raise ValueError(msg)  # noqa: TRY004
#    1314         return (
# -> 1315             self.generate(
#    1316                 [prompt],
#    1317                 stop=stop,
#
# /usr/local/lib/python3.11/dist-packages/langchain_core/language_models/llms.py in generate(self, prompts, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     969                 )
#     970             ]
# --> 971             return self._generate_helper(
#     972                 prompts,
#     973                 stop,
#
# /usr/local/lib/python3.11/dist-packages/langchain_core/language_models/llms.py in _generate_helper(self, prompts, stop, run_managers, new_arg_supported, **kwargs)
#     788         try:
#     789             output = (
# --> 790                 self._generate(
#     791                     prompts,
#     792                     stop=stop,
#
# /usr/local/lib/python3.11/dist-packages/langchain_core/language_models/llms.py in _generate(self, prompts, stop, run_manager, **kwargs)
#    1543         for prompt in prompts:
#    1544             text = (
# -> 1545                 self._call(prompt, stop=stop, run_manager=run_manager, **kwargs)
#    1546                 if new_arg_supported
#    1547                 else self._call(prompt, stop=stop, **kwargs)
#
# /usr/local/lib/python3.11/dist-packages/langchain_community/llms/huggingface_hub.py in _call(self, prompt, stop, run_manager, **kwargs)
#     136         parameters = {**_model_kwargs, **kwargs}
#     137
# --> 138         response = self.client.post(
#     139             json={"inputs": prompt, "parameters": parameters}, task=self.task
#     140         )
#
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_deprecation.py in inner_f(*args, **kwargs)
#     130                 warning_message += " " + message
#     131             warnings.warn(warning_message, FutureWarning)
# --> 132             return f(*args, **kwargs)
#     133
#     134         return inner_f
#
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/inference/_client.py in post(self, json, data, model, task, stream)
#     303         url = provider_helper._prepare_url(self.token, mapped_model)  # type: ignore[arg-type]
#     304         headers = provider_helper._prepare_headers(self.headers, self.token)  # type: ignore[arg-type]
# --> 305         return self._inner_post(
#     306             request_parameters=RequestParameters(
#     307                 url=url,
#
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/inference/_client.py in _inner_post(self, request_parameters, stream)
#     355
#     356         try:
# --> 357             hf_raise_for_status(response)
#     358             return response.iter_lines() if stream else response.content
#     359         except HTTPError as error:
#
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_http.py in hf_raise_for_status(response, endpoint_name)
#     480         # Convert `HTTPError` into a `HfHubHTTPError` to display request information
#     481         # as well (request id and/or server error message)
# --> 482         raise _format(HfHubHTTPError, str(e), response) from e
#     483
#     484
#
# HfHubHTTPError: 504 Server Error: Gateway Time-out for url: https://router.huggingface.co/hf-inference/models/mistralai/Mistral-7B-Instruct-v0.3

# %%
print(agent.chunk_responses)
# Out:
# ['Answer these questions as precisely as you can, in as minimum words as you can\nFormat your answers with \'A1:\', \'A2:\', etc. at the beginning of each answer\nIf you cannot find enough information in the provided context to answer a question, respond with \'Not specified\'. Do NOT guess.\nQ1: To whom did the Virgin Mary allegedly appear in 1858 in Lourdes France?\nQ2: What is in front of the Notre Dame Main Building?\nQ3: The Basilica of the Sacred heart at Notre Dame is beside to which structure?\nQ4: What is the Grotto at Notre Dame?\nQ5: What sits on top of the Main Building at Notre Dame?\nQ6: When did the Scholastic Magazine of Notre dame begin publishing?\nQ7: How often is Notre Dame\'s the Juggler published?\nQ8: What is the daily student paper at Notre Dame called?\nQ9: How many student news papers are found at Notre Dame?\nQ10: In what year did the student paper Common Sense begin publication at Notre Dame?\nQ11: Where is the headquarters of the Congregation of the Holy Cross?\nQ12: What is the primary seminary of the Congregation of the Holy Cross?\nQ13: What is the oldest structure at Notre Dame?\nQ14: What individuals live at Fatima House at Notre Dame?\nQ15: Which prize did Frederick Buechner create?\nQ16: How many BS level degrees are offered in the College of Engineering at Notre Dame?\nQ17: Before the creation of the College of Engineering similar studies were carried out at which Notre Dame college?\nQ18: The College of Science began to offer civil engineering courses beginning at what time at Notre Dame?\nQ19: What entity provides help with the management of time for new students at Notre Dame?\nQ20: What was created at Notre Dame in 1962 to assist first year students?\nQ21: Which organization declared the First Year of Studies program at Notre Dame "outstanding?"\nQ22: What type of degree is an M.Div.?\nQ23: In what year was a Master of Arts course first offered at Notre Dame?\nQ24: Forbes.com placed Notre Dame at what position compared to other US research universities?\nQ25: Which individual worked on projects at Notre Dame that eventually created neoprene?\nQ26: What percentage of students at Notre Dame are the children of former Notre Dame students?\nQ27: Irvin Abell was given what award by Notre Dame?\nQ28: Which year was the Laetare Medal first given out at Notre Dame?\nQ29: Which congregation is in charge of the Old College at Notre Dame?\nQ30: In which architectural style is the Basilica of the Sacred Heart at Notre Dame made?\n\nfrom this context:\nArchitecturally, the school has a Catholic character. Atop the Main Building\'s gold dome is a golden statue of the Virgin Mary. Immediately in front of the Main Building and facing it, is a copper statue of Christ with arms upraised with the legend "Venite Ad Me Omnes". Next to the Main Building is the Basilica of the Sacred Heart. Immediately behind the basilica is the Grotto, a Marian place of prayer and reflection. It is a replica of the grotto at Lourdes, France where the Virgin Mary reputedly appeared to Saint Bernadette Soubirous in 1858. At the end of the main drive (and in a direct line that connects through 3 statues and the Gold Dome), is a simple, modern stone statue of Mary. As at most other universities, Notre Dame\'s students run a number of news media outlets. The nine student-run outlets include three newspapers, both a radio and television station, and several magazines and journals. Begun as a one-page journal in September 1876, the Scholastic magazine is issued twice monthly and claims to be the oldest continuous collegiate publication in the United States. The other magazine, The Juggler, is released twice a year and focuses on student literature and artwork. The Dome yearbook is published annually. The newspapers have varying publication interests, with The Observer published daily and mainly reporting university and other news, and staffed by students from both Notre Dame and Saint Mary\'s College. Unlike Scholastic and The Dome ...

# %%
print(agent.chunked_prompts)
# Out:
# ['Answer these questions as precisely as you can, in as minimum words as you can\nFormat your answers with \'A1:\', \'A2:\', etc. at the beginning of each answer\nIf you cannot find enough information in the provided context to answer a question, respond with \'Not specified\'. Do NOT guess.\nQ1: To whom did the Virgin Mary allegedly appear in 1858 in Lourdes France?\nQ2: What is in front of the Notre Dame Main Building?\nQ3: The Basilica of the Sacred heart at Notre Dame is beside to which structure?\nQ4: What is the Grotto at Notre Dame?\nQ5: What sits on top of the Main Building at Notre Dame?\nQ6: When did the Scholastic Magazine of Notre dame begin publishing?\nQ7: How often is Notre Dame\'s the Juggler published?\nQ8: What is the daily student paper at Notre Dame called?\nQ9: How many student news papers are found at Notre Dame?\nQ10: In what year did the student paper Common Sense begin publication at Notre Dame?\nQ11: Where is the headquarters of the Congregation of the Holy Cross?\nQ12: What is the primary seminary of the Congregation of the Holy Cross?\nQ13: What is the oldest structure at Notre Dame?\nQ14: What individuals live at Fatima House at Notre Dame?\nQ15: Which prize did Frederick Buechner create?\nQ16: How many BS level degrees are offered in the College of Engineering at Notre Dame?\nQ17: Before the creation of the College of Engineering similar studies were carried out at which Notre Dame college?\nQ18: The College of Science began to offer civil engineering courses beginning at what time at Notre Dame?\nQ19: What entity provides help with the management of time for new students at Notre Dame?\nQ20: What was created at Notre Dame in 1962 to assist first year students?\nQ21: Which organization declared the First Year of Studies program at Notre Dame "outstanding?"\nQ22: What type of degree is an M.Div.?\nQ23: In what year was a Master of Arts course first offered at Notre Dame?\nQ24: Forbes.com placed Notre Dame at what position compared to other US research universities?\nQ25: Which individual worked on projects at Notre Dame that eventually created neoprene?\nQ26: What percentage of students at Notre Dame are the children of former Notre Dame students?\nQ27: Irvin Abell was given what award by Notre Dame?\nQ28: Which year was the Laetare Medal first given out at Notre Dame?\nQ29: Which congregation is in charge of the Old College at Notre Dame?\nQ30: In which architectural style is the Basilica of the Sacred Heart at Notre Dame made?\n\nfrom this context:\nArchitecturally, the school has a Catholic character. Atop the Main Building\'s gold dome is a golden statue of the Virgin Mary. Immediately in front of the Main Building and facing it, is a copper statue of Christ with arms upraised with the legend "Venite Ad Me Omnes". Next to the Main Building is the Basilica of the Sacred Heart. Immediately behind the basilica is the Grotto, a Marian place of prayer and reflection. It is a replica of the grotto at Lourdes, France where the Virgin Mary reputedly appeared to Saint Bernadette Soubirous in 1858. At the end of the main drive (and in a direct line that connects through 3 statues and the Gold Dome), is a simple, modern stone statue of Mary. As at most other universities, Notre Dame\'s students run a number of news media outlets. The nine student-run outlets include three newspapers, both a radio and television station, and several magazines and journals. Begun as a one-page journal in September 1876, the Scholastic magazine is issued twice monthly and claims to be the oldest continuous collegiate publication in the United States. The other magazine, The Juggler, is released twice a year and focuses on student literature and artwork. The Dome yearbook is published annually. The newspapers have varying publication interests, with The Observer published daily and mainly reporting university and other news, and staffed by students from both Notre Dame and Saint Mary\'s College. Unlike Scholastic and The Dome ...

# %%
# now parsing the responded to chunks:
import re
from collections import defaultdict
from typing import List, Tuple


class Agent2:
    #same context overload notebook
    def __init__(self, context_map, model_name="mistralai/Mistral-7B-Instruct-v0.3", access_token="TOKEN-HERE"):
        self.context_map = context_map
        self.llm = HuggingFaceHub(
            repo_id=model_name,
            model_kwargs={"temperature": 0.3, "max_length": 200},
            huggingfacehub_api_token=access_token
        )
        self.current_prompt = None # NEW: ask user to input context and questions seperately. chunks will only be made of context.
        self.chunked_prompts = []
        self.chunk_responses = ['Answer these questions as precisely as you can, in as minimum words as you can\nFormat your answers with \'A1:\', \'A2:\', etc. at the beginning of each answer\nIf you cannot find enough information in the provided context to answer a question, respond with \'Not specified\'. Do NOT guess.\nQ1: To whom did the Virgin Mary allegedly appear in 1858 in Lourdes France
ked 1st overall by BusinessWeek.\nA17: In 2014, USA Today named Notre Dame 10th best of all American universities.\nA18: 57.6% of Notre Dame students decide to study abroad.\nA19: The study of a germ-free-life began at Notre Dame in Not specified.\nA20: The Kroc Institute at Notre Dame focuses on peace studies.\nA21: 81% of Notre Dame students feel they are Christian.\nA22: Before its embracing of national standards, Notre Dame pushed a classical education.\nA23: The president of Notre Dame in 1947 was John O\'Hara.\nA24: Theodore Hesburgh lived from 1917 to 2015.\nA25: Theodore Hesburgh was president of Notre Dame from 1952 to 1987.']

# new variables for storing questions, chunks and gold answers respectively.
        self.current_context_chunks = []
        self.current_questions = []
        self.current_gold_answers = []
        # this is for chunk assignment to each question
        self.chunk_assignments = defaultdict(list)
        # for parsing and storing question answer pairs from chunk prompts:
        self.question_answer_map = {}

    def generate_response(self, prompt): #can use this function to get answer from 1 chunk, then 2nd chunk etc, all chunks and then proceed. with normal
        return self.llm(prompt)

    def get_context_questions(self, k=2, q=4):
      #same as context overload notebook
        contexts = []
        questions_answers = []
        selected_contexts = list(self.context_map.items())[:k]
        for context, qa_pairs in selected_contexts:
            contexts.append(context)
            selected_qa = qa_pairs[:q]
            questions_answers.append(selected_qa)
        return contexts, questions_answers

    def generate_Dataset_prompt(self, k=2, q=4):
        ''' This function generates and imitates a prompt from the dataset, later on, we will take questions and context as input from user.'''
        contexts, questions_answers_by_context = self.get_context_questions(k, q)
        combined_context = "\n\n".join(contexts)
        all_questions_answers = []
        for qa_pairs in questions_answers_by_context:
            all_questions_answers.extend(qa_pairs)
        # modified the prompt
        prompt_lines = [
            "Answer these questions as precisely as you can, in as minimum words as you can",
            "Format your answers with 'A1:', 'A2:', etc. at the beginning of each answer",
            "If you cannot find enough information in the provided context to answer a question, respond with 'Not specified'. Do NOT guess.",
        ]
        self.current_questions = []
        self.current_gold_answers = []
        for i, (question, answer) in enumerate(all_questions_answers, 1):
            self.current_questions.append(question)
            self.current_gold_answers.append(answer)
            prompt_lines.append(f"Q{i}: {question}")
        prompt_lines.append("\nfrom this context:")
        prompt_lines.append(combined_context)
        prompt = "\n".join(prompt_lines)
        self.current_prompt = prompt


    def extract_keywords(self, questions: List[str]) -> List[List[str]]:
        """
        Given a list of questions, extract a list of keywords for each question.
        """
        stopwords = set([
            "the", "is", "at", "which", "on", "in", "a", "an", "of", "to", "for", "with",
            "and", "by", "from", "what", "who", "when", "where", "how", "does", "do",
            "did", "was", "were", "has", "have", "had"
        ])
        all_keywords = []
        for question in questions:
            # Remove punctuation
            question_clean = re.sub(r'[^\w\s]', '', question)
            words = question_clean.lower().split()
            # Filter stopwords and small words
            keywords = [word for word in words if word not in stopwords and len(word) > 2]
            all_keywords.append(keywords)
        return all_keywords

    def map_questions_to_chunks(self) -> List[Tuple[str, List[str]]]:
        """
        Map each context chunk to the most probable questions based on keyword matching.
        Returns a list of (context_chunk, assigned_questions) pairs.
        """
        if not self.current_context_chunks:
            raise ValueError("No context chunks available. Please run chunk_current_prompt first.")
        if not self.current_questions:
            raise ValueError("No questions available. Please populate current_questions first.")
        keywords_per_question = self.extract_keywords(self.current_questions)
        # print(f"keywords per question: ", keywords_per_question) #so it returns a list of lists, the list has keywords of each question
        self.chunk_assignments = defaultdict(list)
        lowered_chunks = [chunk.lower() for chunk in self.current_context_chunks]
        for q_idx, keywords in enumerate(keywords_per_question):
            question = self.current_questions[q_idx]
            best_chunk_idx = None
            best_match_count = 0
            for idx, chunk in enumerate(lowered_chunks):
                match_count = sum(1 for keyword in keywords if keyword in chunk)
                if match_count > best_match_count:
                    best_match_count = match_count
                    best_chunk_idx = idx
            if best_chunk_idx is not None and best_match_count > 0:
                self.chunk_assignments[best_chunk_idx].append(question)
        # print(f"chunk assignments: ", self.chunk_assignments)

    def chunk_current_prompt(self, max_words_per_chunk=800):
        """
        Splits the context into ~800-word chunks and constructs prompts accordingly.
        Stores the chunked prompts in self.chunked_prompts.
        """
        if not hasattr(self, 'current_prompt') or self.current_prompt is None:
            raise ValueError("current_prompt not set. Please run generate_Dataset_prompt first.")
        prompt_parts = self.current_prompt.split("\nfrom this context:\n")
        if len(prompt_parts) != 2:
            raise ValueError("Prompt is not formatted correctly.")
        question_block = prompt_parts[0]  # instructions + questions
        context_block = prompt_parts[1]   # full context text
        context_words = context_block.split()
        chunks = [
            " ".join(context_words[i:i+max_words_per_chunk])
            for i in range(0, len(context_words), max_words_per_chunk)
        ]
        self.chunked_prompts = []
        self.current_context_chunks = []
        for chunk in chunks:
            self.current_context_chunks.append(chunk)
            new_prompt = f"{question_block}\n\nfrom this context:\n{chunk}"
            self.chunked_prompts.append(new_prompt)


    def construct_individual_prompts_from_assignments(self):
        """
        Constructs individual prompts by pairing assigned questions with their corresponding context chunks.
        Formats the prompt according to specified rules: minimal word answers, labeled Q1, Q2..., and specific handling for unknowns.
        Stores results in self.individual_prompts as a list of prompt strings.
        """
        if not hasattr(self, 'chunk_assignments') or not self.chunk_assignments:
            raise ValueError("chunk_assignments not set. Please run map_questions_to_chunks first.")

        if not hasattr(self, 'current_context_chunks') or not self.current_context_chunks:
            raise ValueError("No context chunks available.")

        self.individual_prompts = []
        for idx, questions in self.chunk_assignments.items():
            chunk = self.current_context_chunks[idx]
            # Add Q1, Q2... prefix
            formatted_questions = [f"Q{i + 1}: {q}" for i, q in enumerate(questions)]
            question_block = "\n".join(formatted_questions)

            prompt = (
                "Answer these questions as precisely as you can, in as minimum words as you can\n"
                "Format your answers with 'A1:', 'A2:', etc. at the beginning of each answer\n"
                "If you cannot find enough information in the provided context to answer a question, respond with 'Not specified'. Do NOT guess.\n"
                f"{question_block}\n\nfrom this context:\n{chunk}"
            )
            self.individual_prompts.append(prompt)
        self.chunked_prompts = self.individual_prompts


    # def run_all_chunks(self, verbose=True):
    #     """
    #     Calls the LLM for each chunked prompt and prints the responses.

    #     Args:
    #         verbose (bool): If True, prints each response.

    #     Returns:
    #         List of responses from the model for each chunked prompt.
    #     """
    #     if not self.chunked_prompts:
    #         raise ValueError("chunked_prompts not set. Please run chunk_current_prompt first.")
    #     self.chunk_responses = []
    #     for idx, prompt in enumerate(self.chunked_prompts, 1):
    #         response = self.generate_response(prompt)
    #         self.chunk_responses.append(response)
    #         if verbose:
    #             print(f"\n--- Response for Chunk {idx} ---\n")
    #             print(response)
    #             print("\n-------------------------------\n")
    #     print("LOGGING chunk responses:")
    #     print(self.chunk_responses)

    def get_gold_answer_for_question(self, question):
        """
        Finds the gold answer for a given question.

        :param question: The question string to look up.
        :return: The corresponding gold answer string.
        :raises ValueError: If the question is not found in the current_questions list.
        """
        try:
            index = self.current_questions.index(question)
            return self.current_gold_answers[index]
        except ValueError:
            return "Question not found"

    def extract_questions_and_answers(self, verbose=True):
        self.question_answer_map = {}
        for chunk_idx, response in enumerate(self.chunk_responses):
            question_block_start = re.search(r'\bQ1:', response)
            if not question_block_start:
                if verbose:
                    print(f"[Warning] No 'Q1:' found in chunk {chunk_idx}, skipping")
                continue
            cleaned_response = response[question_block_start.start():]
            # print("cleaned_Response is: ", cleaned_response) #so this skips all the prompt lines and starts from Q1
            questions = re.findall(r'Q\d+:\s*([^\n]*)', cleaned_response) #modified this to read from Q or A till a \n newline appeared as the last question also read the entire context.
            answers = re.findall(r'A\d+:\s*([^\n]*)', cleaned_response)
            print("answers: ", answers)
            print("questions: ", questions)
            if verbose and len(answers) != len(questions):
                print(f"[Warning] Mismatch: {len(questions)} questions vs {len(answers)} answers in chunk {chunk_idx}")

            for idx, question in enumerate(questions):
                gold_answer = self.get_gold_answer_for_question(question)
                self.question_answer_map[question] = (answers[idx].strip(), gold_answer)

        return self.question_answer_map


    def print_current_prompt(self):
        ''' This function prints the generated or inputted prompt'''
        print("=======================================================================PRINTING PROMPT======================================================================")
        print(f"\n🧠 Current Prompt:")
        print(f"{self.current_prompt}\n")
        char_length = len(self.current_prompt)
        token_count = len(self.current_prompt.split())
        print("=======================================================================PROMPT COUNTS======================================================================")
        print(f"Length: {char_length} characters, approximately {token_count} tokens")
        print("========================================================================END PRINTING======================================================================")


    def print_chunks(self):
        ''' This function prints each chunked prompt stored in self.chunked_prompts '''
        if not hasattr(self, 'chunked_prompts') or not self.chunked_prompts:
            print("No chunked prompts found. Please run chunk_current_prompt() first.")
            return
        print("=======================================================================PRINTING CHUNKED PROMPTS======================================================================")
        for i, chunk in enumerate(self.chunked_prompts, 1):
            print(f"\n🧠 Prompt Chunk {i}:")
            print(chunk)
            char_length = len(chunk)
            token_count = len(chunk.split())
            print("-----------------------------------------")
            print(f"Length: {char_length} characters, approximately {token_count} tokens")
            print("============================================================================================================================================================")
        print("=======================================================================END OF CHUNKS======================================================================")

    def print_parsed_qa_pairs(self):
        if not hasattr(self, 'question_answer_map') or not self.question_answer_map:
            print("No question-answer pairs found. Please run extract_questions_and_answers() first.")
            return

        print("Parsed Question-Answer Pairs:\n")
        for idx, (question, answer) in enumerate(self.question_answer_map.items(), 1):
            print(f"{idx}. Q: {question}\n   A: {answer}\n")

    def print_qa_pair_comparison(self):
        if not hasattr(self, 'question_answer_map') or not self.question_answer_map:
            print("No question-answer pairs found. Please run extract_questions_and_answers() first.")
            return

        if not hasattr(self, 'current_gold_answers') or not self.current_gold_answers:
            print("No gold answers found. Please set self.current_gold_answers before comparing.")
            return

        print("Question | Predicted Answer | Gold Answer")
        print("-" * 80)

        sorted_items = sorted(
        self.question_answer_map.items(),
        key=lambda item: self.current_questions.index(item[0]) if item[0] in self.current_questions else float('inf')
        )

        for idx, (question, (predicted_answer, gold_answer)) in enumerate(sorted_items):
            print(f"Q{idx+1}: {question}")
            print(f"LLM Answer: {predicted_answer}")
            print(f"Ground Truth: {gold_answer}")
            print()

    def print_qa_pairs(self):

        if not hasattr(self, 'current_gold_answers') or not self.current_gold_answers:
            print("No gold answers found. Please set self.current_gold_answers before comparing.")
            return

        questions = list(self.current_questions)
        gold_answers = self.current_gold_answers

        print("Question | Predicted Answer | Gold Answer")
        print("-" * 80)

        for idx, question in enumerate(questions):
            gold = gold_answers[idx] if idx < len(gold_answers) else "N/A"

            print(f"Q{idx+1}: {question}")
            print(f"  ✅ Gold     : {gold}")
            print()

# %%
#playground:
agent = Agent2(context_map)
agent.generate_Dataset_prompt(k=32, q=5)
# agent.print_current_prompt()
agent.chunk_current_prompt(max_words_per_chunk=700)
agent.map_questions_to_chunks()
agent.construct_individual_prompts_from_assignments()
# agent.print_chunks()
agent.extract_questions_and_answers()
# print("self.questions: ", agent.current_questions)
# print("self.answerrs: ", agent.current_gold_answers)
agent.print_qa_pair_comparison()
# Out:
# answers:  ['The Virgin Mary allegedly appeared to Bernadette Soubirous in 1858 in Lourdes, France.', 'In front of the Notre Dame Main Building is a copper statue of Christ with arms upraised with the legend "Venite Ad Me Omnes".', 'The Basilica of the Sacred heart at Notre Dame is beside the Main Building.', 'The Grotto at Notre Dame is a Marian place of prayer and reflection, a replica of the grotto at Lourdes, France.', 'A golden statue of the Virgin Mary sits on top of the Main Building at Notre Dame.', 'The Scholastic Magazine of Notre Dame began publishing in September 1876.', 'The Juggler is published twice a year.', 'The daily student paper at Notre Dame is called The Observer.', 'There are 9 student-run news outlets at Notre Dame.', 'The student paper Common Sense began publication at Notre Dame in 1987.', 'The headquarters of the Congregation of the Holy Cross is in Rome.', 'The primary seminary of the Congregation of the Holy Cross is Moreau Seminary.', 'The oldest structure at Notre Dame is Old College.', 'Individuals who live at Fatima House at Notre Dame are retired priests and brothers.', 'Frederick Buechner created the Buechner Prize for Preaching.', 'The College of Engineering at Notre Dame offers 8 BS level degrees.', 'Similar studies were carried out at the College of Science before the creation of the College of Engineering.', 'The College of Science began to offer civil engineering courses in the 1870s at Notre Dame.', 'The entity that provides help with the management of time for new students at Notre Dame is the First Year of Studies program.', 'In 1962, a program called the Learning Resource Center was created at Notre Dame to assist first year students.', 'The First Year of Studies program at Notre Dame was recognized as "outstanding" by U.S. News & World Report.', 'An M.Div. is a Master of Divinity degree.', 'A Master of Arts course was first offered at Notre Dame in the 1854–1855 academic year.', 'Forbes.com placed Notre Dame at 18th compared to other US research universities.', 'Irvin Abell worked on projects at Notre Dame that eventually created neoprene.', '20% of students at Notre Dame are the children of former Notre Dame students.', 'Irvin Abell was given the Laetare Medal by Notre Dame.', 'The Laetare Medal was first given out at Notre Dame in 1883.', 'The Old College at Notre Dame is in charge of the Congregation of the Holy Cross.', 'The Basilica of the Sacred Heart at Notre Dame is made in the French Gothic architectural style.']
# questions:  ['To whom did the Virgin Mary allegedly appear in 1858 in Lourdes France?', 'What is in front of the Notre Dame Main Building?', 'The Basilica of the Sacred heart at Notre Dame is beside to which structure?', 'What is the Grotto at Notre Dame?', 'What sits on top of the Main Building at Notre Dame?', 'When did the Scholastic Magazine of Notre dame begin publishing?', "How often is Notre Dame's the Juggler published?", 'What is the daily student paper at Notre Dame called?', 'How many student news papers are found at Notre Dame?', 'In what year did the student paper Common Sense begin publication at Notre Dame?', 'Where is the headquarters of the Congregation of the Holy Cross?', 'What is the primary seminary of the Congregation of the Holy Cross?', 'What is the oldest structure at Notre Dame?', 'What individuals live at Fatima House at Notre Dame?', 'Which prize did Frederick Buechner create?', 'How many BS level degrees are offered in the College of Engineering at Notre Dame?', 'Before the creation of the College of Engineering similar studies were carried out at which Notre Dame college?', 'The College of Science began to offer civil engineering courses beginning at what time at Notre Dame?', 'What entity provides help with the management of time for new students at Notre Dame?', 'What was created at Notre Dame in 1962 to assist first year students?', 'Which organization declared the First Year of Studies program at Notre Dame "outstanding?"', 'What type of degree is an M.Div.?', 'In what year was a Master of Arts course first offered at Notre Dame?', 'Forbes.com placed Notre Dame at what position compared to other US research universities?', 'Which individual worked on projects at Notre Dame that eventually created neoprene?', 'What percentage of students at Notre Dame are the children of former Notre Dame students?', 'Irvin Abell was given what award by Notre Dame?', 'Which year was the Laetare Medal first given out at Notre Dame?', 'Which congregation is in charge of the Old College at Notre Dame?', 'In which architectural style is the Basilica of the Sacred Heart at Notre Dame made?']
# answers:  ['The College of Engineering at Notre Dame was formed in 1893.', 'The Department of Art, Art History, and Design at Notre Dame is the only one to not offer a PhD program.', 'John B. Kroc was married to Ruth Munroe.', 'The person who was the Director of the Science Museum at Notre Dame in the late 19th century was Father Joseph Carrier, C.S.C.', 'John Augustine Zahm had a lifespan of 1851-1921.', 'John Augustine Zahm came to co-direct the Science Department at Notre Dame.', 'John Zahm wrote the book "Evolution and Dogma" in 1896.', 'Father Josh Carrier held the professorship of Chemistry and Physics at Notre Dame.', 'Albert Zahm began comparing aeronatical models at Notre Dame in 1882.', 'The first wireless message in the USA was sent by Professor Jerome Green.', 'Jerome Green sent his first wireless message in 1899.', "John Zahm's brother constructed the Lobund Institute at Notre Dame.", 'The work on a germ-free-life ended up in the creation of the Lobund Institute.', 'Lobund of Notre Dame became independent around the 1920s.', 'In 1950, Lobund at Notre Dame became an Institute.', 'The Lobund Institute was merged into the Department of Biology at Notre Dame in 1958.', 'In 1939, Gurian created the Medieval Institute at Notre Dame.', 'The Review of Politics was inspired by German Catholic journals.', 'Gurian edited the Review of Politics at Notre Dame for 44 years.', 'Thomas Stritch was an editor of the Review of Politics.', 'The president of Notre Dame in 2012 was John Jenkins.', 'The Kellogg Institute for International Studies is part of the University of Notre Dame.', 'Notre Dame began to host the Global Adaptation Index in 2013.', 'The Global Adaptation Index studies the threat of climate change.', 'In 2014, there were 8,462 undergrads attending Notre Dame.', 'In 2014, there were a total of 13,113 students at Notre Dame.', 'The College of Architecture was added to Notre Dame in 1921.', 'The change to national standards undertaken at Notre Dame in the early 20th century took place over 20 years.', 'Cavanaugh created the Lobund Institute involving animal life at Notre Dame.', 'Outside of an institute studying animals, Cavanugh created the Institute for Scholasticism at Notre Dame.', 'John Jenkins became the president of Notre Dame in 2012.', 'John Jenkins is the 18th president of Notre Dame.', 'The president who preceded John Jenkins was Father Edward Malloy.', '$35 million was spent on enhancing Notre Dame Stadium under John Jenkins.']
ked Notre Dame 18th in its 2015-2016 university rankings.', 'The undergrad school at the Mendoza College of Business was ranked 1st overall by BusinessWeek.', 'In 2014, USA Today named Notre Dame 10th best of all American universities.', '57.6% of Notre Dame students decide to study abroad.', 'The study of a germ-free-life began at Notre Dame in Not specified.', 'The Kroc Institute at Notre Dame focuses on peace studies.', '81% of Notre Dame students feel they are Christian.', 'Before its embracing of national standards, Notre Dame pushed a classical education.', "The president of Notre Dame in 1947 was John O'Hara.", 'Theodore Hesburgh lived from 1917 to 2015.', 'Theodore Hesburgh was president of Notre Dame from 1952 to 1987.']
# questions:  ['The granting of Doctorate degrees first occurred in what year at Notre Dame?', 'Which program at Notre Dame offers a Master of Education degree?', 'What institute at Notre Dame studies  the reasons for violent conflict?', "What is the title of Notre Dame's Theodore Hesburgh?", 'In what year was the Joan B. Kroc Institute for International Peace Studies founded?', 'What company did Ray Kroc own?', 'In what year was the Theodore M. Hesburgh Library at Notre Dame finished?', 'Which artist created the mural on the Theodore M. Hesburgh Library?', 'What is a common name to reference the mural created by Millard Sheets at Notre Dame?', 'How many incoming students did Notre Dame admit in fall 2015?', 'What percentage of students were admitted to Notre Dame in fall 2015?', 'Where does Notre Dame rank in terms of academic profile among research universities in the US?', 'What percentage of students at Notre Dame participated in the Early Action program?', 'How many miles does the average student at Notre Dame travel to study there?', 'Where did U.S. News & World Report rank Notre Dame in its 2015-2016 university rankings?', 'The undergrad school at the Mendoza College of Business was ranked where according to BusinessWeek?', 'In 2014 what entity named Notre Dame 10th best of all American universities?', 'What percentage of Notre Dame students decide to study abroad?', 'When did study of a germ-free-life begin at Notre Dame?', 'What does the Kroc Institute at Notre Dame focus on?', 'What percentage of Notre Dame students feel they are Christian?', 'What type of education was pushed at Notre Dame before its embracing of national standards?', 'Which president did Notre Dame have in 1947?', 'What was the lifespan of Theodore Hesburgh?', 'During what years was Theodor Hesburgh president of Notre Dame?']
# Question | Predicted Answer | Gold Answer
# --------------------------------------------------------------------------------
# Q1: To whom did the Virgin Mary allegedly appear in 1858 in Lourdes France?
# LLM Answer: The Virgin Mary allegedly appeared to Bernadette Soubirous in 1858 in Lourdes, France.
# Ground Truth: Saint Bernadette Soubirous
#
# Q2: What is in front of the Notre Dame Main Building?
# LLM Answer: In front of the Notre Dame Main Building is a copper statue of Christ with arms upraised with the legend "Venite Ad Me Omnes".
# Ground Truth: a copper statue of Christ
#
# Q3: The Basilica of the Sacred heart at Notre Dame is beside to which structure?
# LLM Answer: The Basilica of the Sacred heart at Notre Dame is beside the Main Building.
# Ground Truth: the Main Building
#
# Q4: What is the Grotto at Notre Dame?
# LLM Answer: The Grotto at Notre Dame is a Marian place of prayer and reflection, a replica of the grotto at Lourdes, France.
# Ground Truth: a Marian place of prayer and reflection
#
# Q5: What sits on top of the Main Building at Notre Dame?
# LLM Answer: A golden statue of the Virgin Mary sits on top of the Main Building at Notre Dame.
# Ground Truth: a golden statue of the Virgin Mary
#
# Q6: When did the Scholastic Magazine of Notre dame begin publishing?
# LLM Answer: The Scholastic Magazine of Notre Dame began publishing in September 1876.
# Ground Truth: September 1876
#
# Q7: How often is Notre Dame's the Juggler published?
# LLM Answer: The Juggler is published twice a year.
# Ground Truth: twice
#
# Q8: What is the daily student paper at Notre Dame called?
# LLM Answer: The daily student paper at Notre Dame is called The Observer.
# Ground Truth: The Observer
#
# Q9: How many student news papers are found at Notre Dame?
# LLM Answer: There are 9 student-run news outlets at Notre Dame.
# Ground Truth: three
#
# Q10: In what year did the student paper Common Sense begin publication at Notre Dame?
# LLM Answer: The student paper Common Sense began publication at Notre Dame in 1987.
# Ground Truth: 1987
#
# Q11: Where is the headquarters of the Congregation of the Holy Cross?
# LLM Answer: The headquarters of the Congregation of the Holy Cross is in Rome.
# Ground Truth: Rome
#
# Q12: What is the primary seminary of the Congregation of the Holy Cross?
# LLM Answer: The primary seminary of the Congregation of the Holy Cross is Moreau Seminary.
# Ground Truth: Moreau Seminary
#
# Q13: What is the oldest structure at Notre Dame?
# LLM Answer: The oldest structure at Notre Dame is Old College.
# Ground Truth: Old College
#
# Q14: What individuals live at Fatima House at Notre Dame?
# LLM Answer: Individuals who live at Fatima House at Notre Dame are retired priests and brothers.
# Ground Truth: Retired priests and brothers
#
# Q15: Which prize did Frederick Buechner create?
# LLM Answer: Frederick Buechner created the Buechner Prize for Preaching.
# Ground Truth: Buechner Prize for Preaching
#
# Q16: How many BS level degrees are offered in the College of Engineering at Notre Dame?
# LLM Answer: The College of Engineering at Notre Dame offers 8 BS level degrees.
# Ground Truth: eight
#
# Q17: In what year was the College of Engineering at Notre Dame formed?
# LLM Answer: The College of Engineering at Notre Dame was formed in 1893.
# Ground Truth: 1920
#
# Q18: Before the creation of the College of Engineering similar studies were carried out at which Notre Dame college?
# LLM Answer: Similar studies were carried out at the College of Science before the creation of the College of Engineering.
# Ground Truth: the College of Science
#
# Q19: How many departments are within the Stinson-Remick Hall of Engineering?
# LLM Answer: Not specified
# Ground Truth: five
#
# Q20: The College of Science began to offer civil engineering courses beginning at what time at Notre Dame?
# LLM Answer: The College of Science began to offer civil engineering courses in the 1870s at Notre Dame.
# Ground Truth: the 1870s
#
# Q21: What entity provides help with the management of time for new students at Notre Dame?
# LLM Answer: The entity that provides help with the management of time for new students at Notre Dame is the First Year of Studies program.
# Ground Truth: Learning Resource Center
#
# Q22: How many colleges for undergraduates are at Notre Dame?
# LLM Answer: Not specified
# Ground Truth: five
#
# Q23: What was created at Notre Dame in 1962 to assist first year students?
# LLM Answer: In 1962, a program called the Learning Resource Center was created at Notre Dame to assist first year students.
# Ground Truth: The First Year of Studies program
#
# Q24: Which organization declared the First Year of Studies program at Notre Dame "outstanding?"
# LLM Answer: The First Year of Studies program at Notre Dame was recognized as "outstanding" by U.S. News & World Report.
# Ground Truth: U.S. News & World Report
#
# Q25: The granting of Doctorate degrees first occurred in what year at Notre Dame?
# LLM Answer: The granting of Doctorate degrees first occurred in 1924 at Notre Dame.
# Ground Truth: 1924
#
# Q26: What type of degree is an M.Div.?
# LLM Answer: An M.Div. is a Master of Divinity degree.
# Ground Truth: Master of Divinity
#
# Q27: Which program at Notre Dame offers a Master of Education degree?
# LLM Answer: The Alliance for Catholic Education program offers a Master of Education degree.
# Ground Truth: Alliance for Catholic Education
#
# Q28: In what year was a Master of Arts course first offered at Notre Dame?
# LLM Answer: A Master of Arts course was first offered at Notre Dame in the 1854–1855 academic year.
# Ground Truth: 1854
#
# Q29: Which department at Notre Dame is the only one to not offer a PhD program?
# LLM Answer: The Department of Art, Art History, and Design at Notre Dame is the only one to not offer a PhD program.
# Ground Truth: Department of Pre-Professional Studies
#
# Q30: What institute at Notre Dame studies  the reasons for violent conflict?
# LLM Answer: The Joan B. Kroc Institute for International Peace Studies studies the reasons for violent conflict.
# Ground Truth: Joan B. Kroc Institute for International Peace Studies
#
# Q31: What is the title of Notre Dame's Theodore Hesburgh?
# LLM Answer: Theodore Hesburgh is the title of Notre Dame's Theodore M. Hesburgh.
# Ground Truth: President Emeritus of the University of Notre Dame
#
# Q32: In what year was the Joan B. Kroc Institute for International Peace Studies founded?
# LLM Answer: The Joan B. Kroc Institute for International Peace Studies was founded in 1986.
# Ground Truth: 1986
#
# Q33: To whom was John B. Kroc married?
# LLM Answer: John B. Kroc was married to Ruth Munroe.
# Ground Truth: Ray Kroc
#
# Q34: What company did Ray Kroc own?
# LLM Answer: Ray Kroc owned McDonald's.
# Ground Truth: McDonald's
#
# Q35: How many stories tall is the main library at Notre Dame?
# LLM Answer: Not specified
# Ground Truth: 14
#
# Q36: What is the name of the main library at Notre Dame?
# LLM Answer: Main Library
# Ground Truth: Theodore M. Hesburgh Library
#
# Q37: In what year was the Theodore M. Hesburgh Library at Notre Dame finished?
# LLM Answer: The Theodore M. Hesburgh Library at Notre Dame was finished in 1963.
# Ground Truth: 1963
#
# Q38: Which artist created the mural on the Theodore M. Hesburgh Library?
# LLM Answer: Millard Sheets created the mural on the Theodore M. Hesburgh Library.
# Ground Truth: Millard Sheets
#
# Q39: What is a common name to reference the mural created by Millard Sheets at Notre Dame?
# LLM Answer: The common name for the mural created by Millard Sheets at Notre Dame is "Touchdown Jesus".
# Ground Truth: Touchdown Jesus
#
# Q40: How many incoming students did Notre Dame admit in fall 2015?
# LLM Answer: Notre Dame admitted 3,577 incoming students in fall 2015.
# Ground Truth: 3,577
#
# Q41: What percentage of students were admitted to Notre Dame in fall 2015?
# LLM Answer: 19.7% of students were admitted to Notre Dame in fall 2015.
# Ground Truth: 19.7%
#
# Q42: Where does Notre Dame rank in terms of academic profile among research universities in the US?
# LLM Answer: Notre Dame ranks 10 to 15 in terms of academic profile among research universities in the US.
# Ground Truth: the top 10 to 15 in the nation
#
# Q43: What percentage of students at Notre Dame participated in the Early Action program?
# LLM Answer: 39.1% of students at Notre Dame participated in the Early Action program.
# Ground Truth: 39.1%
#
# Q44: How many miles does the average student at Notre Dame travel to study there?
# LLM Answer: The average student at Notre Dame travels more than 750 miles to study there.
# Ground Truth: more than 750 miles
#
# Q45: Where did U.S. News & World Report rank Notre Dame in its 2015-2016 university rankings?
# LLM Answer: U.S. News & World Report ranked Notre Dame 18th in its 2015-2016 university rankings.
# Ground Truth: 18th overall
#
# Q46: Forbes.com placed Notre Dame at what position compared to other US research universities?
# LLM Answer: Forbes.com placed Notre Dame at 18th compared to other US research universities.
# Ground Truth: 8th
#
# Q47: The undergrad school at the Mendoza College of Business was ranked where according to BusinessWeek?
# LLM Answer: The undergrad school at the Mendoza College of Business was ranked 1st overall by BusinessWeek.
# Ground Truth: 1st overall
#
# Q48: In 2014 what entity named Notre Dame 10th best of all American universities?
# LLM Answer: In 2014, USA Today named Notre Dame 10th best of all American universities.
# Ground Truth: USA Today
#
# Q49: What percentage of Notre Dame students decide to study abroad?
# LLM Answer: 57.6% of Notre Dame students decide to study abroad.
# Ground Truth: 57.6%
#
# Q50: What person was the Director of the Science Museum at Notre Dame in the late 19th century?
# LLM Answer: The person who was the Director of the Science Museum at Notre Dame in the late 19th century was Father Joseph Carrier, C.S.C.
# Ground Truth: Father Joseph Carrier, C.S.C.
#
# Q51: What was the lifespan of John Augustine Zahm?
# LLM Answer: John Augustine Zahm had a lifespan of 1851-1921.
# Ground Truth: 1851–1921
#
# Q52: What program did John Augustine Zahm come to co-direct at Nore Dame?
# LLM Answer: John Augustine Zahm came to co-direct the Science Department at Notre Dame.
# Ground Truth: the Science Department
#
# Q53: What book did John Zahm write in 1896?
# LLM Answer: John Zahm wrote the book "Evolution and Dogma" in 1896.
# Ground Truth: Evolution and Dogma
#
# Q54: What professorship did Father Josh Carrier hold at Notre Dame?
# LLM Answer: Father Josh Carrier held the professorship of Chemistry and Physics at Notre Dame.
# Ground Truth: Professor of Chemistry and Physics
#
# Q55: In what year did Albert Zahm begin comparing aeronatical models at Notre Dame?
# LLM Answer: Albert Zahm began comparing aeronatical models at Notre Dame in 1882.
# Ground Truth: 1882
#
# Q56: Which professor sent the first wireless message in the USA?
# LLM Answer: The first wireless message in the USA was sent by Professor Jerome Green.
# Ground Truth: Professor Jerome Green
#
# Q57: In what year did Jerome Green send his first wireless message?
# LLM Answer: Jerome Green sent his first wireless message in 1899.
# Ground Truth: Around 1899
#
# Q58: Which individual worked on projects at Notre Dame that eventually created neoprene?
# LLM Answer: Irvin Abell worked on projects at Notre Dame that eventually created neoprene.
# Ground Truth: Father Julius Nieuwland
#
# Q59: What did the brother of John Zahm construct at Notre Dame?
# LLM Answer: John Zahm's brother constructed the Lobund Institute at Notre Dame.
# Ground Truth: an early wind tunnel
#
# Q60: Work on a germ-free-life ended up in the creation of which Notre Dame institute?
# LLM Answer: The work on a germ-free-life ended up in the creation of the Lobund Institute.
# Ground Truth: The Lobund Institute
#
# Q61: Around what time did Lobund of Notre Dame become independent?
# LLM Answer: Lobund of Notre Dame became independent around the 1920s.
# Ground Truth: the 1940s
#
# Q62: In what year did Lobund at Notre Dame become an Institute?
# LLM Answer: In 1950, Lobund at Notre Dame became an Institute.
# Ground Truth: 1950
#
# Q63: The Lobund Institute was merged into the Department of Biology at Notre Dame in what year?
# LLM Answer: The Lobund Institute was merged into the Department of Biology at Notre Dame in 1958.
# Ground Truth: 1958
#
# Q64: When did study of a germ-free-life begin at Notre Dame?
# LLM Answer: The study of a germ-free-life began at Notre Dame in Not specified.
# Ground Truth: 1928
#
# Q65: Gurian created what in 1939 at Notre Dame?
# LLM Answer: In 1939, Gurian created the Medieval Institute at Notre Dame.
# Ground Truth: The Review of Politics
#
# Q66: What was the Review of Politics inspired by?
# LLM Answer: The Review of Politics was inspired by German Catholic journals.
# Ground Truth: German Catholic journals
#
# Q67: Over how many years did Gurian edit the Review of Politics at Notre Dame?
# LLM Answer: Gurian edited the Review of Politics at Notre Dame for 44 years.
# Ground Truth: 44
#
# Q68: Thomas Stritch was an editor of which publican from Notre Dame?
# LLM Answer: Thomas Stritch was an editor of the Review of Politics.
# Ground Truth: Review of Politics
#
# Q69: Who was the president of Notre Dame in 2012?
# LLM Answer: The president of Notre Dame in 2012 was John Jenkins.
# Ground Truth: John Jenkins
#
# Q70: The Kellogg Institute for International Studies is part of which university?
# LLM Answer: The Kellogg Institute for International Studies is part of the University of Notre Dame.
# Ground Truth: Notre Dame
#
# Q71: What does the Kroc Institute at Notre Dame focus on?
# LLM Answer: The Kroc Institute at Notre Dame focuses on peace studies.
# Ground Truth: International Peace studies
#
# Q72: In what year did Notre Dame begin to host the Global Adaptation Index?
# LLM Answer: Notre Dame began to host the Global Adaptation Index in 2013.
# Ground Truth: 2013
#
# Q73: What threat does the Global Adaptation Index study?
# LLM Answer: The Global Adaptation Index studies the threat of climate change.
# Ground Truth: climate change
#
# Q74: How many undergrads were attending Notre Dame in 2014?
# LLM Answer: In 2014, there were 8,462 undergrads attending Notre Dame.
# Ground Truth: 8,448
#
# Q75: What percentage of students at Notre Dame are the children of former Notre Dame students?
# LLM Answer: 20% of students at Notre Dame are the children of former Notre Dame students.
# Ground Truth: 21–24%
#
# Q76: How many teams participate in the Notre Dame Bookstore Basketball tournament?
# LLM Answer: 700
# Ground Truth: over 700
#
# Q77: For what cause is money raised at the Bengal Bouts tournament at Notre Dame?
# LLM Answer: For the Holy Cross Missions in Bangladesh
# Ground Truth: the Holy Cross Missions in Bangladesh
#
# Q78: How many students in total were at Notre Dame in 2014?
# LLM Answer: In 2014, there were a total of 13,113 students at Notre Dame.
# Ground Truth: 12,179
#
# Q79: What percentage of undergrads live on the Notre Dame campus?
# LLM Answer: 80%
# Ground Truth: 80%
#
# Q80: How many student housing areas are reserved for Notre Dame's graduate students?
# LLM Answer: Not specified
# Ground Truth: four
#
# Q81: How many dorms for males are on the Notre Dame campus?
# LLM Answer: 15
# Ground Truth: 15
#
# Q82: What amount of the graduate student body at Notre Dame live on the campus?
# LLM Answer: Not specified
# Ground Truth: 20%
#
# Q83: There are how many dorms for females at Notre Dame?
# LLM Answer: 14
# Ground Truth: 14
#
# Q84: What is Congregation of Holy Cross in Latin?
# LLM Answer: Congregatio a Sancta Cruce
# Ground Truth: Congregatio a Sancta Cruce
#
# Q85: What percentage of Notre Dame students feel they are Christian?
# LLM Answer: 81% of Notre Dame students feel they are Christian.
# Ground Truth: more than 93%
#
# Q86: How often is Catholic mass held at Notre Dame in a week?
# LLM Answer: Over 100 times
# Ground Truth: over 100 times
#
# Q87: How many chapels are on the Notre Dame campus?
# LLM Answer: 57
# Ground Truth: Fifty-seven
#
# Q88: What amount of the student body of Notre Dame identifies as Catholic?
# LLM Answer: Over 93%
# Ground Truth: over 80%
#
# Q89: In what year was the Main Building at Notre Dame razed in a fire?
# LLM Answer: 1879
# Ground Truth: 1879
#
# Q90: Who was the president of Notre Dame in 1879?
# LLM Answer: The Rev. William Corby
# Ground Truth: Rev. William Corby
#
# Q91: On what date was the rebuilding of The Main Building begun at Notre Dame after the fire that claimed the previous?
# LLM Answer: May 17th
# Ground Truth: 17th of May
#
# Q92: What did the Science Hall at Notre Dame come to be known as?
# LLM Answer: Science Hall came to be known as the LaFortune Center
# Ground Truth: LaFortune Student Center
#
# Q93: What type of education was pushed at Notre Dame before its embracing of national standards?
# LLM Answer: Before its embracing of national standards, Notre Dame pushed a classical education.
# Ground Truth: scholastic and classical
#
# Q94: Which college did Notre Dame add in 1921?
# LLM Answer: The College of Architecture was added to Notre Dame in 1921.
# Ground Truth: College of Commerce
#
# Q95: Over how many years did the change to national standards undertaken at Notre Dame in the early 20th century take place?
# LLM Answer: The change to national standards undertaken at Notre Dame in the early 20th century took place over 20 years.
# Ground Truth: three years
#
# Q96: Catholic people identified with Notre Dame, what religious group did people feel Yale represented?
# LLM Answer: Protestant people identified with Yale
# Ground Truth: the Protestant establishment
#
# Q97: Irvin Abell was given what award by Notre Dame?
# LLM Answer: Irvin Abell was given the Laetare Medal by Notre Dame.
# Ground Truth: Laetare Medal
#
# Q98: Which year was the Laetare Medal first given out at Notre Dame?
# LLM Answer: The Laetare Medal was first given out at Notre Dame in 1883.
# Ground Truth: 1883
#
# Q99: Which institute involving animal life did Cavanaugh create at Notre Dame?
# LLM Answer: Cavanaugh created the Lobund Institute involving animal life at Notre Dame.
# Ground Truth: Lobund Institute for Animal Studies
#
# Q100: What is O'Shaughnessy Hall of Notre Dame formerly known as?
# LLM Answer: Administration Building
# Ground Truth: Hall of Liberal Arts
#
# Q101: Which president did Notre Dame have in 1947?
# LLM Answer: The president of Notre Dame in 1947 was John O'Hara.
# Ground Truth: Rev. John J. Cavanaugh, C.S.C.
#
# Q102: Outside of an institute studying animals, what other institute did Cavanugh create at Notre Dame?
# LLM Answer: Outside of an institute studying animals, Cavanugh created the Institute for Scholasticism at Notre Dame.
# Ground Truth: Medieval Institute
#
# Q103: What was the lifespan of Theodore Hesburgh?
# LLM Answer: Theodore Hesburgh lived from 1917 to 2015.
# Ground Truth: 1917–2015
#
# Q104: During what years was Theodor Hesburgh president of Notre Dame?
# LLM Answer: Theodore Hesburgh was president of Notre Dame from 1952 to 1987.
# Ground Truth: 1952–87
#
# Q105: How many faculty members were at Notre Dame when Hesburgh left the role of president?
# LLM Answer: Not specified
# Ground Truth: 950
#
# Q106: In what year did Notre Dame have its earliest undergraduate that was female?
# LLM Answer: Not specified
# Ground Truth: 1971
#
# Q107: When did John Jenkins become the president of Notre Dame?
# LLM Answer: John Jenkins became the president of Notre Dame in 2012.
# Ground Truth: 2005
#
# Q108: In terms of the amount of presidents Notre Dame has had, where is John Jenkins on the list?
# LLM Answer: John Jenkins is the 18th president of Notre Dame.
# Ground Truth: 17th
#
# Q109: Who was the Notre Dame president that preceded John Jenkins?
# LLM Answer: The president who preceded John Jenkins was Father Edward Malloy.
# Ground Truth: Malloy
#
# Q110: Which arena was constructed under Jenkins at Notre Dame?
# LLM Answer: Compton Family Ice Arena
# Ground Truth: Compton Family Ice Arena
#
# Q111: How much money was spent on enhancing Notre Dame Stadium under John Jenkins?
# LLM Answer: $35 million was spent on enhancing Notre Dame Stadium under John Jenkins.
# Ground Truth: $400m
#
# Q112: Which congregation is in charge of the Old College at Notre Dame?
# LLM Answer: The Old College at Notre Dame is in charge of the Congregation of the Holy Cross.
# Ground Truth: Congregation of Holy Cross
#
# Q113: What structure is found on the location of the original church of Father Sorin at Notre Dame?
# LLM Answer: The Basilica of the Sacred Heart
# Ground Truth: Basilica of the Sacred Heart
#
# Q114: In which architectural style is the Basilica of the Sacred Heart at Notre Dame made?
# LLM Answer: The Basilica of the Sacred Heart at Notre Dame is made in the French Gothic architectural style.
# Ground Truth: French Revival
#
# Q115: Which individual painted the inside of the Basilica of the Sacred Heart at Notre Dame?
# LLM Answer: Luigi Gregori
# Ground Truth: Luigi Gregori
#
# Q116: In what year was the Grotto of Our Lady of Lourdes at Notre Dame constructed?
# LLM Answer: The Grotto of Our Lady of Lourdes was constructed in 1896
# Ground Truth: 1896
#
# Q117: Which person oversaw the creation of a science hall at Notre Dame in 1883?
# LLM Answer: Fr. Zahm
# Ground Truth: Fr. Zahm
#
# Q118: In what year did the student union building at Notre Dame get renamed to LaFortune Center?
# LLM Answer: The student union building at Notre Dame got renamed to LaFortune Center in 1950
# Ground Truth: 1950
#
# Q119: After which individual was the LaFortune Center Notre Dame named?
# LLM Answer: The LaFortune Center Notre Dame was named after Joseph LaFortune
# Ground Truth: Joseph LaFortune
#
# Q120: How large in square feet is the LaFortune Center at Notre Dame?
# LLM Answer: The LaFortune Center at Notre Dame is 83,000 square feet
# Ground Truth: 83,000 square feet
#
# Q121: What is the annual budget of Notre Dame's LaFortune Center?
# LLM Answer: The annual budget of Notre Dame's LaFortune Center is $1.2 million
# Ground Truth: $1.2 million
#
# Q122: How many halls are at Notre Dame that house students?
# LLM Answer: 29
# Ground Truth: 29
#
# Q123: Which library was built at Notre Dame in 1963?
# LLM Answer: The Hesburgh Library was built at Notre Dame in 1963
# Ground Truth: Theodore Hesburgh Library
#
# Q124: How many books are housed at the Theodore Hesburgh Library?
# LLM Answer: Not specified
# Ground Truth: almost 4 million
#
# Q125: Construction for which hall started on March 8th 2007 at Notre Dame?
# LLM Answer: Jenkins Nanovic Halls
# Ground Truth: Duncan Hall
#
# Q126: Which baseball stadium is found at Notre Dame?
# LLM Answer: Notre Dame Stadium
# Ground Truth: Frank Eck Stadium
#
# Q127: In what year did Notre Dame create the Office of Sustainability?
# LLM Answer: The Office of Sustainability was created at Notre Dame in 2008
# Ground Truth: 2008
#
# Q128: What percentage of the food served at Notre Dame is locally grown?
# LLM Answer: 40% of the food served at Notre Dame is locally grown
# Ground Truth: 40%
#
# Q129: Notre Dame got a "B" for its sustainability practices from which entity?
# LLM Answer: Notre Dame got a "B" for its sustainability practices from the Sustainable Endowments Institute.
# Ground Truth: Sustainable Endowments Institute
